# %%
import tkinter as tk
from tkinter import ttk
from PIL import Image, ImageTk
import pytesseract
from pytesseract import Output
import cv2
import speech_recognition as sr
import pyautogui as auto
import pyttsx3
import time
import gspread
import pyperclip
from oauth2client.service_account import ServiceAccountCredentials
from difflib import SequenceMatcher as SM
from PIL import Image
import ctypes
import win32api
import win32con
import atexit
def update_clock():
    current_time = time.strftime("%H:%M:%S")
    current_date = time.strftime("%Y-%m-%d")
    clock.config(text=f"Hora: {current_time}\nFecha: {current_date}")
    clock.after(1000, update_clock)
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/spreadsheets", "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("credentials.json", scope)
client = gspread.authorize(creds)
sheet = client.open_by_url('https://docs.google.com/spreadsheets/d/1RxxZPpm4cnJAzjLWnN38SN4Q57hJNY2bHk0w3Gd-sB0/edit?usp=sharing')
hoja = sheet.worksheet("Provedor Valero")
hoja3 = sheet.worksheet("Provedor Variado")
def copy_clipboard():
    auto.hotkey('Ctrl', 'c')
    time.sleep(.01)  # ctrl-c is usually very fast but your program may execute faster
    return pyperclip.paste()
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
recognizer = sr.Recognizer()
microphone = sr.Microphone(device_index = 0)
eng = pyttsx3.init()
eng.setProperty("rate", 140)
eng.setProperty("volume", 1.0)
listVoices = eng.getProperty("voices")
eng.setProperty("voice", listVoices[2].id)
def on_testado_button_clicked():
    eng.say("Reconocimiento de pantalla activado")
    eng.runAndWait()
    palabra = "Editar"
    img = auto.screenshot()
    d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
    n_boxes = len(d["level"])
    for i in range(n_boxes):
        x , y , text = (d["left"][i], d["top"][i], d["text"][i])
        if text != "" or text !=" " or text != "  "or text !="    ":
            print((i+1), "x: ",x , "Y ", y, " Text", text)
        similitud = SM(None, text, palabra).ratio()
        if similitud >0.7:
            auto.moveTo(x,y)
            auto.click()
            time.sleep(2)
    auto.moveTo(1297, 233)
    auto.mouseDown()
    auto.moveTo(1453,233)
    auto.mouseUp()
    NumFact = copy_clipboard()
    try:
    
        lol = hoja.find(NumFact)
        time.sleep(0.5)
        clienteMayus = hoja.cell(lol.row, 65).value
        if clienteMayus == "PENDIENTE DEFINIR" or "Razon Social":
            if(clienteMayus=="Razon Social"):
                eng.say("No se ha seleccionado nada, por favor abra el documento antes de ejecutar o haga visible el número de factura")
                eng.runAndWait()
            else:
                eng.say("Valero en carpeta bol")
                eng.runAndWait()
        else:
            palabra = "letra:"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra).ratio()
                if similitud >0.7:
                    auto.moveTo(x+40,y)
                    auto.mouseDown()
                    auto.moveTo(x+1080, y)
                    auto.mouseUp()
                    auto.press("delete")
                    time.sleep(1)
            palabra = "letra:"
            palabra2 = "TRASLADO"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra2).ratio()
                if similitud >0.7:
                    auto.moveTo(x+130,y)
                    auto.mouseDown()
                    auto.moveTo(x+210, y)
                    auto.mouseUp()
                    auto.press("delete")
                    auto.moveTo(x+490,y)
                    auto.mouseDown()
                    auto.moveTo(x+540, y)
                    auto.mouseUp()
                    auto.press("delete")
                    auto.moveTo(x+555, y)
                    auto.mouseDown()
                    auto.moveTo(x+650, y)
                    auto.mouseUp()
                    auto.press("delete")
                    time.sleep(1)
            palabra4 = "Subtotal"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra4).ratio()
                if similitud >0.7:
                    auto.moveTo(x+60,y+30)
                    auto.click()
                    auto.press("right")
                    auto.press("right")
                    auto.press("right")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.moveTo(x-460,y+30)
                    auto.mouseDown()
                    auto.moveTo(x-365,y+30)
                    auto.mouseUp()
                    auto.press("delete")
                    time.sleep(1)
            palabra5 = "cambio"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra5).ratio()
                if similitud >0.7:
                    auto.moveTo(x+90,y+25)
                    auto.mouseDown()
                    auto.moveTo(x+250, y -100)
                    auto.mouseUp()
                    time.sleep(0.1)
                    auto.press("delete")
                    time.sleep(1)
            palabra6 = "Unitario"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra6).ratio()
                if similitud >0.7:
                    auto.moveTo(x+340,y + 100)
                    auto.mouseDown()
                    auto.moveTo(x-50 , y + 20)
                    auto.mouseUp()
                    auto.press("delete")
                    time.sleep(1)
            auto.moveTo(1052, 153)
            auto.click()
            time.sleep(1)
            auto.moveTo(1094, 190)
            auto.click()
            time.sleep(5)
            auto.moveTo(671, 244)
            auto.click()
            time.sleep(1)
            auto.moveTo(721, 296)
            time.sleep(1)
            auto.typewrite("P")
            auto.press("enter")
            time.sleep(1)
            auto.moveTo(723, 302)
            auto.click()
            auto.press("space")
            time.sleep(0.5)
            auto.write(clienteMayus)
            time.sleep(1)
            auto.moveTo(1113, 815)
            auto.click()
            time.sleep(1)
            auto.moveTo(1056, 603)
            auto.click()
            auto.sleep(1)
###########AGREGAR MARCA DE AGUA#############################
            auto.moveTo(1052, 153)
            auto.click()
            time.sleep(1)
            auto.moveTo(1094, 190)
            auto.click()
            time.sleep(1)
            auto.moveTo(1086, 607)
            auto.click()
            time.sleep(3)
            auto.moveTo(671, 244)
            auto.click()
            time.sleep(1)
            auto.moveTo(721, 296)
            time.sleep(1)
            auto.typewrite("L")
            auto.typewrite("L")
            auto.typewrite("L")
            auto.press("enter")
            time.sleep(1)
            auto.moveTo(1113, 815)
            auto.click()
            time.sleep(1)
            auto.moveTo(1056, 603)
            auto.click()
            auto.sleep(3)
#####EXPORTAR COMO IMAGEN############
            auto.moveTo(1893, 331)
            auto.click()
            time.sleep(1)
            auto.moveTo(957, 543)
            auto.click()
            time.sleep(1)
            auto.moveTo(946, 741)
            auto.click()
            time.sleep(2)
            auto.moveTo(365, 443)
            auto.click()
            auto.typewrite("-2")
            time.sleep(1)
            auto.moveTo(67, 188)
            auto.click()
            time.sleep(1)
            auto.moveTo(777, 588)
            auto.click()
            time.sleep(10)
            auto.moveTo(1883, 7)
            auto.click()
            time.sleep(1)
            auto.moveTo(1046, 579)
            auto.click()

    except:
        if len(NumFact) == 0 or not NumFact.isdigit():
            eng.say("No se ha seleccionado nada, por favor abra el documento antes de ejecutar el programa o ajuste su pantalla")
            eng.runAndWait()
        else:
            eng.say("VALERO NO REGISTRADA EN BITÁCORA. AVISAR A FACTURACIÓN")
            eng.runAndWait();
            b=0;
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, " Archivo").ratio()
                if similitud >0.7 and b==0:
                    auto.moveTo(x,y)
                    auto.click()
                    time.sleep(2)
                    b=b+1
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            b=0;
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, "Guardar").ratio()
                if similitud >0.7 and b==0:
                    auto.moveTo(x,y);
                    auto.click();
                    time.sleep(1.2);
                    auto.press("right")
                    time.sleep(0.3)
                    auto.typewrite("-NO REGISTRADA")
                    b=1;
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"]);
            b=0
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, "Guardar").ratio()
                if similitud >0.7 and b<=1:
                    if b ==0:
                        b=b+1
                else:
                    auto.moveTo(x,y)
                    auto.click()

def on_facturacion_button_clicked():
    print("Botón Facturación ha sido presionado")
root = tk.Tk()
wtotal = root.winfo_screenwidth()
htotal = root.winfo_screenheight()
wventana = 900
hventana = 555
pwidth = round(wtotal/2-wventana/2)
pheight = round(htotal/2-hventana/2)
root.geometry(str(wventana)+"x"+str(hventana)+"+"+str(pwidth)+"+"+str(pheight))
root.resizable(0,0)
root.title("Departamento de Facturación Petrolíferos Lobo")
logo =Image.open("lobito.jpg")
icono = ImageTk.PhotoImage(logo)
root.iconphoto(True, icono)
def on_exit_button_clicked():
    root.destroy()
image_quit = Image.open("Quit.png")
photo_quit = ImageTk.PhotoImage(image_quit.resize((45,45)))
exit_button = ttk.Button(root, image=photo_quit, compound="bottom", command=on_exit_button_clicked)


# Cargamos las imágenes
image_documento = Image.open("Testado.png")
photo_documento = ImageTk.PhotoImage(image_documento.resize((80,80)))

image_billete = Image.open("Facturación.png")
photo_billete = ImageTk.PhotoImage(image_billete.resize((80,80)))

# Creamos los botones con sus imágenes y etiquetas

testado_button = ttk.Button(root, text="Testado",  compound="top",image=photo_documento, command=on_testado_button_clicked)

facturacion_button = ttk.Button(root, text="Facturación",compound="top", image=photo_billete, command=on_facturacion_button_clicked)

# Guardamos una referencia a las imágenes
testado_button.image = photo_documento
facturacion_button.image = photo_billete

# Posicionamos los botones en la ventana
testado_button.pack()
facturacion_button.pack()
exit_button.pack()
testado_button.place(x=150,y=50, width=300, height = 450)
facturacion_button.place(x=480,y=50, width=300, height =450)
exit_button.place(x=850,y=500, width=50, height = 55)


root.mainloop()
# Out:
# 1 x:  0 Y  0  Text
# 2 x:  0 Y  10  Text
# 3 x:  0 Y  10  Text
# 4 x:  0 Y  10  Text
# 5 x:  0 Y  10  Text
# 6 x:  7 Y  28  Text
# 7 x:  7 Y  28  Text
# 8 x:  7 Y  28  Text
# 9 x:  7 Y  28  Text Archivo
# 10 x:  30 Y  7  Text
# 11 x:  30 Y  7  Text
# 12 x:  30 Y  7  Text
# 13 x:  30 Y  7  Text ECFD_20230213_105632.pdf
# 14 x:  176 Y  0  Text -
# 15 x:  183 Y  7  Text Adobe
# 16 x:  221 Y  7  Text Acrobat
# 17 x:  267 Y  7  Text Pro
# 18 x:  288 Y  7  Text DC
# 19 x:  63 Y  28  Text
# 20 x:  63 Y  28  Text
# 21 x:  63 Y  28  Text
# 22 x:  63 Y  28  Text Edición
# 23 x:  115 Y  28  Text Ver
# 24 x:  145 Y  28  Text Ventana
# 25 x:  201 Y  28  Text Ayuda
# 26 x:  1211 Y  170  Text
# 27 x:  1211 Y  170  Text
# 28 x:  1211 Y  170  Text
# 29 x:  1211 Y  170  Text FACTURA
# 30 x:  1335 Y  170  Text 3644882696
# 31 x:  300 Y  218  Text
# 32 x:  300 Y  218  Text
# 33 x:  300 Y  218  Text
# 34 x:  300 Y  218  Text VALERO
# 35 x:  410 Y  218  Text MARKETING
# 36 x:  566 Y  218  Text AND
# 37 x:  628 Y  218  Text SUPPLY
# 38 x:  733 Y  218  Text DE
# 39 x:  774 Y  218  Text MEXICO
# 40 x:  301 Y  281  Text
# 41 x:  301 Y  281  Text
# 42 x:  301 Y  281  Text
# 43 x:  301 Y  281  Text RFC:
# 44 x:  339 Y  281  Text VMS16042911A
# 45 x:  301 Y  302  Text
# 46 x:  301 Y  302  Text Régimen
# 47 x:  365 Y  302  Text Fiscal:
# 48 x:  412 Y  302  Text 601-General
# 49 x:  499 Y  302  Text de
# 50 x:  520 Y  302  Text Ley
# 51 x:  548 Y  302  Text Personas
# 52 x:  616 Y  302  Text Morales
# 53 x:  301 Y  322  Text
# 54 x:  301 Y  322  Text Lugar,
# 55 x:  345 Y  322  Text fecha
# 56 x:  386 Y  325  Text y
# 57 x:  399 Y  322  Text hora
# 58 x:  432 Y  322  Text de
# 59 x:  453 Y  322  Text expedición:
# 60 x:  533 Y  322  Text 87440
# 61 x:  580 Y  322  Text 13/02/2023
# 62 x:  663 Y  322  Text 10:56:32
# 63 x:  82 Y  369  Text
# 64 x:  82 Y  369  Text
# 65 x:  82 Y  369  Text
# 66 x:  82 Y  369  Text CLIENTE
# 67 x:  90 Y  417  Text
# 68 x:  90 Y  417  Text
# 69 x:  90 Y  417  Text
# 70 x:  90 Y  417  Text PETROLIFEROS
# 71 x:  210 Y  417  Text LOBO
# 72 x:  90 Y  438  Text
# 73 x:  90 Y  438  Text
# 74 x:  90 Y  438  Text RFC:
# 75 x:  129 Y  438  Text PLO170306G79
# 76 x:  90 Y  458  Text
# 77 x:  90 Y  458  Text
# 78 x:  90 Y  458  Text Régimen
# 79 x:  155 Y  458  Text Fiscal:
# 80 x:  201 Y  458  Text 601-General
# 81 x:  288 Y  458  Text de
# 82 x:  310 Y  458  Text Ley
# 83 x:  338 Y  458  Text Personas
# 84 x:  405 Y  458  Text Morales
# 85 x:  90 Y  479  Text
# 86 x:  90 Y  479  Text Domicilio
# 87 x:  156 Y  479  Text Fiscal:
# 88 x:  202 Y  479  Text 64650
# 89 x:  90 Y  499  Text
# 90 x:  90 Y  499  Text
# 91 x:  90 Y  499  Text Uso
# 92 x:  121 Y  499  Text CFDI:
# 93 x:  164 Y  499  Text GO1-Adquisición
# 94 x:  278 Y  499  Text de
# 95 x:  299 Y  499  Text mercancías.
# 96 x:  79 Y  533  Text
# 97 x:  79 Y  533  Text
# 98 x:  79 Y  533  Text
# 99 x:  79 Y  533  Text PRODUCTOS
# 100 x:  243 Y  533  Text /
# 101 x:  258 Y  533  Text SERVICIOS
# 102 x:  328 Y  572  Text
# 103 x:  328 Y  572  Text
# 104 x:  328 Y  572  Text
# 105 x:  328 Y  576  Text Clave
# 106 x:  380 Y  576  Text Prod/
# 107 x:  811 Y  572  Text Objeto
# 108 x:  921 Y  576  Text Clave
# 109 x:  342 Y  591  Text
# 110 x:  342 Y  591  Text Servicio
# 111 x:  824 Y  595  Text Imp
# 112 x:  916 Y  595  Text unidad
# 113 x:  335 Y  625  Text
# 114 x:  335 Y  625  Text
# 115 x:  335 Y  625  Text
# 116 x:  335 Y  625  Text 15101505-
# 117 x:  455 Y  625  Text Diesel
# 118 x:  507 Y  632  Text -
# 119 x:  519 Y  625  Text H/20054/COM/2017
# 120 x:  818 Y  625  Text 02-Si
# 121 x:  909 Y  625  Text STL-Litro
# 122 x:  1038 Y  625  Text 120
# 123 x:  327 Y  634  Text
# 124 x:  327 Y  634  Text
# 125 x:  327 Y  634  Text
# 126 x:  327 Y  634  Text Combustible
# 127 x:  803 Y  644  Text objeto
# 128 x:  855 Y  644  Text de
# 129 x:  911 Y  644  Text estándar
# 130 x:  352 Y  664  Text
# 131 x:  352 Y  664  Text diesel
# 132 x:  801 Y  664  Text impuesto
# 133 x:  423 Y  688  Text
# 134 x:  423 Y  688  Text
# 135 x:  423 Y  688  Text
# 136 x:  423 Y  689  Text TRASLADO:
# 137 x:  516 Y  689  Text Base:
# 138 x:  560 Y  689  Text 485057.23
# 139 x:  641 Y  689  Text Impuesto:
# 140 x:  717 Y  689  Text 002-IVA
# 141 x:  774 Y  689  Text Tipo
# 142 x:  811 Y  689  Text de
# 143 x:  832 Y  689  Text factor:
# 144 x:  883 Y  689  Text Tasa
# 145 x:  919 Y  689  Text Tasa
# 146 x:  957 Y  692  Text o
# 147 x:  971 Y  690  Text cuota:
# 148 x:  1020 Y  689  Text 8.00%
# 149 x:  1067 Y  689  Text Importe:
# 150 x:  1131 Y  688  Text $38,804.58
# 151 x:  967 Y  417  Text
# 152 x:  967 Y  417  Text
# 153 x:  967 Y  417  Text
# 154 x:  967 Y  409  Text Lugar
# 155 x:  1009 Y  417  Text de
# 156 x:  1030 Y  420  Text carga:
# 157 x:  1075 Y  417  Text TRUCK
# 158 x:  1132 Y  417  Text B/S-SunocoBrownsville-MX
# 159 x:  967 Y  438  Text
# 160 x:  967 Y  438  Text Destino:
# 161 x:  1025 Y  438  Text 4000207
# 162 x:  1088 Y  445  Text -
# 163 x:  1098 Y  438  Text PETROLIFEROS
# 164 x:  1218 Y  438  Text LOBO-MX-EXPT
# 165 x:  1334 Y  438  Text ONLY,MEX
# 166 x:  968 Y  458  Text
# 167 x:  968 Y  458  Text Fecha
# 168 x:  1013 Y  458  Text BOL:
# 169 x:  1052 Y  458  Text 10/02/2023
# 170 x:  967 Y  479  Text
# 171 x:  967 Y  479  Text Número
# 172 x:  1024 Y  479  Text de
# 173 x:  1045 Y  479  Text BOL:
# 174 x:  1084 Y  479  Text 10742
# 175 x:  78 Y  582  Text
# 176 x:  78 Y  582  Text
# 177 x:  78 Y  582  Text
# 178 x:  78 Y  586  Text Cantidad
# 179 x:  199 Y  586  Text Clave
# 180 x:  454 Y  582  Text Descripción
# 181 x:  1024 Y  586  Text Unidad
# 182 x:  1114 Y  586  Text Valor
# 183 x:  1162 Y  586  Text Unitario
# 184 x:  1421 Y  586  Text Importe
# 185 x:  111 Y  624  Text
# 186 x:  111 Y  624  Text
# 187 x:  111 Y  624  Text
# 188 x:  111 Y  625  Text 28411.681
# 189 x:  211 Y  625  Text ULSD.M2
# 190 x:  1143 Y  624  Text $17.506084
# 191 x:  1388 Y  624  Text $497,377.27
# 192 x:  327 Y  682  Text
# 193 x:  327 Y  682  Text
# 194 x:  327 Y  682  Text
# 195 x:  327 Y  682  Text
# 196 x:  1221 Y  683  Text
# 197 x:  1221 Y  683  Text
# 198 x:  1221 Y  683  Text
# 199 x:  1221 Y  683  Text
# 200 x:  327 Y  683  Text
# 201 x:  327 Y  683  Text
# 202 x:  327 Y  683  Text
# 203 x:  327 Y  683  Text
# 204 x:  327 Y  712  Text
# 205 x:  327 Y  712  Text
# 206 x:  327 Y  712  Text
# 207 x:  327 Y  712  Text
# 208 x:  78 Y  800  Text
# 209 x:  78 Y  800  Text
# 210 x:  1248 Y  800  Text
# 211 x:  1248 Y  800  Text Subtotal
# 212 x:  1390 Y  803  Text $497,377.27
# 213 x:  78 Y  826  Text
# 214 x:  78 Y  827  Text Traslado
# 215 x:  676 Y  827  Text Base:
# 216 x:  727 Y  826  Text $485,057.23
# 217 x:  834 Y  827  Text Impuesto:
# 218 x:  921 Y  827  Text 002-IVA
# 219 x:  988 Y  827  Text Tipo
# 220 x:  1029 Y  827  Text de
# 221 x:  1054 Y  827  Text factor:
# 222 x:  1113 Y  827  Text Tasa
# 223 x:  1155 Y  827  Text Tasa
# 224 x:  1198 Y  830  Text o
# 225 x:  1214 Y  827  Text cuota:
# 226 x:  1271 Y  827  Text 8.00%
# 227 x:  1399 Y  826  Text $38,804.58
# 228 x:  73 Y  845  Text
# 229 x:  73 Y  845  Text
# 230 x:  73 Y  845  Text
# 231 x:  73 Y  845  Text
# 232 x:  78 Y  853  Text
# 233 x:  78 Y  853  Text
# 234 x:  78 Y  853  Text
# 235 x:  78 Y  854  Text Importe
# 236 x:  147 Y  857  Text con
# 237 x:  183 Y  854  Text letra:
# 238 x:  230 Y  854  Text QUINIENTOS
# 239 x:  343 Y  854  Text TREINTA
# 240 x:  421 Y  854  Text Y
# 241 x:  438 Y  854  Text SEIS
# 242 x:  483 Y  854  Text MIL
# 243 x:  517 Y  854  Text CIENTO
# 244 x:  588 Y  854  Text OCHENTA
# 245 x:  674 Y  844  Text Y
# 246 x:  694 Y  854  Text UN
# 247 x:  724 Y  854  Text PESOS
# 248 x:  788 Y  854  Text 85/100
# 249 x:  851 Y  854  Text MXN
# 250 x:  1278 Y  854  Text Total
# 251 x:  1390 Y  853  Text $536,181.85
# 252 x:  1252 Y  877  Text
# 253 x:  1252 Y  877  Text Moneda
# 254 x:  1448 Y  877  Text MXN
# 255 x:  1192 Y  901  Text
# 256 x:  1192 Y  901  Text Tipo
# 257 x:  1232 Y  901  Text de
# 258 x:  1257 Y  901  Text cambio
# 259 x:  1478 Y  901  Text 1
# 260 x:  75 Y  926  Text
# 261 x:  75 Y  926  Text
# 262 x:  75 Y  926  Text
# 263 x:  75 Y  926  Text
# 264 x:  76 Y  941  Text
# 265 x:  76 Y  941  Text
# 266 x:  77 Y  941  Text
# 267 x:  77 Y  941  Text Cadena
# 268 x:  135 Y  941  Text Original
# 269 x:  196 Y  941  Text del
# 270 x:  223 Y  941  Text Complemento
# 271 x:  326 Y  941  Text de
# 272 x:  349 Y  941  Text Certificación
# 273 x:  444 Y  941  Text Digital
# 274 x:  494 Y  941  Text del
# 275 x:  520 Y  941  Text SAT:
# 276 x:  560 Y  941  Text ||1.11384C0FF8-5D3C-415E-B5F3-EFSEBDAO2A37/2023-02-
# 277 x:  77 Y  959  Text
# 278 x:  77 Y  959  Text 137T11:01:19/5ST060807KU0|cJYtaGyK29/5U+AcFY
# 279 x:  428 Y  959  Text 1Tue15BI4RsglF+8+nTXXymYhnhRPA1bMFLqkm+KUpRDI84e2j0jAtWwW6VKSWxkpOAMZGwuE9Ubr78W4d9wLpOTxqt3lg7XmQaqokZUbTPtzVwux48aZx
# 280 x:  76 Y  976  Text
# 281 x:  76 Y  976  Text rkUdvLbOA6+EH2fCzrbm250ZwOADIRCL2qEqiuw35x66Dsj5Gs3d7bpOmqvGXkqihBkPSL1TwChHDWdgd8sZB¡8BV/q21wJrVkU8jTIJONIGjYFL1/0MUN/w1HiesVDY
# 282 x:  1115 Y  976  Text Tv6glagCzaGETVr2FWOmzu4mkMygEm
# 283 x:  76 Y  993  Text
# 284 x:  76 Y  985  Text kJkCS5x0ycNb2AlcbL
# 285 x:  226 Y  993  Text qKemDK6oFCLJInKg4kRnRynjacfoTg==/000010000005062027891|
# 286 x:  76 Y  1011  Text
# 287 x:  76 Y  1011  Text Sello
# 288 x:  116 Y  1011  Text Digital
# 289 x:  166 Y  1011  Text del
# 290 x:  193 Y  1011  Text Emisor:
# 291 x:  676 Y  1025  Text
# 292 x:  676 Y  1025  Text
# 293 x:  676 Y  1025  Text
# 294 x:  676 Y  1025  Text [Departamento
# 295 x:  765 Y  1025  Text de
# 296 x:  781 Y  1025  Text Facturación
# 297 x:  846 Y  1025  Text Petrolíferos
# 298 x:  909 Y  1025  Text Lobo
# 299 x:  0 Y  8  Text
# 300 x:  0 Y  8  Text
# 301 x:  0 Y  8  Text
# 302 x:  0 Y  8  Text
# 303 x:  1639 Y  207  Text
# 304 x:  1639 Y  207  Text
# 305 x:  1639 Y  207  Text
# 306 x:  1639 Y  208  Text Crear
# 307 x:  1683 Y  207  Text archivo
# 308 x:  1737 Y  208  Text PDF
# 309 x:  1639 Y  253  Text
# 310 x:  1639 Y  254  Text Combinar
# 311 x:  1712 Y  253  Text archivos
# 312 x:  1640 Y  299  Text
# 313 x:  1640 Y  299  Text Editar
# 314 x:  1684 Y  300  Text PDF
# 315 x:  1640 Y  345  Text
# 316 x:  1640 Y  346  Text Exportar
# 317 x:  1701 Y  345  Text archivo
# 318 x:  1757 Y  346  Text PDF
# 319 x:  1639 Y  391  Text
# 320 x:  1639 Y  391  Text Organizar
# 321 x:  1713 Y  391  Text páginas
# 322 x:  1640 Y  437  Text
# 323 x:  1640 Y  437  Text Enviar
# 324 x:  1687 Y  441  Text para
# 325 x:  1721 Y  437  Text comentarios
# 326 x:  1639 Y  484  Text
# 327 x:  1639 Y  484  Text Comentar
# 328 x:  1640 Y  529  Text
# 329 x:  1640 Y  529  Text Rellenar
# 330 x:  1700 Y  519  Text y
# 331 x:  1710 Y  529  Text firmar
# 332 x:  1667 Y  575  Text
# 333 x:  1667 Y  575  Text italizar
# 334 x:  1719 Y  565  Text y
# 335 x:  1732 Y  575  Text OCR
# 336 x:  1640 Y  622  Text
# 337 x:  1640 Y  622  Text Proteger
# 338 x:  1639 Y  667  Text
# 339 x:  1639 Y  667  Text
# 340 x:  1639 Y  667  Text
# 341 x:  1639 Y  667  Text JavaScript
# 342 x:  1609 Y  709  Text
# 343 x:  1609 Y  709  Text
# 344 x:  1609 Y  709  Text
# 345 x:  1609 Y  709  Text [E]
# 346 x:  1639 Y  713  Text Asistente
# 347 x:  1706 Y  713  Text de
# 348 x:  1727 Y  713  Text acciones
# 349 x:  1607 Y  754  Text
# 350 x:  1607 Y  754  Text
# 351 x:  1607 Y  754  Text
# 352 x:  1607 Y  754  Text OS
# 353 x:  1611 Y  968  Text
# 354 x:  1611 Y  968  Text
# 355 x:  1611 Y  968  Text
# 356 x:  1611 Y  968  Text Almacene
# 357 x:  1676 Y  971  Text y
# 358 x:  1688 Y  969  Text comparta
# 359 x:  1750 Y  968  Text archivos
# 360 x:  1807 Y  971  Text en
# 361 x:  1826 Y  968  Text Document
# 362 x:  1731 Y  983  Text
# 363 x:  1731 Y  983  Text Cloud
# 364 x:  1706 Y  1008  Text
# 365 x:  1706 Y  1008  Text
# 366 x:  1706 Y  1008  Text
# 367 x:  1706 Y  1008  Text Más
# 368 x:  1731 Y  1008  Text información
# 1 x:  0 Y  0  Text
# 2 x:  0 Y  10  Text
# 3 x:  0 Y  10  Text
# 4 x:  0 Y  10  Text
# 5 x:  0 Y  10  Text
# 6 x:  7 Y  28  Text
# 7 x:  7 Y  28  Text
# 8 x:  7 Y  28  Text
# 9 x:  7 Y  28  Text Archivo
# 10 x:  30 Y  7  Text
# 11 x:  30 Y  7  Text
# 12 x:  30 Y  7  Text
# 13 x:  30 Y  7  Text sECFD_20230124,010802.pdf
# 14 x:  176 Y  0  Text -
# 15 x:  183 Y  7  Text Adobe
# 16 x:  221 Y  7  Text Acrobat
# 17 x:  267 Y  7  Text Pro
# 18 x:  288 Y  7  Text DC
# 19 x:  63 Y  28  Text
# 20 x:  63 Y  28  Text
# 21 x:  63 Y  28  Text
# 22 x:  63 Y  28  Text Edición
# 23 x:  115 Y  28  Text Ver
# 24 x:  145 Y  28  Text Ventana
# 25 x:  201 Y  28  Text Ayuda
# 26 x:  300 Y  218  Text
# 27 x:  300 Y  218  Text
# 28 x:  300 Y  218  Text
# 29 x:  300 Y  218  Text VALERO
# 30 x:  410 Y  218  Text MARKETING
# 31 x:  566 Y  218  Text AND
# 32 x:  628 Y  218  Text SUPPLY
# 33 x:  733 Y  218  Text DE
# 34 x:  774 Y  218  Text MEXICO
# 35 x:  301 Y  281  Text
# 36 x:  301 Y  281  Text
# 37 x:  301 Y  281  Text
# 38 x:  301 Y  281  Text RFC:
# 39 x:  339 Y  281  Text VMS16042911A
# 40 x:  301 Y  302  Text
# 41 x:  301 Y  302  Text Régimen
# 42 x:  365 Y  302  Text Fiscal:
# 43 x:  412 Y  302  Text 601-General
# 44 x:  499 Y  302  Text de
# 45 x:  520 Y  302  Text Ley
# 46 x:  548 Y  302  Text Personas
# 47 x:  616 Y  302  Text Morales
# 48 x:  301 Y  322  Text
# 49 x:  301 Y  322  Text Lugar,
# 50 x:  345 Y  322  Text fecha
# 51 x:  386 Y  325  Text y
# 52 x:  399 Y  322  Text hora
# 53 x:  432 Y  322  Text de
# 54 x:  453 Y  322  Text expedición:
# 55 x:  533 Y  322  Text 88000
# 56 x:  578 Y  322  Text 24/01/2023
# 57 x:  662 Y  322  Text 01:08:02
# 58 x:  82 Y  369  Text
# 59 x:  82 Y  369  Text
# 60 x:  82 Y  369  Text
# 61 x:  82 Y  369  Text CLIENTE
# 62 x:  90 Y  417  Text
# 63 x:  90 Y  417  Text
# 64 x:  90 Y  417  Text
# 65 x:  90 Y  417  Text PETROLIFEROS
# 66 x:  210 Y  417  Text LOBO
# 67 x:  90 Y  438  Text
# 68 x:  90 Y  438  Text
# 69 x:  90 Y  438  Text RFC:
# 70 x:  129 Y  438  Text PLO170306G79
# 71 x:  90 Y  458  Text
# 72 x:  90 Y  458  Text
# 73 x:  90 Y  458  Text Régimen
# 74 x:  155 Y  458  Text Fiscal:
# 75 x:  201 Y  458  Text 601-General
# 76 x:  288 Y  458  Text de
# 77 x:  310 Y  458  Text Ley
# 78 x:  338 Y  458  Text Personas
# 79 x:  405 Y  458  Text Morales
# 80 x:  90 Y  479  Text
# 81 x:  90 Y  479  Text Domicilio
# 82 x:  156 Y  479  Text Fiscal:
# 83 x:  202 Y  479  Text 64650
# 84 x:  90 Y  499  Text
# 85 x:  90 Y  499  Text
# 86 x:  90 Y  499  Text Uso
# 87 x:  121 Y  499  Text CFDI:
# 88 x:  164 Y  499  Text GO1-Adquisición
# 89 x:  278 Y  499  Text de
# 90 x:  299 Y  499  Text mercancías.
# 91 x:  79 Y  533  Text
# 92 x:  79 Y  533  Text
# 93 x:  79 Y  533  Text
# 94 x:  79 Y  533  Text PRODUCTOS
# 95 x:  243 Y  533  Text /
# 96 x:  258 Y  533  Text SERVICIOS
# 97 x:  328 Y  565  Text
# 98 x:  328 Y  565  Text
# 99 x:  328 Y  565  Text
# 100 x:  328 Y  576  Text Clave
# 101 x:  380 Y  576  Text Prod
# 102 x:  503 Y  586  Text crioció
# 103 x:  811 Y  565  Text Objeto
# 104 x:  921 Y  576  Text Clave
# 105 x:  342 Y  585  Text
# 106 x:  342 Y  585  Text Servicio
# 107 x:  466 Y  589  Text escripción
# 108 x:  824 Y  595  Text Imp
# 109 x:  916 Y  595  Text unidad
# 110 x:  110 Y  625  Text
# 111 x:  110 Y  625  Text
# 112 x:  110 Y  625  Text
# 113 x:  110 Y  625  Text 33957.000
# 114 x:  200 Y  625  Text 87CON11.5.
# 115 x:  335 Y  625  Text  15101514-
# 116 x:  454 Y  625  Text 87
# 117 x:  478 Y  625  Text Oct
# 118 x:  510 Y  625  Text Convencional
# 119 x:  622 Y  625  Text 11.5
# 120 x:  659 Y  625  Text RVP
# 121 x:  698 Y  632  Text -
# 122 x:  710 Y  625  Text H/20054/
# 123 x:  794 Y  615  Text —
# 124 x:  818 Y  625  Text 02-Sí
# 125 x:  909 Y  625  Text STL-Litro
# 126 x:  1038 Y  625  Text 120
# 127 x:  236 Y  639  Text
# 128 x:  236 Y  639  Text ma
# 129 x:  312 Y  644  Text Gasolina
# 130 x:  386 Y  644  Text regular
# 131 x:  454 Y  644  Text COM/2017
# 132 x:  803 Y  644  Text objeto
# 133 x:  855 Y  644  Text de
# 134 x:  911 Y  644  Text estándar
# 135 x:  332 Y  664  Text
# 136 x:  332 Y  667  Text menor
# 137 x:  386 Y  667  Text a
# 138 x:  400 Y  664  Text 91
# 139 x:  801 Y  664  Text impuesto.
# 140 x:  345 Y  683  Text
# 141 x:  345 Y  683  Text octanos
# 142 x:  967 Y  417  Text
# 143 x:  967 Y  417  Text
# 144 x:  967 Y  417  Text
# 145 x:  967 Y  417  Text Lugar
# 146 x:  1009 Y  417  Text de
# 147 x:  1030 Y  420  Text carga:
# 148 x:  1076 Y  417  Text Nuevo
# 149 x:  1124 Y  417  Text Laredo,
# 150 x:  1177 Y  417  Text TMS,
# 151 x:  1218 Y  417  Text MX
# 152 x:  967 Y  438  Text
# 153 x:  967 Y  438  Text Destino:
# 154 x:  1026 Y  438  Text 6002070
# 155 x:  1088 Y  445  Text -
# 156 x:  1098 Y  438  Text PETROLIFEROS
# 157 x:  1218 Y  438  Text LOBO-UNB-MX
# 158 x:  1329 Y  428  Text MEX
# 159 x:  968 Y  458  Text
# 160 x:  968 Y  458  Text Fecha
# 161 x:  1013 Y  458  Text BOL:
# 162 x:  1051 Y  458  Text 23/01/2023
# 163 x:  967 Y  479  Text
# 164 x:  967 Y  479  Text Número
# 165 x:  1024 Y  479  Text de
# 166 x:  1045 Y  479  Text BOL:
# 167 x:  1083 Y  479  Text 84036
# 168 x:  78 Y  586  Text
# 169 x:  78 Y  586  Text
# 170 x:  78 Y  586  Text
# 171 x:  78 Y  586  Text Cantidad
# 172 x:  199 Y  586  Text Clave
# 173 x:  1024 Y  586  Text Unidad
# 174 x:  1114 Y  586  Text Valor
# 175 x:  1162 Y  586  Text Unitario
# 176 x:  1421 Y  586  Text Importe
# 177 x:  1143 Y  624  Text
# 178 x:  1143 Y  624  Text
# 179 x:  1143 Y  624  Text
# 180 x:  1143 Y  624  Text $16.407835
# 181 x:  1388 Y  624  Text $557,160.85
# 182 x:  327 Y  702  Text
# 183 x:  327 Y  702  Text
# 184 x:  327 Y  702  Text
# 185 x:  327 Y  702  Text
# 186 x:  423 Y  708  Text
# 187 x:  423 Y  708  Text
# 188 x:  423 Y  708  Text
# 189 x:  423 Y  709  Text TRASLADO:
# 190 x:  516 Y  709  Text Base:
# 191 x:  561 Y  709  Text 539419.03
# 192 x:  641 Y  709  Text Impuesto:
# 193 x:  717 Y  709  Text 002-IVA
# 194 x:  774 Y  709  Text Tipo
# 195 x:  811 Y  709  Text de
# 196 x:  832 Y  709  Text factor:
# 197 x:  883 Y  709  Text Tasa
# 198 x:  919 Y  709  Text Tasa
# 199 x:  957 Y  712  Text o
# 200 x:  971 Y  710  Text cuota:
# 201 x:  1020 Y  709  Text 8.00%
# 202 x:  1067 Y  709  Text Importe:
# 203 x:  1131 Y  708  Text $43,153.52
# 204 x:  1221 Y  702  Text
# 205 x:  1221 Y  702  Text
# 206 x:  1221 Y  702  Text
# 207 x:  1221 Y  702  Text
# 208 x:  327 Y  702  Text
# 209 x:  327 Y  702  Text
# 210 x:  327 Y  702  Text
# 211 x:  327 Y  702  Text
# 212 x:  327 Y  731  Text
# 213 x:  327 Y  731  Text
# 214 x:  327 Y  731  Text
# 215 x:  327 Y  731  Text
# 216 x:  1248 Y  819  Text
# 217 x:  1248 Y  819  Text
# 218 x:  1248 Y  819  Text
# 219 x:  1248 Y  819  Text Subtotal
# 220 x:  1390 Y  822  Text $557,160.85
# 221 x:  78 Y  846  Text
# 222 x:  78 Y  846  Text
# 223 x:  78 Y  846  Text
# 224 x:  78 Y  847  Text Traslado
# 225 x:  676 Y  847  Text Base:
# 226 x:  727 Y  846  Text $539,419.03
# 227 x:  834 Y  847  Text Impuesto:
# 228 x:  921 Y  847  Text 002-IVA
# 229 x:  988 Y  847  Text Tipo
# 230 x:  1029 Y  847  Text de
# 231 x:  1054 Y  847  Text factor:
# 232 x:  1113 Y  847  Text Tasa
# 233 x:  1155 Y  847  Text Tasa
# 234 x:  1198 Y  850  Text o
# 235 x:  1214 Y  847  Text cuota:
# 236 x:  1271 Y  847  Text 8.00%
# 237 x:  1399 Y  846  Text $43,153.52
# 238 x:  73 Y  866  Text
# 239 x:  73 Y  866  Text
# 240 x:  73 Y  866  Text
# 241 x:  73 Y  866  Text
# 242 x:  78 Y  873  Text
# 243 x:  78 Y  873  Text
# 244 x:  78 Y  873  Text
# 245 x:  78 Y  874  Text Importe
# 246 x:  147 Y  877  Text con
# 247 x:  183 Y  874  Text letra:
# 248 x:  230 Y  874  Text SEISCIENTOS
# 249 x:  352 Y  874  Text MIL
# 250 x:  386 Y  874  Text TRESCIENTOS
# 251 x:  516 Y  874  Text CATORCE
# 252 x:  606 Y  874  Text PESOS
# 253 x:  670 Y  874  Text 37/100
# 254 x:  734 Y  874  Text MXN
# 255 x:  1278 Y  874  Text Total
# 256 x:  1390 Y  873  Text $600,314.37
# 257 x:  1252 Y  897  Text
# 258 x:  1252 Y  897  Text Moneda
# 259 x:  1448 Y  897  Text MXN
# 260 x:  1192 Y  920  Text
# 261 x:  1192 Y  920  Text Tipo
# 262 x:  1232 Y  920  Text de
# 263 x:  1257 Y  920  Text cambio
# 264 x:  1478 Y  920  Text 1
# 265 x:  75 Y  947  Text
# 266 x:  75 Y  947  Text
# 267 x:  75 Y  947  Text
# 268 x:  75 Y  947  Text
# 269 x:  76 Y  961  Text
# 270 x:  76 Y  961  Text
# 271 x:  77 Y  961  Text
# 272 x:  77 Y  961  Text Cadena
# 273 x:  135 Y  961  Text Original
# 274 x:  196 Y  961  Text del
# 275 x:  223 Y  961  Text Complemento
# 276 x:  326 Y  961  Text de
# 277 x:  349 Y  961  Text Certificación
# 278 x:  444 Y  961  Text Digital
# 279 x:  494 Y  961  Text del
# 280 x:  520 Y  961  Text SAT:
# 281 x:  560 Y  961  Text ||1.117216C2EF-8064-498A-9035-8EE0A3EA9820/2023-01-
# 282 x:  76 Y  978  Text
# 283 x:  76 Y  978  Text 24T01:11:04/SSTO60807KU0|htS+qVNLV¡GNROhmiTr3re8nEEH35cdqNfFPVhNQHn73U94qO06DIOBvqhLXR4vhZBnspYOr+uB6gOxJkKFD7mAjmbOIQGPIW7bt2Pkm5Sh7D7bhn6AYmEmpFIc1QbhbB0obAXY
# 284 x:  76 Y  996  Text
# 285 x:  76 Y  996  Text MJUXBWImoRtXrhVZcOAo+tOqCB83FX5oxiz/XqYXx7BgetzGv+QTZlowOzmMarzTH8kz4dUn1DBirHNIQojngz20hi3CwPbhr17rt/doxZKJ/3tkGBd9L
# 286 x:  1049 Y  988  Text +iuJv93/55ATO2XSd4/4167IlyoyGhKJyE5P7P7HOnonzh76J3
# 287 x:  76 Y  1013  Text
# 288 x:  76 Y  1013  Text 7ZsuRffBRgMYBynyVUionqNr1NcJT3/1YGIOsefdA==|00001000000506202789/|
# 289 x:  105 Y  1032  Text
# 290 x:  105 Y  1032  Text
# 291 x:  105 Y  1035  Text 9
# 292 x:  119 Y  1032  Text Digital
# 293 x:  171 Y  1021  Text del
# 294 x:  205 Y  1033  Text Emisor:
# 295 x:  455 Y  1048  Text
# 296 x:  455 Y  1048  Text
# 297 x:  455 Y  1048  Text
# 298 x:  455 Y  1048  Text o
# 299 x:  0 Y  9  Text
# 300 x:  0 Y  9  Text
# 301 x:  0 Y  9  Text
# 302 x:  0 Y  9  Text
# 303 x:  1639 Y  207  Text
# 304 x:  1639 Y  207  Text
# 305 x:  1639 Y  207  Text
# 306 x:  1639 Y  208  Text Crear
# 307 x:  1683 Y  207  Text archivo
# 308 x:  1737 Y  208  Text PDF
# 309 x:  1639 Y  253  Text
# 310 x:  1639 Y  254  Text Combinar
# 311 x:  1712 Y  253  Text archivos
# 312 x:  1640 Y  299  Text
# 313 x:  1640 Y  299  Text Editar
# 314 x:  1684 Y  300  Text PDF
# 315 x:  1640 Y  345  Text
# 316 x:  1640 Y  346  Text Exportar
# 317 x:  1701 Y  345  Text archivo
# 318 x:  1757 Y  346  Text PDF
# 319 x:  1639 Y  391  Text
# 320 x:  1639 Y  391  Text Organizar
# 321 x:  1713 Y  391  Text páginas
# 322 x:  1640 Y  437  Text
# 323 x:  1640 Y  437  Text Enviar
# 324 x:  1687 Y  441  Text para
# 325 x:  1721 Y  437  Text comentarios
# 326 x:  1639 Y  484  Text
# 327 x:  1639 Y  484  Text Comentar
# 328 x:  1640 Y  529  Text
# 329 x:  1640 Y  529  Text Rellenar
# 330 x:  1700 Y  519  Text y
# 331 x:  1710 Y  529  Text firmar
# 332 x:  1667 Y  575  Text
# 333 x:  1667 Y  575  Text italizar
# 334 x:  1719 Y  565  Text y
# 335 x:  1732 Y  575  Text OCR
# 336 x:  1640 Y  622  Text
# 337 x:  1640 Y  622  Text Proteger
# 338 x:  1639 Y  667  Text
# 339 x:  1639 Y  667  Text
# 340 x:  1639 Y  667  Text
# 341 x:  1639 Y  667  Text JavaScript
# 342 x:  1609 Y  709  Text
# 343 x:  1609 Y  709  Text
# 344 x:  1609 Y  709  Text
# 345 x:  1609 Y  709  Text [E]
# 346 x:  1639 Y  713  Text Asistente
# 347 x:  1706 Y  713  Text de
# 348 x:  1727 Y  713  Text acciones
# 349 x:  1607 Y  754  Text
# 350 x:  1607 Y  754  Text
# 351 x:  1607 Y  754  Text
# 352 x:  1607 Y  754  Text OS
# 353 x:  1611 Y  968  Text
# 354 x:  1611 Y  968  Text
# 355 x:  1611 Y  968  Text
# 356 x:  1611 Y  968  Text Almacene
# 357 x:  1676 Y  971  Text y
# 358 x:  1688 Y  969  Text comparta
# 359 x:  1750 Y  968  Text archivos
# 360 x:  1807 Y  971  Text en
# 361 x:  1826 Y  968  Text Document
# 362 x:  1731 Y  983  Text
# 363 x:  1731 Y  983  Text Cloud
# 364 x:  1706 Y  1008  Text
# 365 x:  1706 Y  1008  Text
# 366 x:  1706 Y  1008  Text
# 367 x:  1706 Y  1008  Text Más
# 368 x:  1731 Y  1008  Text información
# 1 x:  0 Y  0  Text
# 2 x:  0 Y  10  Text
# 3 x:  0 Y  10  Text
# 4 x:  0 Y  10  Text
# 5 x:  0 Y  10  Text
# 6 x:  7 Y  28  Text
# 7 x:  7 Y  28  Text
# 8 x:  7 Y  28  Text
# 9 x:  7 Y  28  Text Archivo
# 10 x:  30 Y  7  Text
# 11 x:  30 Y  7  Text
# 12 x:  30 Y  7  Text
# 13 x:  30 Y  7  Text sECFD_20230124,010802.pdf
# 14 x:  176 Y  0  Text -
# 15 x:  183 Y  7  Text Adobe
# 16 x:  221 Y  7  Text Acrobat
# 17 x:  267 Y  7  Text Pro
# 18 x:  288 Y  7  Text DC
# 19 x:  63 Y  28  Text
# 20 x:  63 Y  28  Text
# 21 x:  63 Y  28  Text
# 22 x:  63 Y  28  Text Edición
# 23 x:  115 Y  28  Text Ver
# 24 x:  145 Y  28  Text Ventana
# 25 x:  201 Y  28  Text Ayuda
# 26 x:  300 Y  218  Text
# 27 x:  300 Y  218  Text
# 28 x:  300 Y  218  Text
# 29 x:  300 Y  218  Text VALERO
# 30 x:  410 Y  218  Text MARKETING
# 31 x:  566 Y  218  Text AND
# 32 x:  628 Y  218  Text SUPPLY
# 33 x:  733 Y  218  Text DE
# 34 x:  774 Y  218  Text MEXICO
# 35 x:  301 Y  281  Text
# 36 x:  301 Y  281  Text
# 37 x:  301 Y  281  Text
# 38 x:  301 Y  281  Text RFC:
# 39 x:  339 Y  281  Text VMS16042911A
# 40 x:  301 Y  302  Text
# 41 x:  301 Y  302  Text Régimen
# 42 x:  365 Y  302  Text Fiscal:
# 43 x:  412 Y  302  Text 601-General
# 44 x:  499 Y  302  Text de
# 45 x:  520 Y  302  Text Ley
# 46 x:  548 Y  302  Text Personas
# 47 x:  616 Y  302  Text Morales
# 48 x:  301 Y  322  Text
# 49 x:  301 Y  322  Text Lugar,
# 50 x:  345 Y  322  Text fecha
# 51 x:  386 Y  325  Text y
# 52 x:  399 Y  322  Text hora
# 53 x:  432 Y  322  Text de
# 54 x:  453 Y  322  Text expedición:
# 55 x:  533 Y  322  Text 88000
# 56 x:  578 Y  322  Text 24/01/2023
# 57 x:  662 Y  322  Text 01:08:02
# 58 x:  82 Y  369  Text
# 59 x:  82 Y  369  Text
# 60 x:  82 Y  369  Text
# 61 x:  82 Y  369  Text CLIENTE
# 62 x:  90 Y  417  Text
# 63 x:  90 Y  417  Text
# 64 x:  90 Y  417  Text
# 65 x:  90 Y  417  Text PETROLIFEROS
# 66 x:  210 Y  417  Text LOBO
# 67 x:  90 Y  438  Text
# 68 x:  90 Y  438  Text
# 69 x:  90 Y  438  Text RFC:
# 70 x:  129 Y  438  Text PLO170306G79
# 71 x:  90 Y  458  Text
# 72 x:  90 Y  458  Text
# 73 x:  90 Y  458  Text Régimen
# 74 x:  155 Y  458  Text Fiscal:
# 75 x:  201 Y  458  Text 601-General
# 76 x:  288 Y  458  Text de
# 77 x:  310 Y  458  Text Ley
# 78 x:  338 Y  458  Text Personas
# 79 x:  405 Y  458  Text Morales
# 80 x:  90 Y  479  Text
# 81 x:  90 Y  479  Text Domicilio
# 82 x:  156 Y  479  Text Fiscal:
# 83 x:  202 Y  479  Text 64650
# 84 x:  90 Y  499  Text
# 85 x:  90 Y  499  Text
# 86 x:  90 Y  499  Text Uso
# 87 x:  121 Y  499  Text CFDI:
# 88 x:  164 Y  499  Text GO1-Adquisición
# 89 x:  278 Y  499  Text de
# 90 x:  299 Y  499  Text mercancías.
# 91 x:  79 Y  533  Text
# 92 x:  79 Y  533  Text
# 93 x:  79 Y  533  Text
# 94 x:  79 Y  533  Text PRODUCTOS
# 95 x:  243 Y  533  Text /
# 96 x:  258 Y  533  Text SERVICIOS
# 97 x:  328 Y  565  Text
# 98 x:  328 Y  565  Text
# 99 x:  328 Y  565  Text
# 100 x:  328 Y  576  Text Clave
# 101 x:  380 Y  576  Text Prod
# 102 x:  503 Y  586  Text crioció
# 103 x:  811 Y  565  Text Objeto
# 104 x:  921 Y  576  Text Clave
# 105 x:  342 Y  585  Text
# 106 x:  342 Y  585  Text Servicio
# 107 x:  466 Y  589  Text escripción
# 108 x:  824 Y  595  Text Imp
# 109 x:  916 Y  595  Text unidad
# 110 x:  110 Y  625  Text
# 111 x:  110 Y  625  Text
# 112 x:  110 Y  625  Text
# 113 x:  110 Y  625  Text 33957.000
# 114 x:  200 Y  625  Text 87CON11.5.
# 115 x:  335 Y  625  Text  15101514-
# 116 x:  454 Y  625  Text 87
# 117 x:  478 Y  625  Text Oct
# 118 x:  510 Y  625  Text Convencional
# 119 x:  622 Y  625  Text 11.5
# 120 x:  659 Y  625  Text RVP
# 121 x:  698 Y  632  Text -
# 122 x:  710 Y  625  Text H/20054/
# 123 x:  794 Y  615  Text —
# 124 x:  818 Y  625  Text 02-Sí
# 125 x:  909 Y  625  Text STL-Litro
# 126 x:  1038 Y  625  Text 120
# 127 x:  236 Y  639  Text
# 128 x:  236 Y  639  Text ma
# 129 x:  312 Y  644  Text Gasolina
# 130 x:  386 Y  644  Text regular
# 131 x:  454 Y  644  Text COM/2017
# 132 x:  803 Y  644  Text objeto
# 133 x:  855 Y  644  Text de
# 134 x:  911 Y  644  Text estándar
# 135 x:  332 Y  664  Text
# 136 x:  332 Y  667  Text menor
# 137 x:  386 Y  667  Text a
# 138 x:  400 Y  664  Text 91
# 139 x:  801 Y  664  Text impuesto.
# 140 x:  345 Y  683  Text
# 141 x:  345 Y  683  Text octanos
# 142 x:  967 Y  417  Text
# 143 x:  967 Y  417  Text
# 144 x:  967 Y  417  Text
# 145 x:  967 Y  417  Text Lugar
# 146 x:  1009 Y  417  Text de
# 147 x:  1030 Y  420  Text carga:
# 148 x:  1076 Y  417  Text Nuevo
# 149 x:  1124 Y  417  Text Laredo,
# 150 x:  1177 Y  417  Text TMS,
# 151 x:  1218 Y  417  Text MX
# 152 x:  967 Y  438  Text
# 153 x:  967 Y  438  Text Destino:
# 154 x:  1026 Y  438  Text 6002070
# 155 x:  1088 Y  445  Text -
# 156 x:  1098 Y  438  Text PETROLIFEROS
# 157 x:  1218 Y  438  Text LOBO-UNB-MX
# 158 x:  1329 Y  428  Text MEX
# 159 x:  968 Y  458  Text
# 160 x:  968 Y  458  Text Fecha
# 161 x:  1013 Y  458  Text BOL:
# 162 x:  1051 Y  458  Text 23/01/2023
# 163 x:  967 Y  479  Text
# 164 x:  967 Y  479  Text Número
# 165 x:  1024 Y  479  Text de
# 166 x:  1045 Y  479  Text BOL:
# 167 x:  1083 Y  479  Text 84036
# 168 x:  78 Y  586  Text
# 169 x:  78 Y  586  Text
# 170 x:  78 Y  586  Text
# 171 x:  78 Y  586  Text Cantidad
# 172 x:  199 Y  586  Text Clave
# 173 x:  1024 Y  586  Text Unidad
# 174 x:  1114 Y  586  Text Valor
# 175 x:  1162 Y  586  Text Unitario
# 176 x:  1421 Y  586  Text Importe
# 177 x:  1143 Y  624  Text
# 178 x:  1143 Y  624  Text
# 179 x:  1143 Y  624  Text
# 180 x:  1143 Y  624  Text $16.407835
# 181 x:  1388 Y  624  Text $557,160.85
# 182 x:  327 Y  702  Text
# 183 x:  327 Y  702  Text
# 184 x:  327 Y  702  Text
# 185 x:  327 Y  702  Text
# 186 x:  423 Y  708  Text
# 187 x:  423 Y  708  Text
# 188 x:  423 Y  708  Text
# 189 x:  423 Y  709  Text TRASLADO:
# 190 x:  516 Y  709  Text Base:
# 191 x:  561 Y  709  Text 539419.03
# 192 x:  641 Y  709  Text Impuesto:
# 193 x:  717 Y  709  Text 002-IVA
# 194 x:  774 Y  709  Text Tipo
# 195 x:  811 Y  709  Text de
# 196 x:  832 Y  709  Text factor:
# 197 x:  883 Y  709  Text Tasa
# 198 x:  919 Y  709  Text Tasa
# 199 x:  957 Y  712  Text o
# 200 x:  971 Y  710  Text cuota:
# 201 x:  1020 Y  709  Text 8.00%
# 202 x:  1067 Y  709  Text Importe:
# 203 x:  1131 Y  708  Text $43,153.52
# 204 x:  1221 Y  702  Text
# 205 x:  1221 Y  702  Text
# 206 x:  1221 Y  702  Text
# 207 x:  1221 Y  702  Text
# 208 x:  327 Y  702  Text
# 209 x:  327 Y  702  Text
# 210 x:  327 Y  702  Text
# 211 x:  327 Y  702  Text
# 212 x:  327 Y  731  Text
# 213 x:  327 Y  731  Text
# 214 x:  327 Y  731  Text
# 215 x:  327 Y  731  Text
# 216 x:  1248 Y  819  Text
# 217 x:  1248 Y  819  Text
# 218 x:  1248 Y  819  Text
# 219 x:  1248 Y  819  Text Subtotal
# 220 x:  1390 Y  822  Text $557,160.85
# 221 x:  78 Y  846  Text
# 222 x:  78 Y  846  Text
# 223 x:  78 Y  846  Text
# 224 x:  78 Y  847  Text Traslado
# 225 x:  676 Y  847  Text Base:
# 226 x:  727 Y  846  Text $539,419.03
# 227 x:  834 Y  847  Text Impuesto:
# 228 x:  921 Y  847  Text 002-IVA
# 229 x:  988 Y  847  Text Tipo
# 230 x:  1029 Y  847  Text de
# 231 x:  1054 Y  847  Text factor:
# 232 x:  1113 Y  847  Text Tasa
# 233 x:  1155 Y  847  Text Tasa
# 234 x:  1198 Y  850  Text o
# 235 x:  1214 Y  847  Text cuota:
# 236 x:  1271 Y  847  Text 8.00%
# 237 x:  1399 Y  846  Text $43,153.52
# 238 x:  73 Y  866  Text
# 239 x:  73 Y  866  Text
# 240 x:  73 Y  866  Text
# 241 x:  73 Y  866  Text
# 242 x:  78 Y  873  Text
# 243 x:  78 Y  873  Text
# 244 x:  78 Y  873  Text
# 245 x:  78 Y  874  Text Importe
# 246 x:  147 Y  877  Text con
# 247 x:  183 Y  874  Text letra:
# 248 x:  230 Y  874  Text SEISCIENTOS
# 249 x:  352 Y  874  Text MIL
# 250 x:  386 Y  874  Text TRESCIENTOS
# 251 x:  516 Y  874  Text CATORCE
# 252 x:  606 Y  874  Text PESOS
# 253 x:  670 Y  874  Text 37/100
# 254 x:  734 Y  874  Text MXN
# 255 x:  1278 Y  874  Text Total
# 256 x:  1390 Y  873  Text $600,314.37
# 257 x:  1252 Y  897  Text
# 258 x:  1252 Y  897  Text Moneda
# 259 x:  1448 Y  897  Text MXN
# 260 x:  1192 Y  920  Text
# 261 x:  1192 Y  920  Text Tipo
# 262 x:  1232 Y  920  Text de
# 263 x:  1257 Y  920  Text cambio
# 264 x:  1478 Y  920  Text 1
# 265 x:  75 Y  947  Text
# 266 x:  75 Y  947  Text
# 267 x:  75 Y  947  Text
# 268 x:  75 Y  947  Text
# 269 x:  76 Y  961  Text
# 270 x:  76 Y  961  Text
# 271 x:  77 Y  961  Text
# 272 x:  77 Y  961  Text Cadena
# 273 x:  135 Y  961  Text Original
# 274 x:  196 Y  961  Text del
# 275 x:  223 Y  961  Text Complemento
# 276 x:  326 Y  961  Text de
# 277 x:  349 Y  961  Text Certificación
# 278 x:  444 Y  961  Text Digital
# 279 x:  494 Y  961  Text del
# 280 x:  520 Y  961  Text SAT:
# 281 x:  560 Y  961  Text ||1.117216C2EF-8064-498A-9035-8EE0A3EA9820/2023-01-
# 282 x:  76 Y  978  Text
# 283 x:  76 Y  978  Text 24T01:11:04/SSTO60807KU0|htS+qVNLV¡GNROhmiTr3re8nEEH35cdqNfFPVhNQHn73U94qO06DIOBvqhLXR4vhZBnspYOr+uB6gOxJkKFD7mAjmbOIQGPIW7bt2Pkm5Sh7D7bhn6AYmEmpFIc1QbhbB0obAXY
# 284 x:  76 Y  996  Text
# 285 x:  76 Y  996  Text MJUXBWImoRtXrhVZcOAo+tOqCB83FX5oxiz/XqYXx7BgetzGv+QTZlowOzmMarzTH8kz4dUn1DBirHNIQojngz20hi3CwPbhr17rt/doxZKJ/3tkGBd9L
# 286 x:  1049 Y  988  Text +iuJv93/55ATO2XSd4/4167IlyoyGhKJyE5P7P7HOnonzh76J3
# 287 x:  76 Y  1013  Text
# 288 x:  76 Y  1013  Text 7ZsuRffBRgMYBynyVUionqNr1NcJT3/1YGIOsefdA==|00001000000506202789/|
# 289 x:  105 Y  1032  Text
# 290 x:  105 Y  1032  Text
# 291 x:  105 Y  1035  Text 9
# 292 x:  119 Y  1032  Text Digital
# 293 x:  171 Y  1021  Text del
# 294 x:  205 Y  1033  Text Emisor:
# 295 x:  455 Y  1048  Text
# 296 x:  455 Y  1048  Text
# 297 x:  455 Y  1048  Text
# 298 x:  455 Y  1048  Text o
# 299 x:  0 Y  9  Text
# 300 x:  0 Y  9  Text
# 301 x:  0 Y  9  Text
# 302 x:  0 Y  9  Text
# 303 x:  1639 Y  207  Text
# 304 x:  1639 Y  207  Text
# 305 x:  1639 Y  207  Text
# 306 x:  1639 Y  208  Text Crear
# 307 x:  1683 Y  207  Text archivo
# 308 x:  1737 Y  208  Text PDF
# 309 x:  1639 Y  253  Text
# 310 x:  1639 Y  254  Text Combinar
# 311 x:  1712 Y  253  Text archivos
# 312 x:  1640 Y  299  Text
# 313 x:  1640 Y  299  Text Editar
# 314 x:  1684 Y  300  Text PDF
# 315 x:  1640 Y  345  Text
# 316 x:  1640 Y  346  Text Exportar
# 317 x:  1701 Y  345  Text archivo
# 318 x:  1757 Y  346  Text PDF
# 319 x:  1639 Y  391  Text
# 320 x:  1639 Y  391  Text Organizar
# 321 x:  1713 Y  391  Text páginas
# 322 x:  1640 Y  437  Text
# 323 x:  1640 Y  437  Text Enviar
# 324 x:  1687 Y  441  Text para
# 325 x:  1721 Y  437  Text comentarios
# 326 x:  1639 Y  484  Text
# 327 x:  1639 Y  484  Text Comentar
# 328 x:  1640 Y  529  Text
# 329 x:  1640 Y  529  Text Rellenar
# 330 x:  1700 Y  519  Text y
# 331 x:  1710 Y  529  Text firmar
# 332 x:  1667 Y  575  Text
# 333 x:  1667 Y  575  Text italizar
# 334 x:  1719 Y  565  Text y
# 335 x:  1732 Y  575  Text OCR
# 336 x:  1640 Y  622  Text
# 337 x:  1640 Y  622  Text Proteger
# 338 x:  1639 Y  667  Text
# 339 x:  1639 Y  667  Text
# 340 x:  1639 Y  667  Text
# 341 x:  1639 Y  667  Text JavaScript
# 342 x:  1609 Y  709  Text
# 343 x:  1609 Y  709  Text
# 344 x:  1609 Y  709  Text
# 345 x:  1609 Y  709  Text [E]
# 346 x:  1639 Y  713  Text Asistente
# 347 x:  1706 Y  713  Text de
# 348 x:  1727 Y  713  Text acciones
# 349 x:  1607 Y  754  Text
# 350 x:  1607 Y  754  Text
# 351 x:  1607 Y  754  Text
# 352 x:  1607 Y  754  Text OS
# 353 x:  1611 Y  968  Text
# 354 x:  1611 Y  968  Text
# 355 x:  1611 Y  968  Text
# 356 x:  1611 Y  968  Text Almacene
# 357 x:  1676 Y  971  Text y
# 358 x:  1688 Y  969  Text comparta
# 359 x:  1750 Y  968  Text archivos
# 360 x:  1807 Y  971  Text en
# 361 x:  1826 Y  968  Text Document
# 362 x:  1731 Y  983  Text
# 363 x:  1731 Y  983  Text Cloud
# 364 x:  1706 Y  1008  Text
# 365 x:  1706 Y  1008  Text
# 366 x:  1706 Y  1008  Text
# 367 x:  1706 Y  1008  Text Más
# 368 x:  1731 Y  1008  Text información
# 1 x:  0 Y  0  Text
# 2 x:  0 Y  0  Text
# 3 x:  0 Y  0  Text
# 4 x:  0 Y  0  Text
# 5 x:  0 Y  0  Text
# 6 x:  0 Y  40  Text
# 7 x:  0 Y  40  Text
# 8 x:  0 Y  40  Text
# 9 x:  0 Y  40  Text
# 10 x:  0 Y  42  Text
# 11 x:  0 Y  42  Text
# 12 x:  0 Y  42  Text
# 13 x:  0 Y  42  Text
# 14 x:  68 Y  83  Text
# 15 x:  68 Y  83  Text
# 16 x:  68 Y  83  Text
# 17 x:  68 Y  93  Text
# 18 x:  141 Y  83  Text
# 19 x:  54 Y  150  Text
# 20 x:  54 Y  150  Text
# 21 x:  54 Y  150  Text
# 22 x:  54 Y  150  Text
# 23 x:  51 Y  368  Text
# 24 x:  51 Y  368  Text
# 25 x:  51 Y  368  Text
# 26 x:  51 Y  368  Text
# 27 x:  237 Y  86  Text
# 28 x:  237 Y  86  Text
# 29 x:  237 Y  86  Text
# 30 x:  237 Y  86  Text
# 31 x:  448 Y  42  Text
# 32 x:  448 Y  42  Text
# 33 x:  448 Y  42  Text
# 34 x:  448 Y  42  Text
# 35 x:  0 Y  720  Text
# 36 x:  0 Y  720  Text
# 37 x:  0 Y  720  Text
# 38 x:  0 Y  720  Text
# 39 x:  7 Y  28  Text
# 40 x:  7 Y  28  Text
# 41 x:  7 Y  28  Text
# 42 x:  7 Y  28  Text Archivo
# 43 x:  63 Y  28  Text Edición
# 44 x:  115 Y  28  Text Ver
# 45 x:  145 Y  28  Text Ventana
# 46 x:  201 Y  28  Text Ayuda
# 47 x:  28 Y  55  Text
# 48 x:  28 Y  55  Text 5
# 49 x:  58 Y  59  Text Abrir.
# 50 x:  391 Y  59  Text Ctri+O
# 51 x:  75 Y  87  Text
# 52 x:  75 Y  87  Text Iver
# 53 x:  99 Y  76  Text a
# 54 x:  112 Y  87  Text abrir
# 55 x:  145 Y  76  Text PDF
# 56 x:  174 Y  90  Text de
# 57 x:  192 Y  87  Text la
# 58 x:  206 Y  87  Text últim
# 59 x:  28 Y  109  Text
# 60 x:  28 Y  109  Text E
# 61 x:  59 Y  115  Text Gear
# 62 x:  414 Y  116  Text »
# 63 x:  404 Y  154  Text
# 64 x:  404 Y  154  Text ri+S
# 65 x:  59 Y  182  Text
# 66 x:  59 Y  182  Text Guardar
# 67 x:  113 Y  185  Text como.
# 68 x:  358 Y  182  Text Shift+Ctrl+S
# 69 x:  59 Y  210  Text
# 70 x:  59 Y  210  Text Guardar
# 71 x:  113 Y  213  Text como
# 72 x:  151 Y  211  Text otro
# 73 x:  414 Y  211  Text »
# 74 x:  30 Y  232  Text
# 75 x:  30 Y  232  Text “E,
# 76 x:  59 Y  238  Text Reducir
# 77 x:  108 Y  238  Text el
# 78 x:  121 Y  238  Text tamaño
# 79 x:  173 Y  238  Text del
# 80 x:  195 Y  238  Text archivo
# 81 x:  59 Y  266  Text
# 82 x:  59 Y  266  Text Exportar
# 83 x:  114 Y  269  Text a
# 84 x:  414 Y  267  Text »
# 85 x:  58 Y  294  Text
# 86 x:  58 Y  294  Text Proteger
# 87 x:  116 Y  297  Text con
# 88 x:  142 Y  294  Text contraseña
# 89 x:  29 Y  327  Text
# 90 x:  29 Y  327  Text [4]
# 91 x:  60 Y  323  Text Compartir
# 92 x:  125 Y  333  Text archivo
# 93 x:  58 Y  400  Text
# 94 x:  58 Y  400  Text Cerrar
# 95 x:  101 Y  400  Text archivo
# 96 x:  389 Y  400  Text Ctri+W
# 97 x:  58 Y  439  Text
# 98 x:  58 Y  439  Text Propiedades
# 99 x:  392 Y  439  Text Ctri+D
# 100 x:  28 Y  472  Text
# 101 x:  28 Y  472  Text E)
# 102 x:  59 Y  478  Text Imprimir.
# 103 x:  394 Y  478  Text Ctri+P
# 104 x:  58 Y  517  Text
# 105 x:  58 Y  517  Text 1
# 106 x:  71 Y  517  Text EX52811WDescargasiSECFD_20230124_010802.pdf
# 107 x:  58 Y  545  Text
# 108 x:  58 Y  545  Text 2
# 109 x:  71 Y  545  Text EN52811WDescargasiSECFD_20230213_105632.pdf
# 110 x:  58 Y  573  Text
# 111 x:  58 Y  573  Text 3
# 112 x:  71 Y  573  Text EN528111..ASECFD_20230213_105632-2.pdf
# 113 x:  58 Y  601  Text
# 114 x:  58 Y  601  Text 4
# 115 x:  71 Y  601  Text EN52811WDescargasiDODA
# 116 x:  243 Y  601  Text 10742.pdf
# 117 x:  58 Y  629  Text
# 118 x:  58 Y  629  Text 5
# 119 x:  71 Y  629  Text EN52811WDescargas¡DODA
# 120 x:  242 Y  629  Text 823558.pdf
# 121 x:  58 Y  657  Text
# 122 x:  58 Y  657  Text Ver
# 123 x:  82 Y  647  Text todos
# 124 x:  122 Y  657  Text los
# 125 x:  143 Y  657  Text archivos
# 126 x:  197 Y  658  Text recientes.
# 127 x:  453 Y  657  Text 7
# 128 x:  58 Y  696  Text
# 129 x:  58 Y  696  Text Salir
# 130 x:  88 Y  696  Text de
# 131 x:  107 Y  696  Text la
# 132 x:  121 Y  696  Text aplicación
# 133 x:  391 Y  696  Text Ctri+Q
# 134 x:  422 Y  740  Text
# 135 x:  422 Y  740  Text RASLADO.
# 136 x:  99 Y  899  Text
# 137 x:  99 Y  902  Text porte
# 138 x:  155 Y  902  Text con
# 139 x:  185 Y  902  Text le
# 140 x:  316 Y  899  Text O
# 141 x:  389 Y  899  Text R
# 142 x:  474 Y  899  Text O
# 143 x:  95 Y  984  Text
# 144 x:  95 Y  987  Text dena
# 145 x:  134 Y  984  Text Original
# 146 x:  193 Y  987  Text del
# 147 x:  229 Y  987  Text Comp!
# 148 x:  319 Y  987  Text d
# 149 x:  411 Y  987  Text ón
# 150 x:  433 Y  984  Text Digital
# 151 x:  482 Y  987  Text d
# 152 x:  12 Y  1048  Text
# 153 x:  12 Y  1048  Text
# 154 x:  12 Y  1048  Text
# 155 x:  12 Y  1048  Text
# 156 x:  101 Y  1000  Text
# 157 x:  101 Y  1000  Text
# 158 x:  101 Y  1000  Text
# 159 x:  101 Y  1000  Text
# 160 x:  60 Y  1052  Text
# 161 x:  60 Y  1052  Text
# 162 x:  60 Y  1052  Text
# 163 x:  60 Y  1052  Text /
# 164 x:  90 Y  1055  Text Escribe
# 165 x:  140 Y  1055  Text aquí
# 166 x:  173 Y  1058  Text para
# 167 x:  207 Y  1055  Text buscar.
# 168 x:  378 Y  1019  Text
# 169 x:  378 Y  1019  Text
# 170 x:  378 Y  1019  Text
# 171 x:  378 Y  1019  Text
# 172 x:  454 Y  57  Text
# 173 x:  454 Y  57  Text
# 174 x:  454 Y  57  Text
# 175 x:  454 Y  57  Text D_20230124_..
# 176 x:  558 Y  58  Text Xx
# 177 x:  515 Y  360  Text
# 178 x:  515 Y  360  Text
# 179 x:  515 Y  360  Text
# 180 x:  515 Y  360  Text
# 181 x:  599 Y  1045  Text
# 182 x:  599 Y  1045  Text
# 183 x:  599 Y  1045  Text
# 184 x:  599 Y  1045  Text
# 185 x:  849 Y  141  Text
# 186 x:  849 Y  141  Text
# 187 x:  849 Y  141  Text
# 188 x:  849 Y  141  Text
# 189 x:  809 Y  141  Text
# 190 x:  809 Y  141  Text
# 191 x:  809 Y  141  Text
# 192 x:  809 Y  141  Text H
# 193 x:  868 Y  142  Text
# 194 x:  868 Y  142  Text
# 195 x:  868 Y  142  Text
# 196 x:  868 Y  142  Text
# 197 x:  850 Y  142  Text
# 198 x:  850 Y  142  Text
# 199 x:  850 Y  142  Text
# 200 x:  850 Y  142  Text
# 201 x:  849 Y  156  Text
# 202 x:  849 Y  156  Text
# 203 x:  849 Y  156  Text
# 204 x:  849 Y  156  Text
# 205 x:  447 Y  1077  Text
# 206 x:  447 Y  1077  Text
# 207 x:  447 Y  1077  Text
# 208 x:  447 Y  1077  Text
# 209 x:  928 Y  445  Text
# 210 x:  928 Y  445  Text
# 211 x:  928 Y  445  Text
# 212 x:  928 Y  445  Text
# 213 x:  891 Y  868  Text
# 214 x:  891 Y  868  Text
# 215 x:  891 Y  868  Text
# 216 x:  891 Y  868  Text
# 217 x:  1106 Y  141  Text
# 218 x:  1106 Y  141  Text
# 219 x:  1106 Y  141  Text
# 220 x:  1106 Y  141  Text
# 221 x:  1106 Y  142  Text
# 222 x:  1106 Y  142  Text
# 223 x:  1106 Y  142  Text
# 224 x:  1106 Y  142  Text
# 225 x:  1107 Y  142  Text
# 226 x:  1107 Y  142  Text
# 227 x:  1107 Y  142  Text
# 228 x:  1107 Y  142  Text
# 229 x:  1124 Y  142  Text
# 230 x:  1124 Y  142  Text
# 231 x:  1124 Y  142  Text
# 232 x:  1124 Y  142  Text
# 233 x:  1106 Y  156  Text
# 234 x:  1106 Y  156  Text
# 235 x:  1106 Y  156  Text
# 236 x:  1106 Y  156  Text
# 237 x:  1175 Y  217  Text
# 238 x:  1175 Y  217  Text
# 239 x:  1175 Y  217  Text
# 240 x:  1175 Y  217  Text FACTURA
# 241 x:  1296 Y  217  Text 3644645441
# 242 x:  938 Y  455  Text
# 243 x:  938 Y  455  Text
# 244 x:  938 Y  455  Text
# 245 x:  938 Y  455  Text Lugar
# 246 x:  980 Y  445  Text de
# 247 x:  999 Y  458  Text carga:
# 248 x:  1044 Y  455  Text Nuevo
# 249 x:  1090 Y  455  Text Laredo,
# 250 x:  1142 Y  455  Text TMS,
# 251 x:  1181 Y  455  Text MX
# 252 x:  1181 Y  475  Text
# 253 x:  1181 Y  475  Text LOBO-UNB-MX
# 254 x:  1290 Y  465  Text MEX!
# 255 x:  938 Y  475  Text
# 256 x:  938 Y  475  Text
# 257 x:  938 Y  475  Text
# 258 x:  938 Y  475  Text Destino:
# 259 x:  995 Y  475  Text 6002070
# 260 x:  1055 Y  482  Text -
# 261 x:  1065 Y  475  Text PETROLIFER(
# 262 x:  939 Y  495  Text
# 263 x:  939 Y  495  Text Fecha
# 264 x:  983 Y  495  Text BOL:
# 265 x:  1019 Y  495  Text 23/01/202
# 266 x:  938 Y  515  Text
# 267 x:  938 Y  515  Text Número
# 268 x:  993 Y  515  Text de
# 269 x:  1014 Y  515  Text BOL:
# 270 x:  1051 Y  515  Text 8402
# 271 x:  1007 Y  735  Text
# 272 x:  1007 Y  735  Text
# 273 x:  1007 Y  735  Text
# 274 x:  1007 Y  735  Text
# 275 x:  1267 Y  924  Text
# 276 x:  1267 Y  924  Text
# 277 x:  1267 Y  924  Text
# 278 x:  1267 Y  924  Text
# 279 x:  1193 Y  943  Text
# 280 x:  1193 Y  943  Text
# 281 x:  1193 Y  943  Text
# 282 x:  1193 Y  943  Text
# 283 x:  1698 Y  50  Text
# 284 x:  1698 Y  50  Text
# 285 x:  1698 Y  50  Text
# 286 x:  1698 Y  50  Text (0)
# 287 x:  1549 Y  197  Text
# 288 x:  1549 Y  197  Text
# 289 x:  1549 Y  197  Text
# 290 x:  1549 Y  197  Text FORMATO
# 291 x:  1554 Y  219  Text
# 292 x:  1554 Y  219  Text
# 293 x:  1554 Y  219  Text
# 294 x:  1554 Y  219  Text Arial
# 295 x:  1714 Y  232  Text >
# 296 x:  1548 Y  332  Text
# 297 x:  1548 Y  332  Text
# 298 x:  1548 Y  332  Text
# 299 x:  1548 Y  332  Text
# 300 x:  1613 Y  333  Text
# 301 x:  1613 Y  333  Text
# 302 x:  1613 Y  333  Text
# 303 x:  1613 Y  333  Text
# 304 x:  1624 Y  333  Text
# 305 x:  1624 Y  333  Text
# 306 x:  1624 Y  333  Text
# 307 x:  1624 Y  333  Text
# 308 x:  1665 Y  333  Text
# 309 x:  1665 Y  333  Text
# 310 x:  1665 Y  333  Text
# 311 x:  1665 Y  333  Text
# 312 x:  1689 Y  333  Text
# 313 x:  1689 Y  333  Text
# 314 x:  1689 Y  333  Text
# 315 x:  1689 Y  333  Text
# 316 x:  1548 Y  333  Text
# 317 x:  1548 Y  333  Text
# 318 x:  1548 Y  333  Text
# 319 x:  1548 Y  333  Text
# 320 x:  1589 Y  333  Text
# 321 x:  1589 Y  333  Text
# 322 x:  1589 Y  333  Text
# 323 x:  1589 Y  333  Text
# 324 x:  1548 Y  361  Text
# 325 x:  1548 Y  361  Text
# 326 x:  1548 Y  361  Text
# 327 x:  1548 Y  361  Text
# 328 x:  1545 Y  260  Text
# 329 x:  1545 Y  260  Text
# 330 x:  1545 Y  260  Text
# 331 x:  1545 Y  260  Text
# 332 x:  1548 Y  513  Text
# 333 x:  1548 Y  513  Text
# 334 x:  1548 Y  513  Text
# 335 x:  1548 Y  513  Text OBJETOS
# 336 x:  1549 Y  663  Text
# 337 x:  1549 Y  663  Text
# 338 x:  1549 Y  663  Text
# 339 x:  1549 Y  663  Text DOCUMENTOS
# 340 x:  1635 Y  663  Text DIGITALIZADOS
# 341 x:  1550 Y  686  Text
# 342 x:  1550 Y  686  Text XX
# 343 x:  1577 Y  691  Text Configuración
# 344 x:  1576 Y  774  Text
# 345 x:  1548 Y  770  Text
# 346 x:  1576 Y  774  Text
# 347 x:  1576 Y  774  Text Mostrar
# 348 x:  1629 Y  774  Text cuadros
# 349 x:  1681 Y  774  Text delimitadores
# 350 x:  1548 Y  799  Text
# 351 x:  1548 Y  799  Text
# 352 x:  1548 Y  799  Text
# 353 x:  1548 Y  799  Text
# 354 x:  1548 Y  799  Text
# 355 x:  1548 Y  799  Text
# 356 x:  1548 Y  799  Text
# 357 x:  1548 Y  799  Text
# 358 x:  1564 Y  799  Text
# 359 x:  1564 Y  799  Text
# 360 x:  1564 Y  799  Text
# 361 x:  1564 Y  799  Text
# 362 x:  1576 Y  803  Text
# 363 x:  1576 Y  803  Text
# 364 x:  1576 Y  803  Text
# 365 x:  1576 Y  803  Text Restringir
# 366 x:  1638 Y  803  Text la
# 367 x:  1652 Y  803  Text edición
# 368 x:  1548 Y  815  Text
# 369 x:  1548 Y  815  Text
# 370 x:  1548 Y  815  Text
# 371 x:  1548 Y  815  Text
# 372 x:  1647 Y  1052  Text
# 373 x:  1647 Y  1052  Text
# 374 x:  1647 Y  1052  Text
# 375 x:  1647 Y  1052  Text 108
# 376 x:  1717 Y  1054  Text mw
# 377 x:  1792 Y  55  Text
# 378 x:  1792 Y  55  Text
# 379 x:  1792 Y  55  Text
# 380 x:  1792 Y  55  Text Iniciar
# 381 x:  1845 Y  55  Text sesión
# 382 x:  1770 Y  1055  Text
# 383 x:  1770 Y  1055  Text
# 384 x:  1770 Y  1055  Text
# 385 x:  1770 Y  1055  Text ESP
# 386 x:  1789 Y  88  Text
# 387 x:  1789 Y  88  Text
# 388 x:  1789 Y  88  Text
# 389 x:  1789 Y  88  Text
# 390 x:  1838 Y  93  Text
# 391 x:  1838 Y  93  Text
# 392 x:  1838 Y  93  Text
# 393 x:  1838 Y  93  Text
# 394 x:  1858 Y  94  Text
# 395 x:  1858 Y  94  Text
# 396 x:  1858 Y  94  Text
# 397 x:  1858 Y  94  Text
# 398 x:  1839 Y  94  Text
# 399 x:  1839 Y  94  Text
# 400 x:  1839 Y  94  Text
# 401 x:  1839 Y  94  Text
# 402 x:  1838 Y  108  Text
# 403 x:  1838 Y  108  Text
# 404 x:  1838 Y  108  Text
# 405 x:  1838 Y  108  Text
# 406 x:  1882 Y  549  Text
# 407 x:  1882 Y  549  Text
# 408 x:  1882 Y  549  Text
# 409 x:  1882 Y  549  Text
# 410 x:  1804 Y  1046  Text
# 411 x:  1804 Y  1046  Text
# 412 x:  1805 Y  1046  Text
# 413 x:  1805 Y  1046  Text 1121
# 414 x:  1835 Y  1049  Text 2.m
# 415 x:  1804 Y  1052  Text
# 416 x:  1804 Y  1064  Text 1870272023
# 417 x:  1879 Y  1052  Text A
# 1 x:  0 Y  0  Text
# 2 x:  2 Y  0  Text
# 3 x:  2 Y  0  Text
# 4 x:  2 Y  0  Text
# 5 x:  2 Y  0  Text
# 6 x:  2 Y  35  Text
# 7 x:  2 Y  35  Text
# 8 x:  4 Y  92  Text
# 9 x:  4 Y  92  Text
# 10 x:  4 Y  176  Text
# 11 x:  4 Y  176  Text
# 12 x:  51 Y  39  Text
# 13 x:  51 Y  39  Text
# 14 x:  79 Y  39  Text
# 15 x:  79 Y  39  Text Inicio
# 16 x:  116 Y  24  Text —
# 17 x:  135 Y  39  Text Compartir
# 18 x:  51 Y  66  Text
# 19 x:  51 Y  73  Text >
# 20 x:  77 Y  72  Text +
# 21 x:  96 Y  66  Text m4
# 22 x:  135 Y  56  Text >
# 23 x:  155 Y  70  Text Esteequipo
# 24 x:  223 Y  56  Text >
# 25 x:  239 Y  70  Text Descargas
# 26 x:  746 Y  105  Text
# 27 x:  746 Y  105  Text
# 28 x:  746 Y  105  Text
# 29 x:  746 Y  105  Text Nombre
# 30 x:  748 Y  116  Text
# 31 x:  748 Y  116  Text
# 32 x:  1455 Y  118  Text
# 33 x:  1455 Y  118  Text Logout
# 34 x:  748 Y  116  Text
# 35 x:  748 Y  130  Text ¡Horario
# 36 x:  1400 Y  116  Text a
# 37 x:  748 Y  150  Text
# 38 x:  748 Y  150  Text 1
# 39 x:  767 Y  154  Text My
# 40 x:  790 Y  146  Text m
# 41 x:  800 Y  146  Text en
# 42 x:  832 Y  154  Text capitalización
# 43 x:  1399 Y  160  Text In
# 44 x:  1411 Y  157  Text 3
# 45 x:  1421 Y  157  Text (ipykemel)
# 46 x:  1489 Y  157  Text O
# 47 x:  40 Y  172  Text
# 48 x:  746 Y  172  Text
# 49 x:  748 Y  172  Text
# 50 x:  748 Y  172  Text 3
# 51 x:  767 Y  175  Text Nacional
# 52 x:  817 Y  175  Text Enero
# 53 x:  849 Y  180  Text -
# 54 x:  858 Y  175  Text Bitácora
# 55 x:  903 Y  175  Text Operativa
# 56 x:  957 Y  180  Text -
# 57 x:  746 Y  193  Text
# 58 x:  746 Y  193  Text MÍ
# 59 x:  767 Y  196  Text PARAMO
# 60 x:  42 Y  213  Text
# 61 x:  42 Y  213  Text
# 62 x:  42 Y  213  Text E
# 63 x:  62 Y  216  Text Documentos
# 64 x:  767 Y  217  Text PLO17O
# 65 x:  40 Y  234  Text
# 66 x:  40 Y  234  Text
# 67 x:  40 Y  239  Text EX
# 68 x:  62 Y  240  Text Imágenes
# 69 x:  746 Y  234  Text (
# 70 x:  767 Y  238  Text pLor7o:
# 71 x:  43 Y  262  Text
# 72 x:  43 Y  262  Text
# 73 x:  43 Y  262  Text A
# 74 x:  756 Y  265  Text .
# 75 x:  32 Y  296  Text
# 76 x:  32 Y  296  Text
# 77 x:  32 Y  296  Text
# 78 x:  32 Y  296  Text ds
# 79 x:  53 Y  296  Text OneDrive
# 80 x:  1285 Y  146  Text
# 81 x:  1285 Y  146  Text
# 82 x:  1285 Y  146  Text
# 83 x:  1285 Y  146  Text
# 84 x:  1134 Y  146  Text
# 85 x:  1134 Y  146  Text
# 86 x:  1134 Y  146  Text
# 87 x:  1134 Y  146  Text
# 88 x:  43 Y  318  Text
# 89 x:  43 Y  318  Text
# 90 x:  43 Y  318  Text
# 91 x:  43 Y  318  Text IM
# 92 x:  62 Y  320  Text Documentos
# 93 x:  43 Y  342  Text
# 94 x:  43 Y  342  Text
# 95 x:  43 Y  342  Text
# 96 x:  43 Y  342  Text M
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\52811\AppData\Local\Temp\ipykernel_16484\2094412092.py", line 69, in on_testado_button_clicked
#     clienteMayus = hoja.cell(lol.row, 65).value
# AttributeError: 'NoneType' object has no attribute 'row'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\52811\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\52811\AppData\Local\Temp\ipykernel_16484\2094412092.py", line 310, in on_testado_button_clicked
#     auto.click()
#   File "C:\Users\52811\anaconda3\lib\site-packages\pyautogui\__init__.py", line 597, in wrapper
#     failSafeCheck()
#   File "C:\Users\52811\anaconda3\lib\site-packages\pyautogui\__init__.py", line 1722, in failSafeCheck
#     raise FailSafeException(
# pyautogui.FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.
# 1 x:  0 Y  0  Text
# 2 x:  0 Y  10  Text
# 3 x:  0 Y  10  Text
# 4 x:  0 Y  10  Text
# 5 x:  0 Y  10  Text
# 6 x:  7 Y  28  Text
# 7 x:  7 Y  28  Text
# 8 x:  7 Y  28  Text
# 9 x:  7 Y  28  Text Archivo
# 10 x:  30 Y  7  Text
# 11 x:  30 Y  7  Text
# 12 x:  30 Y  7  Text
# 13 x:  30 Y  7  Text ECFD_20230213_105632.pdf
# 14 x:  176 Y  0  Text -
# 15 x:  183 Y  7  Text Adobe
# 16 x:  221 Y  7  Text Acrobat
# 17 x:  267 Y  7  Text Pro
# 18 x:  288 Y  7  Text DC
# 19 x:  63 Y  28  Text
# 20 x:  63 Y  28  Text
# 21 x:  63 Y  28  Text
# 22 x:  63 Y  28  Text Edición
# 23 x:  115 Y  28  Text Ver
# 24 x:  145 Y  28  Text Ventana
# 25 x:  201 Y  28  Text Ayuda
# 26 x:  1211 Y  170  Text
# 27 x:  1211 Y  170  Text
# 28 x:  1211 Y  170  Text
# 29 x:  1211 Y  170  Text FACTURA
# 30 x:  1335 Y  170  Text 3644882696
# 31 x:  300 Y  218  Text
# 32 x:  300 Y  218  Text
# 33 x:  300 Y  218  Text
# 34 x:  300 Y  218  Text VALERO
# 35 x:  410 Y  218  Text MARKETING
# 36 x:  566 Y  218  Text AND
# 37 x:  628 Y  218  Text SUPPLY
# 38 x:  733 Y  218  Text DE
# 39 x:  774 Y  218  Text MEXICO
# 40 x:  301 Y  281  Text
# 41 x:  301 Y  281  Text
# 42 x:  301 Y  281  Text
# 43 x:  301 Y  281  Text RFC:
# 44 x:  339 Y  281  Text VMS16042911A
# 45 x:  301 Y  302  Text
# 46 x:  301 Y  302  Text Régimen
# 47 x:  365 Y  302  Text Fiscal:
# 48 x:  412 Y  302  Text 601-General
# 49 x:  499 Y  302  Text de
# 50 x:  520 Y  302  Text Ley
# 51 x:  548 Y  302  Text Personas
# 52 x:  616 Y  302  Text Morales
# 53 x:  301 Y  322  Text
# 54 x:  301 Y  322  Text Lugar,
# 55 x:  345 Y  322  Text fecha
# 56 x:  386 Y  325  Text y
# 57 x:  399 Y  322  Text hora
# 58 x:  432 Y  322  Text de
# 59 x:  453 Y  322  Text expedición:
# 60 x:  533 Y  322  Text 87440
# 61 x:  580 Y  322  Text 13/02/2023
# 62 x:  663 Y  322  Text 10:56:32
# 63 x:  82 Y  369  Text
# 64 x:  82 Y  369  Text
# 65 x:  82 Y  369  Text
# 66 x:  82 Y  369  Text CLIENTE
# 67 x:  90 Y  417  Text
# 68 x:  90 Y  417  Text
# 69 x:  90 Y  417  Text
# 70 x:  90 Y  417  Text PETROLIFEROS
# 71 x:  210 Y  417  Text LOBO
# 72 x:  90 Y  438  Text
# 73 x:  90 Y  438  Text
# 74 x:  90 Y  438  Text RFC:
# 75 x:  129 Y  438  Text PLO170306G79
# 76 x:  90 Y  458  Text
# 77 x:  90 Y  458  Text
# 78 x:  90 Y  458  Text Régimen
# 79 x:  155 Y  458  Text Fiscal:
# 80 x:  201 Y  458  Text 601-General
# 81 x:  288 Y  458  Text de
# 82 x:  310 Y  458  Text Ley
# 83 x:  338 Y  458  Text Personas
# 84 x:  405 Y  458  Text Morales
# 85 x:  90 Y  479  Text
# 86 x:  90 Y  479  Text Domicilio
# 87 x:  156 Y  479  Text Fiscal:
# 88 x:  202 Y  479  Text 64650
# 89 x:  90 Y  499  Text
# 90 x:  90 Y  499  Text
# 91 x:  90 Y  499  Text Uso
# 92 x:  121 Y  499  Text CFDI:
# 93 x:  164 Y  499  Text GO1-Adquisición
# 94 x:  278 Y  499  Text de
# 95 x:  299 Y  499  Text mercancías.
# 96 x:  79 Y  533  Text
# 97 x:  79 Y  533  Text
# 98 x:  79 Y  533  Text
# 99 x:  79 Y  533  Text PRODUCTOS
# 100 x:  243 Y  533  Text /
# 101 x:  258 Y  533  Text SERVICIOS
# 102 x:  328 Y  572  Text
# 103 x:  328 Y  572  Text
# 104 x:  328 Y  572  Text
# 105 x:  328 Y  576  Text Clave
# 106 x:  380 Y  576  Text Prod/
# 107 x:  811 Y  572  Text Objeto
# 108 x:  921 Y  576  Text Clave
# 109 x:  342 Y  591  Text
# 110 x:  342 Y  591  Text Servicio
# 111 x:  824 Y  595  Text Imp
# 112 x:  916 Y  595  Text unidad
# 113 x:  335 Y  625  Text
# 114 x:  335 Y  625  Text
# 115 x:  335 Y  625  Text
# 116 x:  335 Y  625  Text 15101505-
# 117 x:  455 Y  625  Text Diesel
# 118 x:  507 Y  632  Text -
# 119 x:  519 Y  625  Text H/20054/COM/2017
# 120 x:  818 Y  625  Text 02-Si
# 121 x:  909 Y  625  Text STL-Litro
# 122 x:  1038 Y  625  Text 120
# 123 x:  327 Y  634  Text
# 124 x:  327 Y  634  Text
# 125 x:  327 Y  634  Text
# 126 x:  327 Y  634  Text Combustible
# 127 x:  803 Y  644  Text objeto
# 128 x:  855 Y  644  Text de
# 129 x:  911 Y  644  Text estándar
# 130 x:  352 Y  664  Text
# 131 x:  352 Y  664  Text diesel
# 132 x:  801 Y  664  Text impuesto
# 133 x:  423 Y  688  Text
# 134 x:  423 Y  688  Text
# 135 x:  423 Y  688  Text
# 136 x:  423 Y  689  Text TRASLADO:
# 137 x:  516 Y  689  Text Base:
# 138 x:  560 Y  689  Text 485057.23
# 139 x:  641 Y  689  Text Impuesto:
# 140 x:  717 Y  689  Text 002-IVA
# 141 x:  774 Y  689  Text Tipo
# 142 x:  811 Y  689  Text de
# 143 x:  832 Y  689  Text factor:
# 144 x:  883 Y  689  Text Tasa
# 145 x:  919 Y  689  Text Tasa
# 146 x:  957 Y  692  Text o
# 147 x:  971 Y  690  Text cuota:
# 148 x:  1020 Y  689  Text 8.00%
# 149 x:  1067 Y  689  Text Importe:
# 150 x:  1131 Y  688  Text $38,804.58
# 151 x:  967 Y  414  Text
# 152 x:  967 Y  414  Text
# 153 x:  967 Y  414  Text
# 154 x:  967 Y  417  Text Lugar
# 155 x:  1009 Y  417  Text de
# 156 x:  1030 Y  420  Text carga:
# 157 x:  1075 Y  417  Text TRUCK
# 158 x:  1132 Y  414  Text B/S-SunocoBrownksville-MX
# 159 x:  967 Y  438  Text
# 160 x:  967 Y  438  Text
# 161 x:  967 Y  438  Text Destino:
# 162 x:  1025 Y  438  Text 4000207
# 163 x:  1088 Y  445  Text -
# 164 x:  1098 Y  438  Text PETROLIFEROS
# 165 x:  1218 Y  438  Text LOBO-MX-EXPT
# 166 x:  1337 Y  438  Text ONLY
# 167 x:  1378 Y  438  Text MEX
# 168 x:  968 Y  458  Text
# 169 x:  968 Y  458  Text Fecha
# 170 x:  1013 Y  458  Text BOL:
# 171 x:  1052 Y  458  Text 10/02/2023
# 172 x:  967 Y  479  Text
# 173 x:  967 Y  479  Text
# 174 x:  967 Y  479  Text Número
# 175 x:  1024 Y  479  Text de
# 176 x:  1045 Y  479  Text BOL:
# 177 x:  1084 Y  479  Text 10742
# 178 x:  78 Y  582  Text
# 179 x:  78 Y  582  Text
# 180 x:  78 Y  582  Text
# 181 x:  78 Y  586  Text Cantidad
# 182 x:  199 Y  586  Text Clave
# 183 x:  454 Y  582  Text Descripción
# 184 x:  1024 Y  586  Text Unidad
# 185 x:  1114 Y  586  Text Valor
# 186 x:  1162 Y  586  Text Unitario
# 187 x:  1421 Y  586  Text Importe
# 188 x:  111 Y  624  Text
# 189 x:  111 Y  624  Text
# 190 x:  111 Y  624  Text
# 191 x:  111 Y  625  Text 28411.681
# 192 x:  211 Y  625  Text ULSD.M2
# 193 x:  1143 Y  624  Text $17.506084
# 194 x:  1388 Y  624  Text $497,377.27
# 195 x:  327 Y  682  Text
# 196 x:  327 Y  682  Text
# 197 x:  327 Y  682  Text
# 198 x:  327 Y  682  Text
# 199 x:  1221 Y  683  Text
# 200 x:  1221 Y  683  Text
# 201 x:  1221 Y  683  Text
# 202 x:  1221 Y  683  Text
# 203 x:  327 Y  683  Text
# 204 x:  327 Y  683  Text
# 205 x:  327 Y  683  Text
# 206 x:  327 Y  683  Text
# 207 x:  327 Y  712  Text
# 208 x:  327 Y  712  Text
# 209 x:  327 Y  712  Text
# 210 x:  327 Y  712  Text
# 211 x:  1248 Y  800  Text
# 212 x:  1248 Y  800  Text
# 213 x:  1248 Y  800  Text
# 214 x:  1248 Y  800  Text Subtotal
# 215 x:  1390 Y  803  Text $497,377.27
# 216 x:  78 Y  826  Text
# 217 x:  78 Y  826  Text
# 218 x:  78 Y  826  Text
# 219 x:  78 Y  827  Text Traslado
# 220 x:  676 Y  827  Text Base:
# 221 x:  727 Y  826  Text $485,057.23
# 222 x:  834 Y  827  Text Impuesto:
# 223 x:  921 Y  827  Text 002-IVA
# 224 x:  988 Y  827  Text Tipo
# 225 x:  1029 Y  827  Text de
# 226 x:  1054 Y  827  Text factor:
# 227 x:  1113 Y  827  Text Tasa
# 228 x:  1155 Y  827  Text Tasa
# 229 x:  1198 Y  830  Text o
# 230 x:  1214 Y  827  Text cuota:
# 231 x:  1271 Y  827  Text 8.00%
# 232 x:  1399 Y  826  Text $38,804.58
# 233 x:  73 Y  845  Text
# 234 x:  73 Y  845  Text
# 235 x:  73 Y  845  Text
# 236 x:  73 Y  845  Text
# 237 x:  78 Y  853  Text
# 238 x:  78 Y  853  Text
# 239 x:  78 Y  853  Text
# 240 x:  78 Y  854  Text Importe
# 241 x:  147 Y  857  Text con
# 242 x:  183 Y  854  Text letra:
# 243 x:  230 Y  854  Text QUINIENTOS
# 244 x:  343 Y  854  Text TREINTA
# 245 x:  421 Y  854  Text Y
# 246 x:  438 Y  854  Text SEIS
# 247 x:  483 Y  854  Text MIL
# 248 x:  517 Y  854  Text CIENTO
# 249 x:  588 Y  854  Text OCHENTA
# 250 x:  674 Y  844  Text Y
# 251 x:  694 Y  854  Text UN
# 252 x:  724 Y  854  Text PESOS
# 253 x:  788 Y  854  Text 85/100
# 254 x:  851 Y  854  Text MXN
# 255 x:  1278 Y  854  Text Total
# 256 x:  1390 Y  853  Text $536,181.85
# 257 x:  1252 Y  877  Text
# 258 x:  1252 Y  877  Text Moneda
# 259 x:  1448 Y  877  Text MXN
# 260 x:  1192 Y  901  Text
# 261 x:  1192 Y  901  Text Tipo
# 262 x:  1232 Y  901  Text de
# 263 x:  1257 Y  901  Text cambio
# 264 x:  1478 Y  901  Text 1
# 265 x:  75 Y  926  Text
# 266 x:  75 Y  926  Text
# 267 x:  75 Y  926  Text
# 268 x:  75 Y  926  Text
# 269 x:  76 Y  941  Text
# 270 x:  76 Y  941  Text
# 271 x:  77 Y  941  Text
# 272 x:  77 Y  941  Text Cadena
# 273 x:  135 Y  941  Text Original
# 274 x:  196 Y  941  Text del
# 275 x:  223 Y  941  Text Complemento
# 276 x:  326 Y  941  Text de
# 277 x:  349 Y  941  Text Certificación
# 278 x:  444 Y  941  Text Digital
# 279 x:  494 Y  941  Text del
# 280 x:  520 Y  941  Text SAT:
# 281 x:  560 Y  941  Text ||1.11384C0FF8-5D3C-415E-B5F3-EFSEBDAO2A37/2023-02-
# 282 x:  77 Y  959  Text
# 283 x:  77 Y  959  Text 137T11:01:19/5ST060807KU0|cJYtaGyK29/5U+AcFY
# 284 x:  428 Y  959  Text 1Tue15BI4RsglF+8+nTXXymYhnhRPA1bMFLqkm+KUpRDI84e2j0jAtWwW6VKSWxkpOAMZGwuE9Ubr78W4d9wLpOTxqt3lg7XmQaqokZUbTPtzVwux48aZx
# 285 x:  76 Y  976  Text
# 286 x:  76 Y  976  Text rkUdvLbOA6+EH2fCzrbm250ZwOADIRCL2qEqiuw35x66Dsj5Gs3d7bpOmqvGXkqihBkPSL1TwChHDWdgd8sZB¡8BV/q21wJrVkU8jTIJONIGjYFL1/0MUN/w1HiesVDY
# 287 x:  1115 Y  976  Text Tv6glagCzaGETVr2FWOmzu4mkMygEm
# 288 x:  76 Y  993  Text
# 289 x:  76 Y  985  Text kJkCS5x0ycNb2AlcbL
# 290 x:  226 Y  993  Text qKemDK6oFCLJInKg4kRnRynjacfoTg==/000010000005062027891|
# 291 x:  76 Y  1011  Text
# 292 x:  76 Y  1011  Text
# 293 x:  76 Y  1011  Text Sello
# 294 x:  116 Y  1011  Text Digital
# 295 x:  166 Y  1011  Text del
# 296 x:  193 Y  1011  Text Emisor:
# 297 x:  0 Y  8  Text
# 298 x:  0 Y  8  Text
# 299 x:  0 Y  8  Text
# 300 x:  0 Y  8  Text
# 301 x:  1639 Y  207  Text
# 302 x:  1639 Y  207  Text
# 303 x:  1639 Y  207  Text
# 304 x:  1639 Y  208  Text Crear
# 305 x:  1683 Y  207  Text archivo
# 306 x:  1737 Y  208  Text PDF
# 307 x:  1639 Y  253  Text
# 308 x:  1639 Y  254  Text Combinar
# 309 x:  1712 Y  253  Text archivos
# 310 x:  1640 Y  299  Text
# 311 x:  1640 Y  299  Text Editar
# 312 x:  1684 Y  300  Text PDF
# 313 x:  1640 Y  345  Text
# 314 x:  1640 Y  346  Text Exportar
# 315 x:  1701 Y  345  Text archivo
# 316 x:  1757 Y  346  Text PDF
# 317 x:  1639 Y  391  Text
# 318 x:  1639 Y  391  Text Organizar
# 319 x:  1713 Y  391  Text páginas
# 320 x:  1640 Y  437  Text
# 321 x:  1640 Y  437  Text Enviar
# 322 x:  1687 Y  441  Text para
# 323 x:  1721 Y  437  Text comentarios
# 324 x:  1639 Y  484  Text
# 325 x:  1639 Y  484  Text Comentar
# 326 x:  1640 Y  529  Text
# 327 x:  1640 Y  529  Text Rellenar
# 328 x:  1700 Y  519  Text y
# 329 x:  1710 Y  529  Text firmar
# 330 x:  1667 Y  575  Text
# 331 x:  1667 Y  575  Text italizar
# 332 x:  1719 Y  565  Text y
# 333 x:  1732 Y  575  Text OCR
# 334 x:  1640 Y  622  Text
# 335 x:  1640 Y  622  Text Proteger
# 336 x:  1639 Y  667  Text
# 337 x:  1639 Y  667  Text
# 338 x:  1639 Y  667  Text
# 339 x:  1639 Y  667  Text JavaScript
# 340 x:  1609 Y  709  Text
# 341 x:  1609 Y  709  Text
# 342 x:  1609 Y  709  Text
# 343 x:  1609 Y  709  Text [E]
# 344 x:  1639 Y  713  Text Asistente
# 345 x:  1706 Y  713  Text de
# 346 x:  1727 Y  713  Text acciones
# 347 x:  1607 Y  754  Text
# 348 x:  1607 Y  754  Text
# 349 x:  1607 Y  754  Text
# 350 x:  1607 Y  754  Text OS
# 351 x:  1611 Y  968  Text
# 352 x:  1611 Y  968  Text
# 353 x:  1611 Y  968  Text
# 354 x:  1611 Y  968  Text Almacene
# 355 x:  1676 Y  971  Text y
# 356 x:  1688 Y  969  Text comparta
# 357 x:  1750 Y  968  Text archivos
# 358 x:  1807 Y  971  Text en
# 359 x:  1826 Y  968  Text Document
# 360 x:  1731 Y  983  Text
# 361 x:  1731 Y  983  Text Cloud
# 362 x:  1706 Y  1008  Text
# 363 x:  1706 Y  1008  Text
# 364 x:  1706 Y  1008  Text
# 365 x:  1706 Y  1008  Text Más
# 366 x:  1731 Y  1008  Text información
