# %%
import tkinter as tk
from tkinter import ttk
from PIL import Image, ImageTk
import pytesseract
from pytesseract import Output
import cv2
import speech_recognition as sr
import pyautogui as auto
import pyttsx3
import time
import gspread
import pyperclip
from oauth2client.service_account import ServiceAccountCredentials
from difflib import SequenceMatcher as SM
from PIL import Image
import ctypes
import win32api
import win32con
import atexit
def update_clock():
    current_time = time.strftime("%H:%M:%S")
    current_date = time.strftime("%Y-%m-%d")
    clock.config(text=f"Hora: {current_time}\nFecha: {current_date}")
    clock.after(1000, update_clock)
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/spreadsheets", "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("credentials.json", scope)
client = gspread.authorize(creds)
sheet = client.open_by_url('https://docs.google.com/spreadsheets/d/1RxxZPpm4cnJAzjLWnN38SN4Q57hJNY2bHk0w3Gd-sB0/edit?usp=sharing')
hoja = sheet.worksheet("Provedor Valero")
hoja3 = sheet.worksheet("Provedor Variado")
def copy_clipboard():
    auto.hotkey('Ctrl', 'c')
    time.sleep(.01)  # ctrl-c is usually very fast but your program may execute faster
    return pyperclip.paste()
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
recognizer = sr.Recognizer()
microphone = sr.Microphone(device_index = 0)
eng = pyttsx3.init()
eng.setProperty("rate", 140)
eng.setProperty("volume", 1.0)
listVoices = eng.getProperty("voices")
eng.setProperty("voice", listVoices[2].id)
def on_testado_button_clicked():
    eng.say("Reconocimiento de pantalla activado")
    eng.runAndWait()
    palabra = "Editar"
    img = auto.screenshot()
    d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
    n_boxes = len(d["level"])
    for i in range(n_boxes):
        x , y , text = (d["left"][i], d["top"][i], d["text"][i])
        if text != "" or text !=" " or text != "  "or text !="    ":
            print((i+1), "x: ",x , "Y ", y, " Text", text)
        similitud = SM(None, text, palabra).ratio()
        if similitud >0.7:
            auto.moveTo(x,y)
            auto.click()
            time.sleep(1.5)
    auto.moveTo(1297, 233)
    auto.mouseDown()
    auto.moveTo(1453,233)
    auto.mouseUp()
    try:
    
        NumFact = copy_clipboard()
        lol = hoja.find(NumFact)
        time.sleep(0.5)
        clienteMayus = hoja.cell(lol.row, 65).value
        if clienteMayus == "PENDIENTE DEFINIR":
            eng.say("Valero en carpeta bol")
            eng.runAndWait()
        else:
            palabra = "letra:"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra).ratio()
                if similitud >0.7:
                    auto.moveTo(x+40,y)
                    auto.mouseDown()
                    auto.moveTo(x+1080, y)
                    auto.mouseUp()
                    auto.press("delete")
                    time.sleep(1)
            palabra = "letra:"
            palabra2 = "TRASLADO"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra2).ratio()
                if similitud >0.7:
                    auto.moveTo(x+130,y)
                    auto.mouseDown()
                    auto.moveTo(x+210, y)
                    auto.mouseUp()
                    auto.press("delete")
                    auto.moveTo(x+490,y)
                    auto.mouseDown()
                    auto.moveTo(x+540, y)
                    auto.mouseUp()
                    auto.press("delete")
                    auto.moveTo(x+555, y)
                    auto.mouseDown()
                    auto.moveTo(x+650, y)
                    auto.mouseUp()
                    auto.press("delete")
                    time.sleep(1)
            palabra4 = "Subtotal"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra4).ratio()
                if similitud >0.7:
                    auto.moveTo(x+60,y+30)
                    auto.click()
                    auto.press("right")
                    auto.press("right")
                    auto.press("right")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.press("backspace")
                    auto.moveTo(x-460,y+30)
                    auto.mouseDown()
                    auto.moveTo(x-365,y+30)
                    auto.mouseUp()
                    auto.press("delete")
                    time.sleep(1)
            palabra5 = "cambio"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra5).ratio()
                if similitud >0.7:
                    auto.moveTo(x+90,y+25)
                    auto.mouseDown()
                    auto.moveTo(x+250, y -100)
                    auto.mouseUp()
                    time.sleep(0.1)
                    auto.press("delete")
                    time.sleep(1)
            palabra6 = "Unitario"
            img = auto.screenshot()
            d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
            n_boxes = len(d["level"])
            for i in range(n_boxes):
                x , y , text = (d["left"][i], d["top"][i], d["text"][i])
                if text != "" or text !=" " or text != "  "or text !="    ":
                    print((i+1), "x: ",x , "Y ", y, " Text", text)
                similitud = SM(None, text, palabra6).ratio()
                if similitud >0.7:
                    auto.moveTo(x+340,y + 100)
                    auto.mouseDown()
                    auto.moveTo(x-50 , y + 20)
                    auto.mouseUp()
                    auto.press("delete")
                    time.sleep(1)
            auto.moveTo(1052, 153)
            auto.click()
            time.sleep(1)
            auto.moveTo(1094, 190)
            auto.click()
            time.sleep(5)
            auto.moveTo(671, 244)
            auto.click()
            time.sleep(1)
            auto.moveTo(721, 296)
            time.sleep(1)
            auto.typewrite("P")
            auto.press("enter")
            time.sleep(1)
            auto.moveTo(723, 302)
            auto.click()
            auto.press("space")
            time.sleep(0.5)
            auto.write(clienteMayus)
            time.sleep(1)
            auto.moveTo(1113, 815)
            auto.click()
            time.sleep(1)
            auto.moveTo(1056, 603)
            auto.click()
            auto.sleep(1)
###########AGREGAR MARCA DE AGUA#############################
            auto.moveTo(1052, 153)
            auto.click()
            time.sleep(1)
            auto.moveTo(1094, 190)
            auto.click()
            time.sleep(1)
            auto.moveTo(1086, 607)
            auto.click()
            time.sleep(3)
            auto.moveTo(671, 244)
            auto.click()
            time.sleep(1)
            auto.moveTo(721, 296)
            time.sleep(1)
            auto.typewrite("L")
            auto.typewrite("L")
            auto.typewrite("L")
            auto.press("enter")
            time.sleep(1)
            auto.moveTo(1113, 815)
            auto.click()
            time.sleep(1)
            auto.moveTo(1056, 603)
            auto.click()
            auto.sleep(3)
#####EXPORTAR COMO IMAGEN############
            auto.moveTo(1893, 331)
            auto.click()
            time.sleep(1)
            auto.moveTo(957, 543)
            auto.click()
            time.sleep(1)
            auto.moveTo(946, 741)
            auto.click()
            time.sleep(2)
            auto.moveTo(365, 443)
            auto.click()
            auto.typewrite("-2")
            time.sleep(1)
            auto.moveTo(67, 188)
            auto.click()
            time.sleep(1)
            auto.moveTo(777, 588)
            auto.click()
            time.sleep(10)
            auto.moveTo(1883, 7)
            auto.click()
            time.sleep(1)
            auto.moveTo(1046, 579)
            auto.click()

    except:
    
        eng.say("VALERO NO REGISTRADA EN BITÁCORA. AVISAR A FACTURACIÓN")
        eng.runAndWait();
        b=0;
        d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
        n_boxes = len(d["level"])
        for i in range(n_boxes):
            x , y , text = (d["left"][i], d["top"][i], d["text"][i])
            if text != "" or text !=" " or text != "  "or text !="    ":
                print((i+1), "x: ",x , "Y ", y, " Text", text)
            similitud = SM(None, text, " Archivo").ratio()
            if similitud >0.7 and b==0:
                auto.moveTo(x,y)
                auto.click()
                time.sleep(2)
                b=b+1
        img = auto.screenshot()
        d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
        n_boxes = len(d["level"])
        b=0;
        for i in range(n_boxes):
            x , y , text = (d["left"][i], d["top"][i], d["text"][i])
            if text != "" or text !=" " or text != "  "or text !="    ":
                print((i+1), "x: ",x , "Y ", y, " Text", text)
            similitud = SM(None, text, "Guardar").ratio()
            if similitud >0.7 and b==0:
                auto.moveTo(x,y);
                auto.click();
                time.sleep(1.2);
                auto.press("right")
                time.sleep(0.3)
                auto.typewrite("-NO REGISTRADA")
                b=1;
        img = auto.screenshot()
        d = pytesseract.image_to_data(img, lang="spa",output_type = Output.DICT)
        n_boxes = len(d["level"]);
        b=0
        for i in range(n_boxes):
            x , y , text = (d["left"][i], d["top"][i], d["text"][i])
            if text != "" or text !=" " or text != "  "or text !="    ":
                print((i+1), "x: ",x , "Y ", y, " Text", text)
            similitud = SM(None, text, "Guardar").ratio()
            if similitud >0.7 and b<=1:
                if b ==0:
                    b=b+1
            else:
                auto.moveTo(x,y)
                auto.click()
def on_facturacion_button_clicked():
    print("Botón Facturación ha sido presionado")
root = tk.Tk()
wtotal = root.winfo_screenwidth()
htotal = root.winfo_screenheight()
wventana = 900
hventana = 555
pwidth = round(wtotal/2-wventana/2)
pheight = round(htotal/2-hventana/2)
root.geometry(str(wventana)+"x"+str(hventana)+"+"+str(pwidth)+"+"+str(pheight))
root.resizable(0,0)
root.title("Departamento de Facturación Petrolíferos Lobo")
logo =Image.open("lobito.jpg")
icono = ImageTk.PhotoImage(logo)
root.iconphoto(True, icono)
def on_exit_button_clicked():
    root.destroy()
image_quit = Image.open("Quit.png")
photo_quit = ImageTk.PhotoImage(image_quit.resize((45,45)))
exit_button = ttk.Button(root, image=photo_quit, compound="bottom", command=on_exit_button_clicked)


# Cargamos las imágenes
image_documento = Image.open("Testado.png")
photo_documento = ImageTk.PhotoImage(image_documento.resize((80,80)))

image_billete = Image.open("Facturación.png")
photo_billete = ImageTk.PhotoImage(image_billete.resize((80,80)))

# Creamos los botones con sus imágenes y etiquetas

testado_button = ttk.Button(root, text="Testado",  compound="top",image=photo_documento, command=on_testado_button_clicked)

facturacion_button = ttk.Button(root, text="Facturación",compound="top", image=photo_billete, command=on_facturacion_button_clicked)

# Guardamos una referencia a las imágenes
testado_button.image = photo_documento
facturacion_button.image = photo_billete

# Posicionamos los botones en la ventana
testado_button.pack()
facturacion_button.pack()
exit_button.pack()
testado_button.place(x=150,y=50, width=300, height = 450)
facturacion_button.place(x=480,y=50, width=300, height =450)
exit_button.place(x=850,y=500, width=50, height = 55)


root.mainloop()
# Out:
# 1 x:  0 Y  0  Text
# 2 x:  7 Y  5  Text
# 3 x:  7 Y  5  Text
# 4 x:  30 Y  5  Text
# 5 x:  30 Y  7  Text ECFD_20230214_092414.pdf
# 6 x:  177 Y  0  Text -
# 7 x:  183 Y  7  Text Adobe
# 8 x:  221 Y  7  Text Acrobat
# 9 x:  267 Y  7  Text Pro
# 10 x:  288 Y  7  Text DC
# 11 x:  1890 Y  5  Text x
# 12 x:  7 Y  28  Text
# 13 x:  7 Y  28  Text Archivo
# 14 x:  63 Y  28  Text Edición
# 15 x:  115 Y  28  Text Ver
# 16 x:  145 Y  28  Text Ventana
# 17 x:  201 Y  28  Text Ayuda
# 18 x:  0 Y  10  Text
# 19 x:  0 Y  10  Text
# 20 x:  0 Y  10  Text
# 21 x:  0 Y  10  Text
# 22 x:  1639 Y  207  Text
# 23 x:  1639 Y  207  Text
# 24 x:  1639 Y  207  Text
# 25 x:  1639 Y  208  Text Crear
# 26 x:  1681 Y  207  Text archivo
# 27 x:  1737 Y  208  Text PDF
# 28 x:  300 Y  218  Text
# 29 x:  300 Y  218  Text
# 30 x:  300 Y  218  Text
# 31 x:  300 Y  218  Text VALERO
# 32 x:  410 Y  218  Text MARKETING
# 33 x:  566 Y  218  Text AND
# 34 x:  628 Y  218  Text SUPPLY
# 35 x:  733 Y  218  Text DE
# 36 x:  774 Y  218  Text MEXICO
# 37 x:  1639 Y  253  Text
# 38 x:  1639 Y  253  Text
# 39 x:  1639 Y  253  Text
# 40 x:  1639 Y  253  Text Combinar
# 41 x:  1712 Y  253  Text archivos
# 42 x:  301 Y  281  Text
# 43 x:  301 Y  281  Text
# 44 x:  301 Y  281  Text
# 45 x:  301 Y  281  Text RFC:
# 46 x:  339 Y  281  Text VMS16042911A
# 47 x:  301 Y  299  Text
# 48 x:  301 Y  302  Text Régimen
# 49 x:  365 Y  302  Text Fiscal:
# 50 x:  412 Y  302  Text 601-General
# 51 x:  499 Y  302  Text de
# 52 x:  520 Y  302  Text Ley
# 53 x:  548 Y  302  Text Personas
# 54 x:  616 Y  302  Text Morales
# 55 x:  1640 Y  299  Text Editar
# 56 x:  1684 Y  300  Text PDF
# 57 x:  301 Y  322  Text
# 58 x:  301 Y  322  Text Lugar,
# 59 x:  345 Y  322  Text fecha
# 60 x:  386 Y  325  Text y
# 61 x:  399 Y  322  Text hora
# 62 x:  432 Y  322  Text de
# 63 x:  453 Y  322  Text expedición:
# 64 x:  533 Y  322  Text 87440
# 65 x:  580 Y  322  Text 14/02/2023
# 66 x:  662 Y  322  Text 09:24:14
# 67 x:  1640 Y  345  Text
# 68 x:  1640 Y  345  Text
# 69 x:  1640 Y  346  Text Exportar
# 70 x:  1701 Y  345  Text archivo
# 71 x:  1757 Y  346  Text PDF
# 72 x:  82 Y  369  Text
# 73 x:  82 Y  369  Text
# 74 x:  82 Y  369  Text
# 75 x:  82 Y  369  Text CLIENTE
# 76 x:  1639 Y  391  Text
# 77 x:  1639 Y  391  Text Organizar
# 78 x:  1713 Y  391  Text páginas
# 79 x:  90 Y  417  Text
# 80 x:  90 Y  417  Text
# 81 x:  90 Y  417  Text
# 82 x:  90 Y  417  Text PETROLIFEROS
# 83 x:  210 Y  417  Text LOBO
# 84 x:  967 Y  417  Text Lugar
# 85 x:  1009 Y  417  Text de
# 86 x:  1030 Y  420  Text carga:
# 87 x:  1075 Y  417  Text TRUCK
# 88 x:  1132 Y  417  Text B/S-SunocoBrownsville-MX
# 89 x:  90 Y  437  Text
# 90 x:  90 Y  438  Text RFC:
# 91 x:  129 Y  438  Text PLO170306G79
# 92 x:  967 Y  438  Text Destino:
# 93 x:  1025 Y  438  Text 4000207
# 94 x:  1088 Y  445  Text -
# 95 x:  1098 Y  438  Text PETROLIFEROS
# 96 x:  1218 Y  438  Text LOBO-MX-EXPT
# 97 x:  1337 Y  438  Text ONLY
# 98 x:  1378 Y  438  Text MEX
# 99 x:  1640 Y  437  Text Enviar
# 100 x:  1687 Y  441  Text para
# 101 x:  1721 Y  437  Text comentarios
# 102 x:  90 Y  458  Text
# 103 x:  90 Y  458  Text Régimen
# 104 x:  155 Y  458  Text Fiscal:
# 105 x:  201 Y  458  Text 601-General
# 106 x:  288 Y  458  Text de
# 107 x:  310 Y  458  Text Ley
# 108 x:  338 Y  458  Text Personas
# 109 x:  405 Y  458  Text Morales
# 110 x:  968 Y  458  Text Fecha
# 111 x:  1013 Y  458  Text BOL:
# 112 x:  1052 Y  458  Text 13/02/2023
# 113 x:  90 Y  479  Text
# 114 x:  90 Y  479  Text
# 115 x:  90 Y  479  Text Domicilio
# 116 x:  156 Y  479  Text Fiscal:
# 117 x:  202 Y  479  Text 64650
# 118 x:  967 Y  479  Text Número
# 119 x:  1024 Y  479  Text de
# 120 x:  1045 Y  479  Text BOL:
# 121 x:  1084 Y  479  Text 10771
# 122 x:  1639 Y  484  Text Car
# 123 x:  90 Y  499  Text
# 124 x:  90 Y  499  Text
# 125 x:  90 Y  499  Text Uso
# 126 x:  121 Y  499  Text CFDI:
# 127 x:  164 Y  499  Text GO1-Adquisición
# 128 x:  278 Y  499  Text de
# 129 x:  299 Y  499  Text mercancías.
# 130 x:  79 Y  529  Text
# 131 x:  79 Y  529  Text
# 132 x:  79 Y  529  Text
# 133 x:  79 Y  533  Text PRODUCTOS
# 134 x:  243 Y  533  Text /
# 135 x:  258 Y  533  Text SERVICIOS
# 136 x:  1640 Y  529  Text Rellenar
# 137 x:  1701 Y  524  Text y
# 138 x:  1713 Y  529  Text firmar
# 139 x:  328 Y  572  Text
# 140 x:  328 Y  572  Text
# 141 x:  328 Y  572  Text
# 142 x:  328 Y  576  Text Clave
# 143 x:  380 Y  576  Text Prod/
# 144 x:  503 Y  586  Text annie
# 145 x:  811 Y  572  Text Objeto
# 146 x:  921 Y  576  Text Clave
# 147 x:  1046 Y  586  Text a
# 148 x:  1185 Y  586  Text a
# 149 x:  1667 Y  575  Text italizar
# 150 x:  1717 Y  579  Text y
# 151 x:  1725 Y  576  Text OCR
# 152 x:  342 Y  582  Text
# 153 x:  342 Y  583  Text Servicio
# 154 x:  454 Y  582  Text Descripción
# 155 x:  824 Y  595  Text Imp
# 156 x:  916 Y  595  Text unidad
# 157 x:  1024 Y  586  Text Unidad
# 158 x:  1114 Y  586  Text Valor
# 159 x:  1162 Y  586  Text Unitario
# 160 x:  1421 Y  582  Text Importe
# 161 x:  110 Y  622  Text
# 162 x:  110 Y  622  Text
# 163 x:  110 Y  622  Text
# 164 x:  110 Y  625  Text 28471.877
# 165 x:  200 Y  625  Text 87CON11.5.
# 166 x:  335 Y  625  Text  15101514-
# 167 x:  454 Y  625  Text 87
# 168 x:  478 Y  625  Text Oct
# 169 x:  510 Y  625  Text Convencional
# 170 x:  622 Y  625  Text 11.5
# 171 x:  659 Y  625  Text RVP
# 172 x:  698 Y  632  Text -
# 173 x:  710 Y  625  Text H/20054/
# 174 x:  794 Y  615  Text —
# 175 x:  818 Y  625  Text 02-Sí
# 176 x:  909 Y  625  Text STL-Litro
# 177 x:  1038 Y  625  Text 120
# 178 x:  1143 Y  624  Text $16.717313
# 179 x:  1388 Y  624  Text $475,973.28
# 180 x:  1640 Y  622  Text Proteger
# 181 x:  237 Y  644  Text
# 182 x:  237 Y  644  Text M2
# 183 x:  312 Y  644  Text Gasolina
# 184 x:  386 Y  644  Text regular
# 185 x:  454 Y  644  Text COM/2017
# 186 x:  803 Y  644  Text objeto
# 187 x:  855 Y  644  Text de
# 188 x:  911 Y  644  Text estándar
# 189 x:  332 Y  654  Text
# 190 x:  332 Y  667  Text menor
# 191 x:  386 Y  667  Text a
# 192 x:  400 Y  664  Text 91
# 193 x:  801 Y  654  Text impuesto.
# 194 x:  1639 Y  667  Text JavaScript
# 195 x:  345 Y  683  Text
# 196 x:  345 Y  683  Text octanos
# 197 x:  78 Y  586  Text
# 198 x:  78 Y  586  Text
# 199 x:  78 Y  586  Text
# 200 x:  78 Y  586  Text Cantidad
# 201 x:  199 Y  586  Text Clave
# 202 x:  327 Y  703  Text
# 203 x:  327 Y  703  Text
# 204 x:  327 Y  703  Text
# 205 x:  327 Y  703  Text
# 206 x:  423 Y  708  Text
# 207 x:  423 Y  708  Text
# 208 x:  423 Y  708  Text
# 209 x:  423 Y  709  Text TRASLADO:
# 210 x:  516 Y  709  Text Base:
# 211 x:  560 Y  709  Text 461097.32
# 212 x:  641 Y  709  Text Impuesto:
# 213 x:  717 Y  709  Text 002-IVA
# 214 x:  774 Y  709  Text Tipo
# 215 x:  811 Y  709  Text de
# 216 x:  832 Y  709  Text factor:
# 217 x:  883 Y  709  Text Tasa
# 218 x:  919 Y  709  Text Tasa
# 219 x:  957 Y  712  Text o
# 220 x:  971 Y  710  Text cuota:
# 221 x:  1020 Y  709  Text 8.00%
# 222 x:  1067 Y  709  Text Importe:
# 223 x:  1131 Y  708  Text $36,887.79
# 224 x:  1609 Y  709  Text E]
# 225 x:  1639 Y  713  Text Asistente
# 226 x:  1706 Y  713  Text de
# 227 x:  1727 Y  713  Text acciones
# 228 x:  327 Y  702  Text
# 229 x:  327 Y  702  Text
# 230 x:  327 Y  702  Text
# 231 x:  327 Y  702  Text
# 232 x:  1221 Y  702  Text
# 233 x:  1221 Y  702  Text
# 234 x:  1221 Y  702  Text
# 235 x:  1221 Y  702  Text
# 236 x:  327 Y  732  Text
# 237 x:  327 Y  732  Text
# 238 x:  327 Y  732  Text
# 239 x:  327 Y  732  Text
# 240 x:  1607 Y  754  Text
# 241 x:  1607 Y  754  Text
# 242 x:  1607 Y  754  Text
# 243 x:  1607 Y  754  Text OS
# 244 x:  78 Y  813  Text
# 245 x:  1248 Y  813  Text
# 246 x:  1248 Y  813  Text
# 247 x:  1248 Y  813  Text Subtotal
# 248 x:  1390 Y  822  Text $475,973.28
# 249 x:  78 Y  846  Text
# 250 x:  78 Y  846  Text
# 251 x:  78 Y  847  Text Traslado
# 252 x:  676 Y  847  Text Base:
# 253 x:  727 Y  846  Text $461,097.32
# 254 x:  834 Y  847  Text Impuesto:
# 255 x:  921 Y  847  Text 002-IVA
# 256 x:  988 Y  847  Text Tipo
# 257 x:  1029 Y  847  Text de
# 258 x:  1054 Y  847  Text factor:
# 259 x:  1113 Y  847  Text Tasa
# 260 x:  1155 Y  847  Text Tasa
# 261 x:  1198 Y  850  Text o
# 262 x:  1214 Y  847  Text cuota:
# 263 x:  1271 Y  847  Text 8.00%
# 264 x:  1399 Y  846  Text $36,887.79
# 265 x:  78 Y  873  Text
# 266 x:  78 Y  874  Text Importe
# 267 x:  147 Y  877  Text con
# 268 x:  183 Y  874  Text letra:
# 269 x:  230 Y  874  Text QUINIENTOS
# 270 x:  344 Y  874  Text DOCE
# 271 x:  399 Y  874  Text MIL
# 272 x:  433 Y  874  Text OCHOCIENTOS
# 273 x:  568 Y  874  Text SESENTA
# 274 x:  652 Y  864  Text Y
# 275 x:  670 Y  874  Text UN
# 276 x:  700 Y  874  Text PESOS
# 277 x:  764 Y  874  Text 07/100
# 278 x:  828 Y  874  Text MXN
# 279 x:  1278 Y  874  Text Total
# 280 x:  1390 Y  873  Text $512,861.07
# 281 x:  1252 Y  897  Text
# 282 x:  1252 Y  897  Text Moneda
# 283 x:  1448 Y  897  Text MXN
# 284 x:  1192 Y  920  Text
# 285 x:  1192 Y  920  Text
# 286 x:  1192 Y  920  Text Tipo
# 287 x:  1232 Y  920  Text de
# 288 x:  1257 Y  920  Text cambio
# 289 x:  1478 Y  920  Text 1
# 290 x:  73 Y  867  Text
# 291 x:  73 Y  867  Text
# 292 x:  73 Y  867  Text
# 293 x:  73 Y  867  Text
# 294 x:  75 Y  948  Text
# 295 x:  75 Y  948  Text
# 296 x:  75 Y  948  Text
# 297 x:  75 Y  948  Text
# 298 x:  76 Y  961  Text
# 299 x:  76 Y  961  Text
# 300 x:  77 Y  961  Text
# 301 x:  77 Y  961  Text Cadena
# 302 x:  135 Y  961  Text Original
# 303 x:  196 Y  961  Text del
# 304 x:  223 Y  961  Text Complemento
# 305 x:  326 Y  961  Text de
# 306 x:  349 Y  961  Text Certificación
# 307 x:  444 Y  961  Text Digital
# 308 x:  494 Y  961  Text del
# 309 x:  520 Y  961  Text SAT:
# 310 x:  560 Y  961  Text |[1.112E7306F9-9511-4238-B84A-SCF5CE4CEBO9/2023-02-
# 311 x:  1611 Y  968  Text Almacene
# 312 x:  1676 Y  971  Text y
# 313 x:  1688 Y  969  Text comparta
# 314 x:  1750 Y  968  Text archivos
# 315 x:  1807 Y  971  Text en
# 316 x:  1826 Y  968  Text Document
# 317 x:  77 Y  978  Text
# 318 x:  77 Y  978  Text 14709:25:42SSTOS0807KU0|EgmtzIZgJu2XS1q+bGnX0DrCB9plyKi1JuZf+MBn/5gPwwHTfsTbq460
# 319 x:  837 Y  978  Text 1qVdctu2p1CESytucesH1jSeelo8TJAXSXXK5D34ApD30BCpKalaRUNhWKuDtdd138CbJOwcwo/ynpWa
# 320 x:  1731 Y  983  Text "Cloud
# 321 x:  76 Y  986  Text
# 322 x:  76 Y  986  Text UJGNFLeBSrJ1+Mj5F7alaRoyUtLPxaqC8M2irINR+yK4zCXpgarm2g7tPzFZKhIF24nX2XF00Y
# 323 x:  707 Y  986  Text QwcyLLV5dtav8AOgvZ58vOmy0WiPwzmDAAZb5bcAN4GyfFAe+S7WNKNWCCKk3CCDN74PtU7eQsrK3IE1YR
# 324 x:  1784 Y  1008  Text o
# 325 x:  76 Y  1003  Text
# 326 x:  76 Y  1003  Text 26PSj42NSqFzyFIcSo75nIV36igIRWjQ4el/80C432kzA==|00001000000506202789I|
# 327 x:  1706 Y  1008  Text stato
# 328 x:  105 Y  1032  Text
# 329 x:  105 Y  1032  Text
# 330 x:  105 Y  1035  Text o
# 331 x:  119 Y  1032  Text Digital
# 332 x:  169 Y  1035  Text g
# 333 x:  231 Y  1033  Text or
# 1 x:  0 Y  0  Text
# 2 x:  0 Y  10  Text
# 3 x:  0 Y  10  Text
# 4 x:  0 Y  10  Text
# 5 x:  0 Y  10  Text
# 6 x:  302 Y  10  Text
# 7 x:  7 Y  28  Text
# 8 x:  7 Y  28  Text
# 9 x:  7 Y  28  Text
# 10 x:  7 Y  28  Text Archivo
# 11 x:  63 Y  28  Text Edición
# 12 x:  115 Y  28  Text Ver
# 13 x:  145 Y  28  Text Ventana
# 14 x:  201 Y  28  Text Ayuda
# 15 x:  21 Y  145  Text
# 16 x:  21 Y  145  Text
# 17 x:  21 Y  145  Text
# 18 x:  21 Y  145  Text Editar
# 19 x:  71 Y  145  Text PDF
# 20 x:  30 Y  7  Text
# 21 x:  30 Y  7  Text
# 22 x:  30 Y  7  Text
# 23 x:  30 Y  7  Text sECFD_20230214_092414.pdf
# 24 x:  176 Y  0  Text -
# 25 x:  183 Y  7  Text Adobe
# 26 x:  221 Y  7  Text Acrobat
# 27 x:  267 Y  7  Text Pro
# 28 x:  288 Y  7  Text DC
# 29 x:  760 Y  92  Text
# 30 x:  760 Y  92  Text
# 31 x:  793 Y  92  Text
# 32 x:  793 Y  92  Text ¡IMXUMONO)
# 33 x:  760 Y  139  Text
# 34 x:  760 Y  139  Text TU0oOCAR
# 35 x:  291 Y  262  Text
# 36 x:  291 Y  262  Text
# 37 x:  291 Y  262  Text
# 38 x:  291 Y  262  Text VALERO
# 39 x:  398 Y  262  Text MARKETING
# 40 x:  549 Y  262  Text AND
# 41 x:  609 Y  262  Text SUPPLY
# 42 x:  711 Y  262  Text DE
# 43 x:  751 Y  262  Text MEXICO
# 44 x:  292 Y  323  Text
# 45 x:  292 Y  323  Text
# 46 x:  292 Y  323  Text
# 47 x:  292 Y  323  Text RFC:
# 48 x:  329 Y  323  Text VMS16042911A.
# 49 x:  292 Y  343  Text
# 50 x:  292 Y  343  Text Régimen
# 51 x:  354 Y  343  Text Fiscal:
# 52 x:  400 Y  343  Text 601-General
# 53 x:  484 Y  343  Text de
# 54 x:  505 Y  343  Text Ley
# 55 x:  532 Y  343  Text Personas
# 56 x:  597 Y  343  Text Morales
# 57 x:  292 Y  363  Text
# 58 x:  292 Y  363  Text
# 59 x:  292 Y  363  Text
# 60 x:  292 Y  363  Text Lugar,
# 61 x:  335 Y  363  Text fecha
# 62 x:  375 Y  366  Text y
# 63 x:  387 Y  363  Text hora
# 64 x:  419 Y  363  Text de
# 65 x:  440 Y  363  Text expedición:
# 66 x:  517 Y  363  Text 87440
# 67 x:  563 Y  363  Text 14/02/2023
# 68 x:  642 Y  363  Text 09:24:14
# 69 x:  76 Y  403  Text
# 70 x:  76 Y  403  Text
# 71 x:  76 Y  403  Text
# 72 x:  76 Y  403  Text CEI
# 73 x:  88 Y  455  Text
# 74 x:  88 Y  455  Text
# 75 x:  88 Y  455  Text
# 76 x:  88 Y  455  Text PETROLIFEROS
# 77 x:  204 Y  455  Text LOBO
# 78 x:  88 Y  475  Text
# 79 x:  88 Y  475  Text RFC:
# 80 x:  126 Y  475  Text PLO170306G79
# 81 x:  88 Y  495  Text
# 82 x:  88 Y  495  Text
# 83 x:  88 Y  495  Text
# 84 x:  88 Y  495  Text Régimen
# 85 x:  150 Y  495  Text Fiscal:
# 86 x:  196 Y  495  Text 601-General
# 87 x:  280 Y  495  Text de
# 88 x:  301 Y  495  Text Ley
# 89 x:  328 Y  495  Text Personas
# 90 x:  393 Y  495  Text Morales
# 91 x:  88 Y  515  Text
# 92 x:  88 Y  515  Text
# 93 x:  88 Y  515  Text
# 94 x:  88 Y  515  Text Domicilio
# 95 x:  151 Y  515  Text Fiscal:
# 96 x:  197 Y  515  Text 64650
# 97 x:  88 Y  534  Text
# 98 x:  88 Y  534  Text
# 99 x:  88 Y  534  Text
# 100 x:  88 Y  534  Text Uso
# 101 x:  118 Y  534  Text CFDI:
# 102 x:  159 Y  534  Text G01-Adquisición
# 103 x:  270 Y  534  Text de
# 104 x:  290 Y  534  Text mercancías.
# 105 x:  77 Y  568  Text
# 106 x:  77 Y  568  Text
# 107 x:  77 Y  568  Text
# 108 x:  77 Y  568  Text PRODUCTOS
# 109 x:  236 Y  568  Text /
# 110 x:  250 Y  568  Text SERVICIOS
# 111 x:  318 Y  609  Text
# 112 x:  318 Y  609  Text
# 113 x:  318 Y  609  Text
# 114 x:  318 Y  609  Text Clave
# 115 x:  369 Y  609  Text Prod/
# 116 x:  332 Y  629  Text
# 117 x:  332 Y  629  Text Servicio
# 118 x:  76 Y  614  Text
# 119 x:  76 Y  614  Text
# 120 x:  76 Y  614  Text
# 121 x:  76 Y  614  Text Cantidad
# 122 x:  194 Y  618  Text Clave
# 123 x:  107 Y  656  Text
# 124 x:  107 Y  656  Text
# 125 x:  107 Y  656  Text
# 126 x:  107 Y  656  Text 28471.877
# 127 x:  195 Y  656  Text 87CON11.5.
# 128 x:  441 Y  618  Text
# 129 x:  441 Y  618  Text
# 130 x:  441 Y  618  Text
# 131 x:  441 Y  618  Text Descri
# 132 x:  325 Y  656  Text
# 133 x:  325 Y  656  Text
# 134 x:  325 Y  656  Text
# 135 x:  325 Y  656  Text 15101514-
# 136 x:  440 Y  656  Text 87
# 137 x:  464 Y  656  Text Oct
# 138 x:  495 Y  656  Text Convencional
# 139 x:  603 Y  656  Text 11.5
# 140 x:  639 Y  656  Text RVP
# 141 x:  677 Y  663  Text -
# 142 x:  688 Y  656  Text H/20054/'
# 143 x:  303 Y  675  Text
# 144 x:  303 Y  675  Text
# 145 x:  303 Y  675  Text
# 146 x:  303 Y  675  Text Gasolina
# 147 x:  389 Y  675  Text regular
# 148 x:  440 Y  675  Text COM/2017
# 149 x:  322 Y  694  Text
# 150 x:  322 Y  697  Text menor
# 151 x:  374 Y  697  Text a
# 152 x:  389 Y  694  Text 91
# 153 x:  335 Y  713  Text
# 154 x:  335 Y  713  Text octanos
# 155 x:  938 Y  455  Text
# 156 x:  938 Y  455  Text
# 157 x:  938 Y  455  Text
# 158 x:  938 Y  455  Text Lugar
# 159 x:  979 Y  455  Text de
# 160 x:  999 Y  458  Text carga:
# 161 x:  1043 Y  455  Text TRUCK
# 162 x:  1097 Y  455  Text B/S-SunocoBrownsville-MX
# 163 x:  938 Y  475  Text
# 164 x:  938 Y  475  Text
# 165 x:  938 Y  475  Text Destino:
# 166 x:  994 Y  475  Text 4000207
# 167 x:  1055 Y  482  Text -
# 168 x:  1065 Y  475  Text PETROLIFEROS
# 169 x:  1181 Y  475  Text LOBO-MX-EXPT
# 170 x:  1294 Y  475  Text ONLY,MEX
# 171 x:  938 Y  495  Text
# 172 x:  938 Y  495  Text Fecha
# 173 x:  982 Y  495  Text BOL:
# 174 x:  1020 Y  495  Text 13/02/2023
# 175 x:  938 Y  515  Text
# 176 x:  938 Y  515  Text
# 177 x:  938 Y  515  Text Número
# 178 x:  993 Y  515  Text de
# 179 x:  1014 Y  515  Text BOL:
# 180 x:  1052 Y  515  Text 10771
# 181 x:  777 Y  599  Text
# 182 x:  787 Y  599  Text
# 183 x:  787 Y  599  Text
# 184 x:  787 Y  599  Text Objeto
# 185 x:  894 Y  609  Text Clave:
# 186 x:  799 Y  629  Text
# 187 x:  799 Y  629  Text Imp
# 188 x:  889 Y  629  Text unidad
# 189 x:  793 Y  656  Text
# 190 x:  793 Y  656  Text 02-Si
# 191 x:  881 Y  656  Text ¡STILL
# 192 x:  928 Y  656  Text itro
# 193 x:  1007 Y  656  Text 120
# 194 x:  778 Y  675  Text
# 195 x:  778 Y  675  Text
# 196 x:  778 Y  675  Text objeto
# 197 x:  829 Y  675  Text de,
# 198 x:  883 Y  675  Text estándar
# 199 x:  777 Y  694  Text
# 200 x:  777 Y  694  Text
# 201 x:  777 Y  694  Text impuesto
# 202 x:  993 Y  618  Text
# 203 x:  993 Y  618  Text
# 204 x:  993 Y  618  Text
# 205 x:  993 Y  618  Text Unidad
# 206 x:  1080 Y  618  Text Valor
# 207 x:  1127 Y  618  Text Unitario
# 208 x:  1378 Y  618  Text Importe
# 209 x:  1109 Y  655  Text
# 210 x:  1109 Y  655  Text
# 211 x:  1109 Y  655  Text
# 212 x:  1109 Y  655  Text $16.717313
# 213 x:  1346 Y  655  Text $475,973.28
# 214 x:  318 Y  731  Text
# 215 x:  318 Y  731  Text
# 216 x:  318 Y  731  Text
# 217 x:  318 Y  731  Text
# 218 x:  318 Y  731  Text
# 219 x:  318 Y  731  Text
# 220 x:  318 Y  731  Text
# 221 x:  318 Y  731  Text
# 222 x:  410 Y  727  Text
# 223 x:  410 Y  727  Text
# 224 x:  410 Y  727  Text
# 225 x:  410 Y  738  Text TRASLADO:
# 226 x:  501 Y  738  Text Base:
# 227 x:  544 Y  738  Text 461097.32
# 228 x:  622 Y  738  Text Impuesto:
# 229 x:  695 Y  738  Text 002-IVA
# 230 x:  751 Y  738  Text Tipo
# 231 x:  786 Y  738  Text de
# 232 x:  807 Y  738  Text factor:
# 233 x:  857 Y  738  Text Tasa
# 234 x:  891 Y  738  Text Tasa
# 235 x:  928 Y  741  Text o
# 236 x:  942 Y  739  Text cuota:
# 237 x:  989 Y  738  Text 8.00%
# 238 x:  1035 Y  738  Text Importe:
# 239 x:  1097 Y  737  Text $36,887.79
# 240 x:  1169 Y  727  Text 1]
# 241 x:  318 Y  760  Text
# 242 x:  318 Y  760  Text
# 243 x:  318 Y  760  Text
# 244 x:  318 Y  760  Text
# 245 x:  76 Y  871  Text
# 246 x:  76 Y  871  Text
# 247 x:  76 Y  871  Text
# 248 x:  76 Y  871  Text Traslado
# 249 x:  656 Y  870  Text
# 250 x:  656 Y  870  Text
# 251 x:  656 Y  870  Text
# 252 x:  656 Y  871  Text Base:
# 253 x:  705 Y  870  Text $461,097.32
# 254 x:  809 Y  871  Text Impuesto:
# 255 x:  893 Y  871  Text 002-IVA
# 256 x:  958 Y  871  Text Tipo
# 257 x:  998 Y  871  Text de
# 258 x:  1022 Y  871  Text factor:
# 259 x:  1079 Y  871  Text Tasa
# 260 x:  1120 Y  871  Text Tasa
# 261 x:  1162 Y  874  Text o
# 262 x:  1177 Y  871  Text cuota:
# 263 x:  1233 Y  871  Text 8.00%
# 264 x:  1210 Y  848  Text
# 265 x:  1210 Y  848  Text
# 266 x:  1210 Y  848  Text
# 267 x:  1210 Y  849  Text Subtotal
# 268 x:  1347 Y  848  Text $475,973.28
# 269 x:  1357 Y  870  Text
# 270 x:  1357 Y  870  Text $36,887.79
# 271 x:  73 Y  890  Text
# 272 x:  73 Y  890  Text
# 273 x:  73 Y  890  Text
# 274 x:  73 Y  890  Text
# 275 x:  76 Y  897  Text
# 276 x:  76 Y  897  Text
# 277 x:  76 Y  897  Text
# 278 x:  76 Y  897  Text Importe
# 279 x:  143 Y  900  Text con
# 280 x:  178 Y  897  Text letra:
# 281 x:  223 Y  897  Text QUINIENTOS
# 282 x:  334 Y  897  Text DOCE
# 283 x:  387 Y  897  Text MIL
# 284 x:  420 Y  897  Text OCHOCIENTOS
# 285 x:  551 Y  897  Text SESENTA
# 286 x:  634 Y  893  Text Y
# 287 x:  650 Y  897  Text UN
# 288 x:  679 Y  897  Text PESOS
# 289 x:  741 Y  897  Text 07/100
# 290 x:  803 Y  897  Text MXN
# 291 x:  1240 Y  897  Text Total
# 292 x:  1156 Y  896  Text
# 293 x:  1156 Y  896  Text
# 294 x:  1347 Y  896  Text
# 295 x:  1347 Y  896  Text $512,861.07
# 296 x:  1214 Y  910  Text
# 297 x:  1214 Y  910  Text Moneda
# 298 x:  1404 Y  920  Text MXN
# 299 x:  1156 Y  942  Text
# 300 x:  1156 Y  942  Text Tipo
# 301 x:  1194 Y  942  Text de
# 302 x:  1219 Y  942  Text cambio
# 303 x:  1433 Y  942  Text 1
# 304 x:  73 Y  969  Text
# 305 x:  73 Y  969  Text
# 306 x:  73 Y  969  Text
# 307 x:  73 Y  969  Text
# 308 x:  75 Y  982  Text
# 309 x:  75 Y  982  Text
# 310 x:  75 Y  982  Text
# 311 x:  75 Y  982  Text Cadena
# 312 x:  132 Y  982  Text Original
# 313 x:  190 Y  982  Text del
# 314 x:  216 Y  982  Text Complemento
# 315 x:  317 Y  982  Text de
# 316 x:  339 Y  982  Text Certificación
# 317 x:  431 Y  982  Text Digital
# 318 x:  479 Y  982  Text del
# 319 x:  505 Y  982  Text SAT:
# 320 x:  543 Y  982  Text |11.112£7306F9-9511-4238-B84A-6CF5CE4CEB09|2023-02-
# 321 x:  75 Y  999  Text
# 322 x:  75 Y  999  Text 14709-25:42|SSTO60807KU0|Egm1tzIZgJu2XS1q+bGnXODrCB9plyKj1JuZt+MBN/SgPwwHTtsTbq46019Vdctu2p1CESytuce5H1jSeeloSTJAXSXXK5D24ApD308CpKalaRNhWKuDtdd13BCbJOwcwo/ynpWa
# 323 x:  75 Y  1015  Text
# 324 x:  75 Y  1015  Text
# 325 x:  75 Y  1015  Text
# 326 x:  75 Y  1005  Text UJGNFLeBSrJ1+Mj5F7alaRoyUtL
# 327 x:  298 Y  1005  Text PxaqC8M2iriNR+yK4zCXpgamm2g7tPz!
# 328 x:  84 Y  1033  Text
# 329 x:  84 Y  1037  Text A
# 330 x:  213 Y  1036  Text A
# 331 x:  498 Y  1033  Text 2
# 332 x:  455 Y  1048  Text
# 333 x:  455 Y  1048  Text
# 334 x:  455 Y  1048  Text
# 335 x:  455 Y  1048  Text o
# 336 x:  547 Y  1015  Text
# 337 x:  547 Y  1015  Text
# 338 x:  547 Y  1015  Text
# 339 x:  543 Y  1008  Text 'FZKhIF24nX2XFOOY
# 340 x:  681 Y  1015  Text QwcyLLV5dkav8AOgvZ56vQmy0WjPwzmDAAZb5bcAN4GyfFAe+S7WNKNWCjCKk3CCDN74PtU7eQsrK3IETYR
# 341 x:  1694 Y  46  Text
# 342 x:  1694 Y  46  Text
# 343 x:  1694 Y  46  Text
# 344 x:  1694 Y  46  Text 10)
# 345 x:  1791 Y  55  Text Iniciar
# 346 x:  1845 Y  55  Text sesión
# 347 x:  1793 Y  92  Text
# 348 x:  1793 Y  92  Text A
# 349 x:  1881 Y  92  Text %
# 350 x:  1822 Y  137  Text
# 351 x:  1822 Y  137  Text (cerrar
# 352 x:  1902 Y  142  Text )
# 353 x:  1549 Y  197  Text
# 354 x:  1549 Y  197  Text
# 355 x:  1549 Y  197  Text
# 356 x:  1549 Y  197  Text FORMATO
# 357 x:  1554 Y  219  Text
# 358 x:  1554 Y  219  Text
# 359 x:  1554 Y  219  Text
# 360 x:  1554 Y  219  Text Arial
# 361 x:  1881 Y  219  Text ER
# 362 x:  1548 Y  513  Text
# 363 x:  1548 Y  513  Text
# 364 x:  1548 Y  513  Text
# 365 x:  1548 Y  513  Text OBJETOS
# 366 x:  1549 Y  663  Text
# 367 x:  1549 Y  663  Text
# 368 x:  1549 Y  663  Text
# 369 x:  1549 Y  663  Text DOCUMENTOS
# 370 x:  1635 Y  663  Text DIGITALIZADOS
# 371 x:  1550 Y  686  Text
# 372 x:  1550 Y  686  Text
# 373 x:  1550 Y  686  Text
# 374 x:  1550 Y  686  Text $
# 375 x:  1596 Y  691  Text Configuración
# 376 x:  1548 Y  774  Text
# 377 x:  1548 Y  770  Text
# 378 x:  1576 Y  774  Text
# 379 x:  1576 Y  774  Text Mostrar
# 380 x:  1630 Y  766  Text cuadro:
# 381 x:  1548 Y  799  Text
# 382 x:  1548 Y  799  Text KO
# 383 x:  1576 Y  803  Text Restringir
# 384 x:  1635 Y  795  Text la
# 385 x:  1652 Y  795  Text edi
# 386 x:  1805 Y  1046  Text
# 387 x:  1805 Y  1046  Text
# 388 x:  1805 Y  1046  Text
# 389 x:  1805 Y  1036  Text 11:51
# 390 x:  1836 Y  1036  Text a.m.
# 391 x:  0 Y  25  Text
# 392 x:  0 Y  25  Text
# 393 x:  0 Y  25  Text
# 394 x:  0 Y  25  Text
# 1 x:  0 Y  0  Text
# 2 x:  7 Y  7  Text
# 3 x:  7 Y  7  Text
# 4 x:  30 Y  7  Text
# 5 x:  30 Y  7  Text sECFD_20230214_092414.pdf
# 6 x:  176 Y  0  Text -
# 7 x:  183 Y  7  Text Adobe
# 8 x:  221 Y  7  Text Acrobat
# 9 x:  267 Y  7  Text Pro
# 10 x:  288 Y  7  Text DC
# 11 x:  7 Y  28  Text
# 12 x:  7 Y  28  Text Archivo
# 13 x:  63 Y  28  Text Edición
# 14 x:  115 Y  28  Text Ver
# 15 x:  145 Y  28  Text Ventana
# 16 x:  201 Y  28  Text Ayuda
# 17 x:  0 Y  10  Text
# 18 x:  0 Y  10  Text
# 19 x:  0 Y  10  Text
# 20 x:  0 Y  10  Text
# 21 x:  302 Y  10  Text
# 22 x:  21 Y  145  Text
# 23 x:  21 Y  145  Text
# 24 x:  21 Y  145  Text
# 25 x:  21 Y  145  Text Editar
# 26 x:  71 Y  145  Text PDF
# 27 x:  291 Y  262  Text
# 28 x:  291 Y  262  Text
# 29 x:  291 Y  262  Text
# 30 x:  291 Y  262  Text VALERO
# 31 x:  398 Y  262  Text MARKETING
# 32 x:  549 Y  262  Text AND
# 33 x:  609 Y  262  Text SUPPLY
# 34 x:  711 Y  262  Text DE
# 35 x:  751 Y  262  Text MEXICO
# 36 x:  292 Y  323  Text
# 37 x:  292 Y  323  Text
# 38 x:  292 Y  323  Text
# 39 x:  292 Y  323  Text RFC:
# 40 x:  329 Y  323  Text VMS16042911A.
# 41 x:  292 Y  343  Text
# 42 x:  292 Y  343  Text
# 43 x:  292 Y  343  Text
# 44 x:  292 Y  343  Text Régimen
# 45 x:  354 Y  343  Text Fiscal:
# 46 x:  400 Y  343  Text 601-General
# 47 x:  484 Y  343  Text de
# 48 x:  505 Y  343  Text Ley
# 49 x:  532 Y  343  Text Personas
# 50 x:  597 Y  343  Text Morales
# 51 x:  292 Y  363  Text
# 52 x:  292 Y  363  Text Lugar,
# 53 x:  335 Y  363  Text fecha
# 54 x:  375 Y  366  Text y
# 55 x:  387 Y  363  Text hora
# 56 x:  419 Y  363  Text de
# 57 x:  440 Y  363  Text expedición:
# 58 x:  517 Y  363  Text 87440
# 59 x:  563 Y  363  Text 14/02/2023
# 60 x:  642 Y  363  Text 09:24:14
# 61 x:  760 Y  92  Text
# 62 x:  760 Y  92  Text
# 63 x:  793 Y  92  Text
# 64 x:  793 Y  92  Text ¡IMXUMONO)
# 65 x:  760 Y  139  Text
# 66 x:  760 Y  139  Text TU0oOCAR
# 67 x:  76 Y  403  Text
# 68 x:  76 Y  403  Text
# 69 x:  76 Y  403  Text
# 70 x:  76 Y  403  Text CEI
# 71 x:  88 Y  455  Text
# 72 x:  88 Y  455  Text
# 73 x:  88 Y  455  Text
# 74 x:  88 Y  455  Text PETROLIFEROS
# 75 x:  204 Y  455  Text LOBO
# 76 x:  88 Y  475  Text
# 77 x:  88 Y  475  Text
# 78 x:  88 Y  475  Text RFC:
# 79 x:  126 Y  475  Text PLO170306G79
# 80 x:  88 Y  495  Text
# 81 x:  88 Y  495  Text
# 82 x:  88 Y  495  Text Régimen
# 83 x:  150 Y  495  Text Fiscal:
# 84 x:  196 Y  495  Text 601-General
# 85 x:  280 Y  495  Text de
# 86 x:  301 Y  495  Text Ley
# 87 x:  328 Y  495  Text Personas
# 88 x:  393 Y  495  Text Morales
# 89 x:  88 Y  515  Text
# 90 x:  88 Y  515  Text Domicilio
# 91 x:  151 Y  515  Text Fiscal:
# 92 x:  197 Y  515  Text 64650
# 93 x:  88 Y  534  Text
# 94 x:  88 Y  534  Text
# 95 x:  88 Y  534  Text Uso
# 96 x:  118 Y  534  Text CFDI:
# 97 x:  159 Y  534  Text G01-Adquisición
# 98 x:  270 Y  534  Text de
# 99 x:  290 Y  534  Text mercancías.
# 100 x:  77 Y  568  Text
# 101 x:  77 Y  568  Text
# 102 x:  77 Y  568  Text
# 103 x:  77 Y  568  Text PRODUCTOS
# 104 x:  236 Y  568  Text /
# 105 x:  250 Y  568  Text SERVICIOS
# 106 x:  318 Y  609  Text
# 107 x:  318 Y  609  Text
# 108 x:  318 Y  609  Text
# 109 x:  318 Y  609  Text Clave
# 110 x:  369 Y  609  Text Prod/
# 111 x:  332 Y  629  Text
# 112 x:  332 Y  629  Text Servicio
# 113 x:  107 Y  656  Text
# 114 x:  107 Y  656  Text
# 115 x:  107 Y  656  Text
# 116 x:  107 Y  656  Text 28471.877
# 117 x:  195 Y  656  Text 87CON11.5.
# 118 x:  325 Y  656  Text 15101514-
# 119 x:  440 Y  656  Text 87
# 120 x:  464 Y  656  Text Oct
# 121 x:  495 Y  656  Text Convencional
# 122 x:  603 Y  656  Text 11.5
# 123 x:  639 Y  656  Text RVP
# 124 x:  677 Y  663  Text -
# 125 x:  688 Y  656  Text H/20054/'
# 126 x:  76 Y  614  Text
# 127 x:  76 Y  614  Text
# 128 x:  76 Y  614  Text
# 129 x:  76 Y  614  Text Cantidad
# 130 x:  194 Y  618  Text Clave
# 131 x:  441 Y  618  Text Descri
# 132 x:  230 Y  675  Text
# 133 x:  230 Y  675  Text
# 134 x:  230 Y  675  Text
# 135 x:  230 Y  675  Text M2
# 136 x:  303 Y  675  Text
# 137 x:  303 Y  675  Text
# 138 x:  303 Y  675  Text
# 139 x:  303 Y  675  Text Gasolina
# 140 x:  389 Y  675  Text regular
# 141 x:  440 Y  675  Text COM/2017
# 142 x:  778 Y  675  Text objeto
# 143 x:  829 Y  675  Text de
# 144 x:  322 Y  694  Text
# 145 x:  322 Y  697  Text menora
# 146 x:  389 Y  694  Text 91
# 147 x:  777 Y  694  Text impuesto
# 148 x:  335 Y  713  Text
# 149 x:  335 Y  713  Text octanos
# 150 x:  938 Y  455  Text
# 151 x:  938 Y  455  Text
# 152 x:  938 Y  455  Text
# 153 x:  938 Y  455  Text Lugar
# 154 x:  979 Y  455  Text de
# 155 x:  999 Y  458  Text carga:
# 156 x:  1043 Y  455  Text TRUCK
# 157 x:  1097 Y  455  Text B/S-SunocoBrownsville-MX
# 158 x:  938 Y  475  Text
# 159 x:  938 Y  475  Text
# 160 x:  938 Y  475  Text Destino:
# 161 x:  994 Y  475  Text 4000207
# 162 x:  1055 Y  482  Text -
# 163 x:  1065 Y  475  Text PETROLIFEROS
# 164 x:  1181 Y  475  Text LOBO-MX-EXPT
# 165 x:  1294 Y  475  Text ONLY,MEX
# 166 x:  938 Y  495  Text
# 167 x:  938 Y  495  Text Fecha
# 168 x:  982 Y  495  Text BOL:
# 169 x:  1020 Y  495  Text 13/02/2023
# 170 x:  938 Y  515  Text
# 171 x:  938 Y  515  Text
# 172 x:  938 Y  515  Text Número
# 173 x:  993 Y  515  Text de
# 174 x:  1014 Y  515  Text BOL:
# 175 x:  1052 Y  515  Text 10771
# 176 x:  889 Y  609  Text
# 177 x:  889 Y  609  Text
# 178 x:  894 Y  609  Text
# 179 x:  894 Y  609  Text Clave
# 180 x:  889 Y  629  Text
# 181 x:  889 Y  629  Text unidad
# 182 x:  881 Y  655  Text
# 183 x:  881 Y  655  Text
# 184 x:  881 Y  655  Text
# 185 x:  881 Y  656  Text STILL
# 186 x:  928 Y  656  Text itro,
# 187 x:  1007 Y  656  Text 120
# 188 x:  1109 Y  655  Text $16.717313
# 189 x:  1346 Y  655  Text $475,973.28
# 190 x:  883 Y  675  Text
# 191 x:  883 Y  675  Text estándar
# 192 x:  993 Y  618  Text
# 193 x:  993 Y  618  Text
# 194 x:  993 Y  618  Text
# 195 x:  993 Y  618  Text Unidad
# 196 x:  1080 Y  618  Text Valor
# 197 x:  1127 Y  618  Text Unitario
# 198 x:  1378 Y  618  Text Importe
# 199 x:  318 Y  731  Text
# 200 x:  318 Y  731  Text
# 201 x:  318 Y  731  Text
# 202 x:  318 Y  731  Text
# 203 x:  318 Y  731  Text
# 204 x:  318 Y  731  Text
# 205 x:  318 Y  731  Text
# 206 x:  318 Y  731  Text
# 207 x:  410 Y  727  Text
# 208 x:  410 Y  727  Text
# 209 x:  410 Y  727  Text
# 210 x:  410 Y  738  Text TRASLADO:
# 211 x:  501 Y  738  Text Base:
# 212 x:  544 Y  738  Text 461097.32
# 213 x:  622 Y  738  Text Impuesto:
# 214 x:  695 Y  738  Text 002-IVA
# 215 x:  751 Y  738  Text Tipo
# 216 x:  786 Y  738  Text de
# 217 x:  807 Y  738  Text factor:
# 218 x:  857 Y  738  Text Tasa
# 219 x:  891 Y  738  Text Tasa
# 220 x:  928 Y  741  Text o
# 221 x:  942 Y  739  Text cuota:
# 222 x:  989 Y  738  Text 8.00%
# 223 x:  1035 Y  738  Text Importe:
# 224 x:  1097 Y  737  Text $36,887.79
# 225 x:  1169 Y  727  Text 1]
# 226 x:  318 Y  760  Text
# 227 x:  318 Y  760  Text
# 228 x:  318 Y  760  Text
# 229 x:  318 Y  760  Text
# 230 x:  76 Y  871  Text
# 231 x:  76 Y  871  Text
# 232 x:  76 Y  871  Text
# 233 x:  76 Y  871  Text Traslado
# 234 x:  1210 Y  845  Text
# 235 x:  1210 Y  845  Text
# 236 x:  1210 Y  845  Text
# 237 x:  1210 Y  845  Text Subtotal
# 238 x:  1347 Y  848  Text $475,973.28
# 239 x:  656 Y  870  Text
# 240 x:  656 Y  870  Text
# 241 x:  656 Y  870  Text
# 242 x:  656 Y  871  Text Base:
# 243 x:  705 Y  870  Text $461,097.32
# 244 x:  809 Y  871  Text Impuesto:
# 245 x:  893 Y  871  Text 002-IVA
# 246 x:  958 Y  871  Text Tipo
# 247 x:  998 Y  871  Text de
# 248 x:  1022 Y  871  Text factor:
# 249 x:  1079 Y  871  Text Tasa
# 250 x:  1120 Y  871  Text Tasa
# 251 x:  1162 Y  874  Text o
# 252 x:  1177 Y  871  Text cuota:
# 253 x:  1233 Y  871  Text 8.00%
# 254 x:  1357 Y  870  Text $36,887.79
# 255 x:  74 Y  890  Text
# 256 x:  74 Y  890  Text
# 257 x:  74 Y  890  Text
# 258 x:  74 Y  890  Text
# 259 x:  76 Y  894  Text
# 260 x:  76 Y  894  Text
# 261 x:  76 Y  894  Text
# 262 x:  76 Y  897  Text Importe
# 263 x:  143 Y  900  Text con
# 264 x:  178 Y  894  Text letra;]
# 265 x:  1156 Y  887  Text
# 266 x:  1156 Y  887  Text
# 267 x:  1240 Y  887  Text
# 268 x:  1240 Y  887  Text Total]
# 269 x:  1347 Y  896  Text $512,861.07
# 270 x:  1214 Y  910  Text
# 271 x:  1214 Y  910  Text Moneda
# 272 x:  1404 Y  920  Text MXN
# 273 x:  1156 Y  942  Text
# 274 x:  1156 Y  942  Text Tipo
# 275 x:  1194 Y  942  Text de
# 276 x:  1219 Y  942  Text cambio
# 277 x:  1433 Y  942  Text 1
# 278 x:  73 Y  969  Text
# 279 x:  73 Y  969  Text
# 280 x:  73 Y  969  Text
# 281 x:  73 Y  969  Text
# 282 x:  75 Y  982  Text
# 283 x:  75 Y  982  Text
# 284 x:  75 Y  982  Text
# 285 x:  75 Y  982  Text Cadena
# 286 x:  132 Y  982  Text Original
# 287 x:  190 Y  982  Text del
# 288 x:  216 Y  982  Text Complemento
# 289 x:  317 Y  982  Text de
# 290 x:  339 Y  982  Text Certificación
# 291 x:  431 Y  982  Text Digital
# 292 x:  479 Y  982  Text del
# 293 x:  505 Y  982  Text SAT:
# 294 x:  543 Y  982  Text |11.112£7306F9-9511-4238-B84A-6CF5CE4CEB09|2023-02-
# 295 x:  75 Y  999  Text
# 296 x:  75 Y  999  Text 14709-25:42|SSTO60807KU0|Egm1tzIZgJu2XS1q+bGnXODrCB9plyKj1JuZt+MBN/SgPwwHTtsTbq46019Vdctu2p1CESytuce5H1jSeeloSTJAXSXXK5D24ApD308CpKalaRNhWKuDtdd13BCbJOwcwo/ynpWa
# 297 x:  455 Y  1048  Text
# 298 x:  455 Y  1048  Text
# 299 x:  455 Y  1048  Text
# 300 x:  455 Y  1048  Text o
# 301 x:  75 Y  1015  Text
# 302 x:  75 Y  1015  Text
# 303 x:  75 Y  1015  Text
# 304 x:  75 Y  1008  Text UJGNFLeBSrJ1+Mj5F7alaRoyUtl
# 305 x:  295 Y  1015  Text PxaqC8M2irtNR+yK4zCXpgarm2g7tPzFZKhIF24nX2XF00YQwcyLLV5dkxvBAOgvZ56vOmy0WjPwzmDAAZb5bcAN4GyfFAe+STWNKNWC¡CKk3CCDN74PtU7eQsrKSIETYR
# 306 x:  114 Y  1033  Text
# 307 x:  114 Y  1035  Text PIN
# 308 x:  213 Y  1036  Text ds
# 309 x:  278 Y  1036  Text LaGiO
# 310 x:  390 Y  1034  Text Ao
# 311 x:  498 Y  1033  Text o
# 312 x:  1694 Y  46  Text
# 313 x:  1694 Y  46  Text
# 314 x:  1694 Y  46  Text
# 315 x:  1694 Y  46  Text 10)
# 316 x:  1791 Y  55  Text Iniciar
# 317 x:  1845 Y  55  Text sesión
# 318 x:  1793 Y  92  Text
# 319 x:  1793 Y  92  Text
# 320 x:  1793 Y  92  Text
# 321 x:  1793 Y  88  Text GA
# 322 x:  1842 Y  94  Text E
# 323 x:  1881 Y  92  Text ld
# 324 x:  1822 Y  137  Text
# 325 x:  1822 Y  137  Text
# 326 x:  1822 Y  137  Text
# 327 x:  1822 Y  137  Text (cerrar
# 328 x:  1902 Y  142  Text )
# 329 x:  1885 Y  231  Text
# 330 x:  1885 Y  231  Text
# 331 x:  1885 Y  231  Text
# 332 x:  1885 Y  231  Text EN
# 333 x:  1548 Y  513  Text
# 334 x:  1548 Y  513  Text
# 335 x:  1548 Y  513  Text
# 336 x:  1548 Y  513  Text OBJETOS
# 337 x:  1549 Y  663  Text
# 338 x:  1549 Y  663  Text
# 339 x:  1549 Y  663  Text
# 340 x:  1549 Y  663  Text DOCUMENTOS
# 341 x:  1635 Y  663  Text DIGITALIZADOS
# 342 x:  1550 Y  686  Text
# 343 x:  1550 Y  686  Text
# 344 x:  1550 Y  686  Text
# 345 x:  1550 Y  686  Text $
# 346 x:  1596 Y  691  Text Configuración
# 347 x:  1548 Y  774  Text
# 348 x:  1548 Y  770  Text
# 349 x:  1576 Y  774  Text
# 350 x:  1576 Y  774  Text Mostrar
# 351 x:  1630 Y  766  Text cuadro:
# 352 x:  1548 Y  799  Text
# 353 x:  1548 Y  799  Text KO
# 354 x:  1576 Y  803  Text Restringir
# 355 x:  1635 Y  795  Text la
# 356 x:  1652 Y  795  Text edi
# 357 x:  0 Y  25  Text
# 358 x:  0 Y  25  Text
# 359 x:  0 Y  25  Text
# 360 x:  0 Y  25  Text
# 1 x:  0 Y  0  Text
# 2 x:  7 Y  7  Text
# 3 x:  7 Y  7  Text
# 4 x:  30 Y  7  Text
# 5 x:  30 Y  7  Text sECFD_20230214_092414.pdf
# 6 x:  176 Y  0  Text -
# 7 x:  183 Y  7  Text Adobe
# 8 x:  221 Y  7  Text Acrobat
# 9 x:  267 Y  7  Text Pro
# 10 x:  288 Y  7  Text DC
# 11 x:  7 Y  28  Text
# 12 x:  7 Y  28  Text Archivo
# 13 x:  63 Y  28  Text Edición
# 14 x:  115 Y  28  Text Ver
# 15 x:  145 Y  28  Text Ventana
# 16 x:  201 Y  28  Text Ayuda
# 17 x:  0 Y  10  Text
# 18 x:  0 Y  10  Text
# 19 x:  0 Y  10  Text
# 20 x:  0 Y  10  Text
# 21 x:  302 Y  10  Text
# 22 x:  21 Y  145  Text
# 23 x:  21 Y  145  Text
# 24 x:  21 Y  145  Text
# 25 x:  21 Y  145  Text Editar
# 26 x:  71 Y  145  Text PDF
# 27 x:  291 Y  262  Text
# 28 x:  291 Y  262  Text
# 29 x:  291 Y  262  Text
# 30 x:  291 Y  262  Text VALERO
# 31 x:  398 Y  262  Text MARKETING
# 32 x:  549 Y  262  Text AND
# 33 x:  609 Y  262  Text SUPPLY
# 34 x:  711 Y  262  Text DE
# 35 x:  751 Y  262  Text MEXICO
# 36 x:  292 Y  323  Text
# 37 x:  292 Y  323  Text
# 38 x:  292 Y  323  Text
# 39 x:  292 Y  323  Text RFC:
# 40 x:  329 Y  323  Text VMS16042911A.
# 41 x:  292 Y  343  Text
# 42 x:  292 Y  343  Text
# 43 x:  292 Y  343  Text
# 44 x:  292 Y  343  Text Régimen
# 45 x:  354 Y  343  Text Fiscal:
# 46 x:  400 Y  343  Text 601-General
# 47 x:  484 Y  343  Text de
# 48 x:  505 Y  343  Text Ley
# 49 x:  532 Y  343  Text Personas
# 50 x:  597 Y  343  Text Morales
# 51 x:  292 Y  363  Text
# 52 x:  292 Y  363  Text Lugar,
# 53 x:  335 Y  363  Text fecha
# 54 x:  375 Y  366  Text y
# 55 x:  387 Y  363  Text hora
# 56 x:  419 Y  363  Text de
# 57 x:  440 Y  363  Text expedición:
# 58 x:  517 Y  363  Text 87440
# 59 x:  563 Y  363  Text 14/02/2023
# 60 x:  642 Y  363  Text 09:24:14
# 61 x:  760 Y  92  Text
# 62 x:  760 Y  92  Text
# 63 x:  793 Y  92  Text
# 64 x:  793 Y  92  Text ¡IMXUMONO)
# 65 x:  760 Y  139  Text
# 66 x:  760 Y  139  Text TU0oOCAR
# 67 x:  76 Y  403  Text
# 68 x:  76 Y  403  Text
# 69 x:  76 Y  403  Text
# 70 x:  76 Y  403  Text CEI
# 71 x:  88 Y  455  Text
# 72 x:  88 Y  455  Text
# 73 x:  88 Y  455  Text
# 74 x:  88 Y  455  Text PETROLIFEROS
# 75 x:  204 Y  455  Text LOBO
# 76 x:  88 Y  475  Text
# 77 x:  88 Y  475  Text
# 78 x:  88 Y  475  Text RFC:
# 79 x:  126 Y  475  Text PLO170306G79
# 80 x:  88 Y  495  Text
# 81 x:  88 Y  495  Text
# 82 x:  88 Y  495  Text Régimen
# 83 x:  150 Y  495  Text Fiscal:
# 84 x:  196 Y  495  Text 601-General
# 85 x:  280 Y  495  Text de
# 86 x:  301 Y  495  Text Ley
# 87 x:  328 Y  495  Text Personas
# 88 x:  393 Y  495  Text Morales
# 89 x:  88 Y  515  Text
# 90 x:  88 Y  515  Text Domicilio
# 91 x:  151 Y  515  Text Fiscal:
# 92 x:  197 Y  515  Text 64650
# 93 x:  88 Y  534  Text
# 94 x:  88 Y  534  Text
# 95 x:  88 Y  534  Text Uso
# 96 x:  118 Y  534  Text CFDI:
# 97 x:  159 Y  534  Text G01-Adquisición
# 98 x:  270 Y  534  Text de
# 99 x:  290 Y  534  Text mercancías.
# 100 x:  77 Y  568  Text
# 101 x:  77 Y  568  Text
# 102 x:  77 Y  568  Text
# 103 x:  77 Y  568  Text PRODUCTOS
# 104 x:  236 Y  568  Text /
# 105 x:  250 Y  568  Text SERVICIOS
# 106 x:  318 Y  609  Text
# 107 x:  318 Y  609  Text
# 108 x:  318 Y  609  Text
# 109 x:  318 Y  609  Text Clave
# 110 x:  369 Y  609  Text Prod/
# 111 x:  332 Y  629  Text
# 112 x:  332 Y  629  Text Servicio
# 113 x:  107 Y  656  Text
# 114 x:  107 Y  656  Text
# 115 x:  107 Y  656  Text
# 116 x:  107 Y  656  Text 28471.877
# 117 x:  195 Y  656  Text 87CON11.5.
# 118 x:  325 Y  656  Text 15101514-
# 119 x:  440 Y  656  Text 87
# 120 x:  464 Y  656  Text Oct
# 121 x:  495 Y  656  Text Convencional
# 122 x:  603 Y  656  Text 11.5
# 123 x:  639 Y  656  Text RVP
# 124 x:  677 Y  663  Text -
# 125 x:  688 Y  656  Text H/20054/'
# 126 x:  76 Y  614  Text
# 127 x:  76 Y  614  Text
# 128 x:  76 Y  614  Text
# 129 x:  76 Y  614  Text Cantidad
# 130 x:  194 Y  618  Text Clave
# 131 x:  441 Y  618  Text Descri
# 132 x:  230 Y  675  Text
# 133 x:  230 Y  675  Text
# 134 x:  230 Y  675  Text
# 135 x:  230 Y  675  Text M2
# 136 x:  303 Y  675  Text
# 137 x:  303 Y  675  Text
# 138 x:  303 Y  675  Text
# 139 x:  303 Y  675  Text Gasolina
# 140 x:  389 Y  675  Text regular
# 141 x:  440 Y  675  Text COM/2017
# 142 x:  778 Y  675  Text objeto
# 143 x:  829 Y  675  Text de
# 144 x:  322 Y  694  Text
# 145 x:  322 Y  697  Text menora
# 146 x:  389 Y  694  Text 91
# 147 x:  777 Y  694  Text impuesto
# 148 x:  335 Y  713  Text
# 149 x:  335 Y  713  Text octanos
# 150 x:  938 Y  455  Text
# 151 x:  938 Y  455  Text
# 152 x:  938 Y  455  Text
# 153 x:  938 Y  455  Text Lugar
# 154 x:  979 Y  455  Text de
# 155 x:  999 Y  458  Text carga:
# 156 x:  1043 Y  455  Text TRUCK
# 157 x:  1097 Y  455  Text B/S-SunocoBrownsville-MX
# 158 x:  938 Y  475  Text
# 159 x:  938 Y  475  Text
# 160 x:  938 Y  475  Text Destino:
# 161 x:  994 Y  475  Text 4000207
# 162 x:  1055 Y  482  Text -
# 163 x:  1065 Y  475  Text PETROLIFEROS
# 164 x:  1181 Y  475  Text LOBO-MX-EXPT
# 165 x:  1294 Y  475  Text ONLY,MEX
# 166 x:  938 Y  495  Text
# 167 x:  938 Y  495  Text Fecha
# 168 x:  982 Y  495  Text BOL:
# 169 x:  1020 Y  495  Text 13/02/2023
# 170 x:  938 Y  515  Text
# 171 x:  938 Y  515  Text
# 172 x:  938 Y  515  Text Número
# 173 x:  993 Y  515  Text de
# 174 x:  1014 Y  515  Text BOL:
# 175 x:  1052 Y  515  Text 10771
# 176 x:  889 Y  609  Text
# 177 x:  889 Y  609  Text
# 178 x:  894 Y  609  Text
# 179 x:  894 Y  609  Text Clave
# 180 x:  889 Y  629  Text
# 181 x:  889 Y  629  Text unidad
# 182 x:  881 Y  655  Text
# 183 x:  881 Y  655  Text
# 184 x:  881 Y  655  Text
# 185 x:  881 Y  656  Text STILL
# 186 x:  928 Y  656  Text itro,
# 187 x:  1007 Y  656  Text 120
# 188 x:  1109 Y  655  Text $16.717313
# 189 x:  1346 Y  655  Text $475,973.28
# 190 x:  883 Y  675  Text
# 191 x:  883 Y  675  Text estándar
# 192 x:  993 Y  618  Text
# 193 x:  993 Y  618  Text
# 194 x:  993 Y  618  Text
# 195 x:  993 Y  618  Text Unidad
# 196 x:  1080 Y  618  Text Valor
# 197 x:  1127 Y  618  Text Unitario
# 198 x:  1378 Y  618  Text Importe
# 199 x:  318 Y  731  Text
# 200 x:  318 Y  731  Text
# 201 x:  318 Y  731  Text
# 202 x:  318 Y  731  Text
# 203 x:  318 Y  731  Text
# 204 x:  318 Y  731  Text
# 205 x:  318 Y  731  Text
# 206 x:  318 Y  731  Text
# 207 x:  410 Y  735  Text
# 208 x:  410 Y  735  Text
# 209 x:  410 Y  735  Text
# 210 x:  410 Y  738  Text TRASLADO:
# 211 x:  501 Y  738  Text Base:Impuesto:
# 212 x:  613 Y  738  Text 002-1VA
# 213 x:  670 Y  738  Text Tipo
# 214 x:  705 Y  738  Text de
# 215 x:  726 Y  738  Text factor:
# 216 x:  776 Y  738  Text Tasa
# 217 x:  812 Y  738  Text Tasa
# 218 x:  850 Y  741  Text o
# 219 x:  863 Y  739  Text cuota
# 220 x:  907 Y  735  Text Importe]
# 221 x:  318 Y  760  Text
# 222 x:  318 Y  760  Text
# 223 x:  318 Y  760  Text
# 224 x:  318 Y  760  Text
# 225 x:  76 Y  871  Text
# 226 x:  76 Y  871  Text
# 227 x:  76 Y  871  Text
# 228 x:  76 Y  871  Text Traslado
# 229 x:  1210 Y  845  Text
# 230 x:  1210 Y  845  Text
# 231 x:  1210 Y  845  Text
# 232 x:  1210 Y  845  Text Subtotal
# 233 x:  1347 Y  848  Text $475,973.28
# 234 x:  656 Y  870  Text
# 235 x:  656 Y  870  Text
# 236 x:  656 Y  870  Text
# 237 x:  656 Y  871  Text Base:
# 238 x:  705 Y  870  Text $461,097.32
# 239 x:  809 Y  871  Text Impuesto:
# 240 x:  893 Y  871  Text 002-IVA
# 241 x:  958 Y  871  Text Tipo
# 242 x:  998 Y  871  Text de
# 243 x:  1022 Y  871  Text factor:
# 244 x:  1079 Y  871  Text Tasa
# 245 x:  1120 Y  871  Text Tasa
# 246 x:  1162 Y  874  Text o
# 247 x:  1177 Y  871  Text cuota:
# 248 x:  1233 Y  871  Text 8.00%
# 249 x:  1357 Y  870  Text $36,887.79
# 250 x:  73 Y  890  Text
# 251 x:  73 Y  890  Text
# 252 x:  73 Y  890  Text
# 253 x:  73 Y  890  Text
# 254 x:  76 Y  897  Text
# 255 x:  76 Y  897  Text
# 256 x:  76 Y  897  Text
# 257 x:  76 Y  897  Text Importe
# 258 x:  143 Y  900  Text con
# 259 x:  178 Y  897  Text letra:
# 260 x:  1156 Y  896  Text
# 261 x:  1156 Y  896  Text
# 262 x:  1240 Y  896  Text
# 263 x:  1240 Y  897  Text Total
# 264 x:  1347 Y  896  Text $512,861.07
# 265 x:  1214 Y  910  Text
# 266 x:  1214 Y  910  Text Moneda
# 267 x:  1404 Y  920  Text MXN
# 268 x:  1156 Y  942  Text
# 269 x:  1156 Y  942  Text Tipo
# 270 x:  1194 Y  942  Text de
# 271 x:  1219 Y  942  Text cambio
# 272 x:  1433 Y  942  Text 1
# 273 x:  73 Y  969  Text
# 274 x:  73 Y  969  Text
# 275 x:  73 Y  969  Text
# 276 x:  73 Y  969  Text
# 277 x:  75 Y  982  Text
# 278 x:  75 Y  982  Text
# 279 x:  75 Y  982  Text
# 280 x:  75 Y  982  Text Cadena
# 281 x:  132 Y  982  Text Original
# 282 x:  190 Y  982  Text del
# 283 x:  216 Y  982  Text Complemento
# 284 x:  317 Y  982  Text de
# 285 x:  339 Y  982  Text Certificación
# 286 x:  431 Y  982  Text Digital
# 287 x:  479 Y  982  Text del
# 288 x:  505 Y  982  Text SAT:
# 289 x:  543 Y  982  Text |11.112£7306F9-9511-4238-B84A-6CF5CE4CEB09|2023-02-
# 290 x:  75 Y  999  Text
# 291 x:  75 Y  999  Text 14709-25:42|SSTO60807KU0|Egm1tzIZgJu2XS1q+bGnXODrCB9plyKj1JuZt+MBN/SgPwwHTtsTbq46019Vdctu2p1CESytuce5H1jSeeloSTJAXSXXK5D24ApD308CpKalaRNhWKuDtdd13BCbJOwcwo/ynpWa
# 292 x:  455 Y  1048  Text
# 293 x:  455 Y  1048  Text
# 294 x:  455 Y  1048  Text
# 295 x:  455 Y  1048  Text o
# 296 x:  75 Y  1015  Text
# 297 x:  75 Y  1015  Text
# 298 x:  75 Y  1015  Text
# 299 x:  75 Y  1008  Text UJGNFLeBSrJ1+Mj5F7alaRoyUtl
# 300 x:  295 Y  1015  Text PxaqC8M2irtNR+yK4zCXpgarm2g7tPzFZKhIF24nX2XF00YQwcyLLV5dkxvBAOgvZ56vOmy0WjPwzmDAAZb5bcAN4GyfFAe+STWNKNWC¡CKk3CCDN74PtU7eQsrKSIETYR
# 301 x:  114 Y  1033  Text
# 302 x:  114 Y  1035  Text PIN
# 303 x:  213 Y  1036  Text ds
# 304 x:  278 Y  1036  Text LaGiO
# 305 x:  390 Y  1034  Text Ao
# 306 x:  498 Y  1033  Text o
# 307 x:  1791 Y  55  Text
# 308 x:  1791 Y  55  Text
# 309 x:  1791 Y  55  Text
# 310 x:  1791 Y  55  Text Iniciar
# 311 x:  1845 Y  55  Text sesión
# 312 x:  1793 Y  92  Text
# 313 x:  1793 Y  92  Text
# 314 x:  1793 Y  92  Text
# 315 x:  1793 Y  88  Text GA
# 316 x:  1842 Y  94  Text E
# 317 x:  1881 Y  92  Text ld
# 318 x:  1822 Y  137  Text
# 319 x:  1822 Y  137  Text
# 320 x:  1822 Y  137  Text
# 321 x:  1822 Y  137  Text (cerrar
# 322 x:  1902 Y  142  Text )
# 323 x:  1885 Y  231  Text
# 324 x:  1885 Y  231  Text
# 325 x:  1885 Y  231  Text
# 326 x:  1885 Y  231  Text EN
# 327 x:  1548 Y  513  Text
# 328 x:  1548 Y  513  Text
# 329 x:  1548 Y  513  Text
# 330 x:  1548 Y  513  Text OBJETOS
# 331 x:  1549 Y  663  Text
# 332 x:  1549 Y  663  Text
# 333 x:  1549 Y  663  Text
# 334 x:  1549 Y  663  Text DOCUMENTOS
# 335 x:  1635 Y  663  Text DIGITALIZADOS
# 336 x:  1550 Y  686  Text
# 337 x:  1550 Y  686  Text
# 338 x:  1550 Y  686  Text
# 339 x:  1550 Y  686  Text $
# 340 x:  1596 Y  691  Text Configuración
# 341 x:  1548 Y  774  Text
# 342 x:  1548 Y  770  Text
# 343 x:  1576 Y  774  Text
# 344 x:  1576 Y  774  Text Mostrar
# 345 x:  1630 Y  766  Text cuadro:
# 346 x:  1548 Y  799  Text
# 347 x:  1548 Y  799  Text KO
# 348 x:  1576 Y  803  Text Restringir
# 349 x:  1635 Y  795  Text la
# 350 x:  1652 Y  795  Text edi
# 351 x:  0 Y  25  Text
# 352 x:  0 Y  25  Text
# 353 x:  0 Y  25  Text
# 354 x:  0 Y  25  Text
# 1 x:  0 Y  0  Text
# 2 x:  30 Y  7  Text
# 3 x:  30 Y  7  Text
# 4 x:  30 Y  7  Text
# 5 x:  30 Y  7  Text sECFD_20230214_092414.pdf
# 6 x:  176 Y  0  Text -
# 7 x:  183 Y  7  Text Adobe
# 8 x:  221 Y  7  Text Acrobat
# 9 x:  267 Y  7  Text Pro
# 10 x:  288 Y  7  Text DC
# 11 x:  63 Y  28  Text
# 12 x:  63 Y  28  Text
# 13 x:  63 Y  28  Text
# 14 x:  63 Y  28  Text Edición
# 15 x:  115 Y  28  Text Ver
# 16 x:  145 Y  28  Text Ventana
# 17 x:  201 Y  28  Text Ayuda
# 18 x:  793 Y  92  Text
# 19 x:  793 Y  92  Text
# 20 x:  793 Y  92  Text
# 21 x:  793 Y  92  Text ¡IXUMOO)
# 22 x:  21 Y  139  Text
# 23 x:  21 Y  139  Text
# 24 x:  21 Y  139  Text
# 25 x:  21 Y  145  Text Editar
# 26 x:  75 Y  145  Text PDF
# 27 x:  760 Y  139  Text DTuASR
# 28 x:  291 Y  262  Text
# 29 x:  291 Y  262  Text
# 30 x:  291 Y  262  Text
# 31 x:  291 Y  262  Text VALERO
# 32 x:  398 Y  262  Text MARKETING
# 33 x:  549 Y  262  Text AND
# 34 x:  609 Y  262  Text SUPPLY
# 35 x:  711 Y  262  Text DE
# 36 x:  751 Y  262  Text MEXICO
# 37 x:  292 Y  323  Text
# 38 x:  292 Y  323  Text
# 39 x:  292 Y  323  Text
# 40 x:  292 Y  323  Text RFC:
# 41 x:  329 Y  323  Text VMS16042911A.
# 42 x:  292 Y  343  Text
# 43 x:  292 Y  343  Text Régimen
# 44 x:  354 Y  343  Text Fiscal:
# 45 x:  400 Y  343  Text 601-General
# 46 x:  484 Y  343  Text de
# 47 x:  505 Y  343  Text Ley
# 48 x:  532 Y  343  Text Personas
# 49 x:  597 Y  343  Text Morales
# 50 x:  292 Y  363  Text
# 51 x:  292 Y  363  Text Lugar,
# 52 x:  335 Y  363  Text fecha
# 53 x:  375 Y  366  Text y
# 54 x:  387 Y  363  Text hora
# 55 x:  419 Y  363  Text de
# 56 x:  440 Y  363  Text expedición:
# 57 x:  517 Y  363  Text 87440
# 58 x:  563 Y  363  Text 14/02/2023
# 59 x:  642 Y  363  Text 09:24:14
# 60 x:  76 Y  403  Text
# 61 x:  76 Y  403  Text
# 62 x:  76 Y  403  Text
# 63 x:  76 Y  403  Text CEI
# 64 x:  88 Y  455  Text
# 65 x:  88 Y  455  Text
# 66 x:  88 Y  455  Text
# 67 x:  88 Y  455  Text PETROLIFEROS
# 68 x:  204 Y  455  Text LOBO
# 69 x:  88 Y  475  Text
# 70 x:  88 Y  475  Text
# 71 x:  88 Y  475  Text RFC:
# 72 x:  126 Y  475  Text PLO170306G79
# 73 x:  88 Y  495  Text
# 74 x:  88 Y  495  Text
# 75 x:  88 Y  495  Text Régimen
# 76 x:  150 Y  495  Text Fiscal:
# 77 x:  196 Y  495  Text 601-General
# 78 x:  280 Y  495  Text de
# 79 x:  301 Y  495  Text Ley
# 80 x:  328 Y  495  Text Personas
# 81 x:  393 Y  495  Text Morales
# 82 x:  88 Y  515  Text
# 83 x:  88 Y  515  Text Domicilio
# 84 x:  151 Y  515  Text Fiscal:
# 85 x:  197 Y  515  Text 64650
# 86 x:  88 Y  534  Text
# 87 x:  88 Y  534  Text
# 88 x:  88 Y  534  Text Uso
# 89 x:  118 Y  534  Text CFDI:
# 90 x:  159 Y  534  Text G01-Adquisición
# 91 x:  270 Y  534  Text de
# 92 x:  290 Y  534  Text mercancías.
# 93 x:  77 Y  568  Text
# 94 x:  77 Y  568  Text
# 95 x:  77 Y  568  Text
# 96 x:  77 Y  568  Text PRODUCTOS
# 97 x:  236 Y  568  Text /
# 98 x:  250 Y  568  Text SERVICIOS
# 99 x:  76 Y  599  Text
# 100 x:  76 Y  599  Text
# 101 x:  76 Y  599  Text
# 102 x:  76 Y  618  Text Cantidad
# 103 x:  194 Y  618  Text Clave
# 104 x:  318 Y  609  Text Clave
# 105 x:  369 Y  609  Text Prod
# 106 x:  441 Y  618  Text Descripció
# 107 x:  787 Y  599  Text Objeto
# 108 x:  894 Y  609  Text Clave:
# 109 x:  332 Y  619  Text
# 110 x:  332 Y  619  Text Servicio
# 111 x:  799 Y  629  Text Imp
# 112 x:  889 Y  629  Text unidad
# 113 x:  107 Y  655  Text
# 114 x:  107 Y  656  Text 28471.877
# 115 x:  195 Y  656  Text 87CON11.5.
# 116 x:  325 Y  656  Text 115101514-|
# 117 x:  440 Y  656  Text 87
# 118 x:  464 Y  656  Text Oct
# 119 x:  495 Y  656  Text Convencional
# 120 x:  603 Y  656  Text 11.5
# 121 x:  639 Y  656  Text RVP
# 122 x:  677 Y  663  Text -
# 123 x:  688 Y  656  Text H/20054/
# 124 x:  793 Y  656  Text 02-SÍl
# 125 x:  881 Y  656  Text ¡STI
# 126 x:  912 Y  656  Text Litro,
# 127 x:  1007 Y  656  Text 120
# 128 x:  1109 Y  655  Text $16.717313
# 129 x:  1346 Y  655  Text $475,973.28
# 130 x:  230 Y  675  Text
# 131 x:  230 Y  675  Text M2
# 132 x:  303 Y  675  Text Gasolina
# 133 x:  389 Y  675  Text regular
# 134 x:  440 Y  675  Text COM/2017
# 135 x:  778 Y  675  Text objeto
# 136 x:  829 Y  675  Text de,
# 137 x:  864 Y  666  Text —
# 138 x:  883 Y  675  Text [estándar
# 139 x:  322 Y  694  Text
# 140 x:  322 Y  697  Text menora
# 141 x:  389 Y  694  Text 91
# 142 x:  777 Y  694  Text impuesto
# 143 x:  335 Y  713  Text
# 144 x:  335 Y  713  Text octanos
# 145 x:  938 Y  455  Text
# 146 x:  938 Y  455  Text
# 147 x:  938 Y  455  Text
# 148 x:  938 Y  455  Text Lugar
# 149 x:  979 Y  455  Text de
# 150 x:  999 Y  458  Text carga:
# 151 x:  1043 Y  455  Text TRUCK
# 152 x:  1097 Y  455  Text B/S-SunocoBrownsville-MX
# 153 x:  938 Y  475  Text
# 154 x:  938 Y  475  Text
# 155 x:  938 Y  475  Text Destino:
# 156 x:  994 Y  475  Text 4000207
# 157 x:  1055 Y  482  Text -
# 158 x:  1065 Y  475  Text PETROLIFEROS
# 159 x:  1181 Y  475  Text LOBO-MX-EXPT
# 160 x:  1294 Y  475  Text ONLY,MEX
# 161 x:  938 Y  495  Text
# 162 x:  938 Y  495  Text Fecha
# 163 x:  982 Y  495  Text BOL:
# 164 x:  1020 Y  495  Text 13/02/2023
# 165 x:  938 Y  515  Text
# 166 x:  938 Y  515  Text
# 167 x:  938 Y  515  Text Número
# 168 x:  993 Y  515  Text de
# 169 x:  1014 Y  515  Text BOL:
# 170 x:  1052 Y  515  Text 10771
# 171 x:  993 Y  618  Text
# 172 x:  993 Y  618  Text
# 173 x:  993 Y  618  Text
# 174 x:  993 Y  618  Text Unidad
# 175 x:  1080 Y  618  Text Valor
# 176 x:  1127 Y  618  Text Unitario
# 177 x:  1378 Y  618  Text Importe
# 178 x:  318 Y  731  Text
# 179 x:  318 Y  731  Text
# 180 x:  318 Y  731  Text
# 181 x:  318 Y  731  Text
# 182 x:  318 Y  731  Text
# 183 x:  318 Y  731  Text
# 184 x:  318 Y  731  Text
# 185 x:  318 Y  731  Text
# 186 x:  410 Y  727  Text
# 187 x:  410 Y  727  Text
# 188 x:  410 Y  727  Text
# 189 x:  410 Y  738  Text TRASLADO:
# 190 x:  501 Y  738  Text Base:Impuesto:
# 191 x:  613 Y  738  Text 002-IVA
# 192 x:  670 Y  738  Text Tipo
# 193 x:  705 Y  738  Text de
# 194 x:  726 Y  738  Text factor:
# 195 x:  776 Y  738  Text Tasa
# 196 x:  812 Y  738  Text Tasa
# 197 x:  850 Y  741  Text o
# 198 x:  863 Y  739  Text cuota
# 199 x:  907 Y  738  Text Importe:
# 200 x:  1169 Y  727  Text 1]
# 201 x:  318 Y  760  Text
# 202 x:  318 Y  760  Text
# 203 x:  318 Y  760  Text
# 204 x:  318 Y  760  Text
# 205 x:  76 Y  838  Text
# 206 x:  76 Y  838  Text
# 207 x:  1208 Y  838  Text
# 208 x:  1208 Y  838  Text Subtotal
# 209 x:  1347 Y  848  Text $475,973.28
# 210 x:  76 Y  868  Text
# 211 x:  76 Y  871  Text Sraslado
# 212 x:  806 Y  868  Text Base:|
# 213 x:  860 Y  869  Text Impuesto:
# 214 x:  944 Y  869  Text 002-1VA
# 215 x:  1010 Y  869  Text Tipo
# 216 x:  1050 Y  869  Text de
# 217 x:  1074 Y  869  Text factor:
# 218 x:  1131 Y  869  Text Tasa
# 219 x:  1171 Y  869  Text Tasa
# 220 x:  1215 Y  872  Text o
# 221 x:  1230 Y  869  Text cuota:
# 222 x:  1357 Y  870  Text $36,887.79
# 223 x:  73 Y  889  Text
# 224 x:  73 Y  889  Text
# 225 x:  73 Y  889  Text
# 226 x:  73 Y  889  Text
# 227 x:  76 Y  896  Text
# 228 x:  76 Y  896  Text
# 229 x:  76 Y  896  Text
# 230 x:  76 Y  897  Text Importe
# 231 x:  143 Y  900  Text con
# 232 x:  178 Y  897  Text letra:
# 233 x:  1240 Y  897  Text Total
# 234 x:  1347 Y  896  Text $512,861.07
# 235 x:  1214 Y  910  Text
# 236 x:  1214 Y  910  Text Moneda
# 237 x:  1404 Y  920  Text MXN
# 238 x:  1156 Y  942  Text
# 239 x:  1156 Y  942  Text Tipo
# 240 x:  1194 Y  942  Text de
# 241 x:  1219 Y  942  Text cambio
# 242 x:  1433 Y  942  Text 1
# 243 x:  73 Y  968  Text
# 244 x:  73 Y  968  Text
# 245 x:  73 Y  968  Text
# 246 x:  73 Y  968  Text
# 247 x:  75 Y  982  Text
# 248 x:  75 Y  982  Text
# 249 x:  75 Y  982  Text
# 250 x:  75 Y  982  Text Cadena
# 251 x:  132 Y  982  Text Original
# 252 x:  190 Y  982  Text del
# 253 x:  216 Y  982  Text Complemento
# 254 x:  317 Y  982  Text de
# 255 x:  339 Y  982  Text Certificación
# 256 x:  431 Y  982  Text Digital
# 257 x:  479 Y  982  Text del
# 258 x:  505 Y  982  Text SAT:
# 259 x:  543 Y  982  Text |11.112£7306F9-9511-4238-B84A-6CF5CE4CEB09|2023-02-
# 260 x:  75 Y  999  Text
# 261 x:  75 Y  999  Text
# 262 x:  75 Y  999  Text 14709-25:42|SSTO60807KU0|Egm1tzIZgJu2XS1q+bGnXODrCB9plyKj1JuZt+MBN/SgPwwHTtsTbq46019Vdctu2p1CESytuce5H1jSeeloSTJAXSXXK5D24ApD308CpKalaRNhWKuDtdd13BCbJOwcwo/ynpWa
# 263 x:  75 Y  1015  Text
# 264 x:  75 Y  1015  Text
# 265 x:  75 Y  1005  Text UJGNFLeBSrJ1+Mj5F7alaRoyUtL
# 266 x:  298 Y  1005  Text PxaqC8M2iriNR
# 267 x:  401 Y  1005  Text +yK4zCXpgarm2g7tPzF
# 268 x:  556 Y  1005  Text ZKhIF24nX2XF00
# 269 x:  675 Y  1015  Text Y
# 270 x:  681 Y  1015  Text QwcyLLV5dkxv8AOgvZ56vOmy0WiPwzmDAAZb5bcAN4GyiFAe+S7WNKNWCCKk3cCDN74PtUTEOsIKIETYR
# 271 x:  237 Y  1033  Text
# 272 x:  237 Y  1036  Text aia
# 273 x:  360 Y  1034  Text Dia
# 274 x:  498 Y  1033  Text 2
# 275 x:  298 Y  1033  Text
# 276 x:  298 Y  1033  Text
# 277 x:  298 Y  1033  Text
# 278 x:  298 Y  1033  Text O
# 279 x:  455 Y  1048  Text e
# 280 x:  0 Y  10  Text
# 281 x:  0 Y  10  Text
# 282 x:  0 Y  10  Text
# 283 x:  0 Y  10  Text
# 284 x:  1694 Y  46  Text
# 285 x:  1694 Y  46  Text
# 286 x:  1694 Y  46  Text
# 287 x:  1694 Y  46  Text 10)
# 288 x:  1791 Y  55  Text Iniciar
# 289 x:  1845 Y  55  Text sesión
# 290 x:  1793 Y  92  Text
# 291 x:  1793 Y  92  Text
# 292 x:  1793 Y  92  Text
# 293 x:  1793 Y  88  Text GA
# 294 x:  1842 Y  94  Text E
# 295 x:  1881 Y  92  Text ld
# 296 x:  1822 Y  142  Text
# 297 x:  1822 Y  142  Text
# 298 x:  1822 Y  142  Text
# 299 x:  1822 Y  142  Text Ccerrar
# 300 x:  1902 Y  142  Text >)
# 301 x:  1549 Y  197  Text
# 302 x:  1549 Y  197  Text
# 303 x:  1549 Y  197  Text
# 304 x:  1549 Y  197  Text FORMATO
# 305 x:  1554 Y  219  Text
# 306 x:  1554 Y  219  Text
# 307 x:  1554 Y  219  Text
# 308 x:  1554 Y  219  Text Arial
# 309 x:  1881 Y  219  Text ER
# 310 x:  1548 Y  513  Text
# 311 x:  1548 Y  513  Text
# 312 x:  1548 Y  513  Text
# 313 x:  1548 Y  513  Text OBJETOS
# 314 x:  1549 Y  663  Text
# 315 x:  1549 Y  663  Text
# 316 x:  1549 Y  663  Text
# 317 x:  1549 Y  663  Text DOCUMENTOS
# 318 x:  1635 Y  663  Text DIGITALIZADOS
# 319 x:  1550 Y  686  Text
# 320 x:  1550 Y  686  Text
# 321 x:  1550 Y  686  Text
# 322 x:  1550 Y  686  Text $
# 323 x:  1596 Y  691  Text Configuración
# 324 x:  1548 Y  774  Text
# 325 x:  1548 Y  770  Text
# 326 x:  1576 Y  774  Text
# 327 x:  1576 Y  774  Text Mostrar
# 328 x:  1630 Y  766  Text cuadro:
# 329 x:  1548 Y  799  Text
# 330 x:  1548 Y  799  Text KO
# 331 x:  1576 Y  803  Text Restringir
# 332 x:  1635 Y  795  Text la
# 333 x:  1652 Y  795  Text edi
# 1 x:  0 Y  0  Text
# 2 x:  7 Y  5  Text
# 3 x:  7 Y  5  Text
# 4 x:  30 Y  5  Text
# 5 x:  30 Y  7  Text ECFD_20230214_092414.pdf
# 6 x:  177 Y  0  Text -
# 7 x:  183 Y  7  Text Adobe
# 8 x:  221 Y  7  Text Acrobat
# 9 x:  267 Y  7  Text Pro
# 10 x:  288 Y  7  Text DC
# 11 x:  1890 Y  5  Text x
# 12 x:  7 Y  28  Text
# 13 x:  7 Y  28  Text Archivo
# 14 x:  63 Y  28  Text Edición
# 15 x:  115 Y  28  Text Ver
# 16 x:  145 Y  28  Text Ventana
# 17 x:  201 Y  28  Text Ayuda
# 18 x:  0 Y  10  Text
# 19 x:  0 Y  10  Text
# 20 x:  0 Y  10  Text
# 21 x:  0 Y  10  Text
# 22 x:  302 Y  10  Text
# 23 x:  793 Y  46  Text
# 24 x:  793 Y  46  Text
# 25 x:  1694 Y  46  Text
# 26 x:  1694 Y  46  Text 10)
# 27 x:  1791 Y  55  Text Iniciar
# 28 x:  1845 Y  55  Text sesión
# 29 x:  793 Y  86  Text
# 30 x:  793 Y  92  Text RDO00
# 31 x:  986 Y  99  Text vw
# 32 x:  1789 Y  86  Text RA
# 33 x:  1881 Y  92  Text lo
# 34 x:  21 Y  137  Text
# 35 x:  21 Y  137  Text
# 36 x:  21 Y  137  Text
# 37 x:  21 Y  145  Text Editar
# 38 x:  75 Y  145  Text PDF
# 39 x:  760 Y  139  Text DTaAdR
# 40 x:  1822 Y  137  Text (cerrar
# 41 x:  1902 Y  142  Text )
# 42 x:  1549 Y  197  Text
# 43 x:  1549 Y  197  Text
# 44 x:  1549 Y  197  Text
# 45 x:  1549 Y  197  Text FORMATO
# 46 x:  291 Y  231  Text
# 47 x:  291 Y  231  Text
# 48 x:  1885 Y  231  Text
# 49 x:  1885 Y  231  Text ES
# 50 x:  291 Y  262  Text
# 51 x:  291 Y  262  Text VALERO
# 52 x:  398 Y  262  Text MARKETING
# 53 x:  549 Y  262  Text AND
# 54 x:  609 Y  262  Text SUPPLY
# 55 x:  711 Y  262  Text DE
# 56 x:  751 Y  262  Text MEXICO
# 57 x:  292 Y  323  Text
# 58 x:  292 Y  323  Text
# 59 x:  292 Y  323  Text
# 60 x:  292 Y  323  Text RFC:
# 61 x:  329 Y  323  Text VMS16042911A.
# 62 x:  292 Y  343  Text
# 63 x:  292 Y  343  Text Régimen
# 64 x:  354 Y  343  Text Fiscal:
# 65 x:  400 Y  343  Text 601-General
# 66 x:  484 Y  343  Text de
# 67 x:  505 Y  343  Text Ley
# 68 x:  532 Y  343  Text Personas
# 69 x:  597 Y  343  Text Morales
# 70 x:  292 Y  363  Text
# 71 x:  292 Y  363  Text Lugar,
# 72 x:  335 Y  363  Text fecha
# 73 x:  375 Y  366  Text y
# 74 x:  387 Y  363  Text hora
# 75 x:  419 Y  363  Text de
# 76 x:  440 Y  363  Text expedición:
# 77 x:  517 Y  363  Text 87440
# 78 x:  563 Y  363  Text 14/02/2023
# 79 x:  642 Y  363  Text 09:24:14
# 80 x:  76 Y  403  Text
# 81 x:  76 Y  403  Text
# 82 x:  76 Y  403  Text
# 83 x:  76 Y  403  Text CEI
# 84 x:  88 Y  455  Text
# 85 x:  88 Y  455  Text
# 86 x:  88 Y  455  Text
# 87 x:  88 Y  455  Text PETROLIFEROS
# 88 x:  204 Y  455  Text LOBO
# 89 x:  938 Y  455  Text Lugar
# 90 x:  979 Y  455  Text de
# 91 x:  999 Y  458  Text carga:
# 92 x:  1043 Y  455  Text TRUCK
# 93 x:  1097 Y  455  Text B/S-SunocoBrownsville-MX
# 94 x:  88 Y  475  Text
# 95 x:  88 Y  475  Text
# 96 x:  88 Y  475  Text
# 97 x:  88 Y  475  Text RFC:
# 98 x:  126 Y  475  Text PLO170306G79
# 99 x:  88 Y  495  Text
# 100 x:  88 Y  495  Text
# 101 x:  88 Y  495  Text Régimen
# 102 x:  150 Y  495  Text Fiscal:
# 103 x:  196 Y  495  Text 601-General
# 104 x:  280 Y  495  Text de
# 105 x:  301 Y  495  Text Ley
# 106 x:  328 Y  495  Text Personas
# 107 x:  393 Y  495  Text Morales
# 108 x:  88 Y  515  Text
# 109 x:  88 Y  515  Text Domicilio
# 110 x:  151 Y  515  Text Fiscal:
# 111 x:  197 Y  515  Text 64650
# 112 x:  88 Y  534  Text
# 113 x:  88 Y  534  Text
# 114 x:  88 Y  534  Text Uso
# 115 x:  118 Y  534  Text CFDI:
# 116 x:  159 Y  534  Text G01-Adquisición
# 117 x:  270 Y  534  Text de
# 118 x:  290 Y  534  Text mercancías.
# 119 x:  77 Y  568  Text
# 120 x:  77 Y  568  Text
# 121 x:  77 Y  568  Text
# 122 x:  77 Y  568  Text PRODUCTOS
# 123 x:  236 Y  568  Text /
# 124 x:  250 Y  568  Text SERVICIOS
# 125 x:  318 Y  609  Text
# 126 x:  318 Y  609  Text
# 127 x:  318 Y  609  Text
# 128 x:  318 Y  609  Text Clave
# 129 x:  369 Y  609  Text Prod/
# 130 x:  332 Y  629  Text
# 131 x:  332 Y  629  Text Servicio
# 132 x:  107 Y  656  Text
# 133 x:  107 Y  656  Text
# 134 x:  107 Y  656  Text
# 135 x:  107 Y  656  Text 28471.877
# 136 x:  195 Y  656  Text 87CON11.5.
# 137 x:  325 Y  656  Text 15101514-
# 138 x:  440 Y  656  Text 87
# 139 x:  464 Y  656  Text Oct
# 140 x:  495 Y  656  Text Convencional
# 141 x:  603 Y  656  Text 11.5
# 142 x:  639 Y  656  Text RVP
# 143 x:  677 Y  663  Text -
# 144 x:  688 Y  656  Text H/20054/'
# 145 x:  230 Y  675  Text
# 146 x:  230 Y  675  Text M2
# 147 x:  303 Y  675  Text Gasolina
# 148 x:  374 Y  675  Text regular
# 149 x:  440 Y  675  Text COM/2017
# 150 x:  322 Y  694  Text
# 151 x:  322 Y  697  Text menor
# 152 x:  374 Y  697  Text a
# 153 x:  389 Y  694  Text 91
# 154 x:  335 Y  713  Text
# 155 x:  335 Y  713  Text octanos
# 156 x:  76 Y  614  Text
# 157 x:  76 Y  614  Text
# 158 x:  76 Y  614  Text
# 159 x:  76 Y  614  Text Cantidad
# 160 x:  194 Y  618  Text Clave
# 161 x:  441 Y  618  Text Descri
# 162 x:  938 Y  475  Text
# 163 x:  938 Y  475  Text
# 164 x:  938 Y  475  Text
# 165 x:  938 Y  475  Text Destino:
# 166 x:  994 Y  475  Text 4000207
# 167 x:  1055 Y  482  Text -
# 168 x:  1065 Y  475  Text PETROLIFEROS
# 169 x:  1181 Y  475  Text LOBO-MX-EXPT
# 170 x:  1294 Y  475  Text ONLY,MEX
# 171 x:  938 Y  495  Text
# 172 x:  938 Y  495  Text Fecha
# 173 x:  982 Y  495  Text BOL:
# 174 x:  1020 Y  495  Text 13/02/2023
# 175 x:  938 Y  515  Text
# 176 x:  938 Y  515  Text Número
# 177 x:  993 Y  515  Text de
# 178 x:  1014 Y  515  Text BOL:
# 179 x:  1052 Y  515  Text 10771
# 180 x:  889 Y  609  Text
# 181 x:  889 Y  609  Text
# 182 x:  894 Y  609  Text
# 183 x:  894 Y  609  Text Clave
# 184 x:  889 Y  629  Text
# 185 x:  889 Y  629  Text unidad
# 186 x:  881 Y  655  Text
# 187 x:  881 Y  655  Text
# 188 x:  881 Y  655  Text
# 189 x:  881 Y  656  Text STILL
# 190 x:  928 Y  656  Text itro,
# 191 x:  1007 Y  656  Text 120
# 192 x:  1109 Y  655  Text $16.717313
# 193 x:  1346 Y  655  Text $475,973.28
# 194 x:  883 Y  675  Text
# 195 x:  883 Y  675  Text estándar
# 196 x:  993 Y  618  Text
# 197 x:  993 Y  618  Text
# 198 x:  993 Y  618  Text
# 199 x:  993 Y  618  Text Unidad
# 200 x:  1080 Y  618  Text Valor
# 201 x:  1127 Y  618  Text Unitario
# 202 x:  1378 Y  618  Text Importe
# 203 x:  318 Y  730  Text
# 204 x:  318 Y  730  Text
# 205 x:  318 Y  730  Text
# 206 x:  318 Y  730  Text
# 207 x:  318 Y  731  Text
# 208 x:  318 Y  731  Text
# 209 x:  318 Y  731  Text
# 210 x:  318 Y  731  Text
# 211 x:  410 Y  727  Text
# 212 x:  410 Y  727  Text
# 213 x:  410 Y  727  Text
# 214 x:  410 Y  738  Text TRASLADO:
# 215 x:  501 Y  738  Text Base:Impuesto:
# 216 x:  613 Y  738  Text 002-IVA
# 217 x:  670 Y  738  Text Tipo
# 218 x:  705 Y  738  Text de
# 219 x:  726 Y  738  Text factor:
# 220 x:  776 Y  738  Text Tasa
# 221 x:  812 Y  738  Text Tasa
# 222 x:  850 Y  741  Text o
# 223 x:  863 Y  739  Text cuota
# 224 x:  907 Y  738  Text Importe:
# 225 x:  1169 Y  727  Text 1]
# 226 x:  318 Y  759  Text
# 227 x:  318 Y  759  Text
# 228 x:  318 Y  759  Text
# 229 x:  318 Y  759  Text
# 230 x:  76 Y  871  Text
# 231 x:  76 Y  871  Text
# 232 x:  76 Y  871  Text
# 233 x:  76 Y  871  Text Traslado
# 234 x:  1213 Y  847  Text
# 235 x:  1213 Y  847  Text
# 236 x:  1213 Y  847  Text
# 237 x:  1213 Y  847  Text Subtotal
# 238 x:  860 Y  869  Text
# 239 x:  860 Y  869  Text
# 240 x:  860 Y  869  Text
# 241 x:  860 Y  869  Text Impuesto:
# 242 x:  944 Y  869  Text 002-IVA
# 243 x:  1010 Y  869  Text Tipo
# 244 x:  1050 Y  869  Text de
# 245 x:  1074 Y  869  Text factor:
# 246 x:  1131 Y  869  Text Tasa
# 247 x:  1171 Y  869  Text Tasa
# 248 x:  1215 Y  872  Text o
# 249 x:  1230 Y  869  Text cuota:
# 250 x:  73 Y  888  Text
# 251 x:  73 Y  888  Text
# 252 x:  73 Y  888  Text
# 253 x:  73 Y  888  Text
# 254 x:  76 Y  897  Text
# 255 x:  76 Y  897  Text
# 256 x:  76 Y  897  Text
# 257 x:  76 Y  897  Text Importe
# 258 x:  143 Y  900  Text con
# 259 x:  178 Y  897  Text letra:
# 260 x:  1156 Y  897  Text
# 261 x:  1156 Y  897  Text
# 262 x:  1240 Y  897  Text
# 263 x:  1240 Y  897  Text Total
# 264 x:  1214 Y  920  Text
# 265 x:  1214 Y  920  Text Moneda
# 266 x:  1156 Y  942  Text
# 267 x:  1156 Y  942  Text Tipo
# 268 x:  1194 Y  942  Text de
# 269 x:  1219 Y  942  Text cambio
# 270 x:  73 Y  967  Text
# 271 x:  73 Y  967  Text
# 272 x:  73 Y  967  Text
# 273 x:  73 Y  967  Text
# 274 x:  75 Y  982  Text
# 275 x:  75 Y  982  Text
# 276 x:  75 Y  982  Text
# 277 x:  75 Y  982  Text Cadena
# 278 x:  132 Y  982  Text Original
# 279 x:  190 Y  982  Text del
# 280 x:  216 Y  982  Text Complemento
# 281 x:  317 Y  982  Text de
# 282 x:  339 Y  982  Text Certificación
# 283 x:  431 Y  982  Text Digital
# 284 x:  479 Y  982  Text del
# 285 x:  505 Y  982  Text SAT:
# 286 x:  543 Y  982  Text |11.112£7306F9-9511-4238-B84A-6CF5CE4CEB09|2023-02-
# 287 x:  75 Y  999  Text
# 288 x:  75 Y  999  Text 14709-25:42|SSTO60807KU0|Egm1tzIZgJu2XS1q+bGnXODrCB9plyKj1JuZt+MBN/SgPwwHTtsTbq46019Vdctu2p1CESytuce5H1jSeeloSTJAXSXXK5D24ApD308CpKalaRNhWKuDtdd13BCbJOwcwo/ynpWa
# 289 x:  75 Y  1015  Text
# 290 x:  75 Y  1015  Text
# 291 x:  75 Y  1015  Text
# 292 x:  75 Y  1005  Text UJGNFLeBSrJ1+Mj5F7alaRoyUtL
# 293 x:  298 Y  1005  Text PxaqC8M2iriNR+yK4zCXpgamm2g7tPz!
# 294 x:  455 Y  1048  Text
# 295 x:  455 Y  1048  Text
# 296 x:  455 Y  1048  Text
# 297 x:  455 Y  1048  Text o
# 298 x:  547 Y  1015  Text
# 299 x:  547 Y  1015  Text
# 300 x:  547 Y  1015  Text
# 301 x:  543 Y  1008  Text 'FZKhIF24nX2XFOOY
# 302 x:  681 Y  1015  Text QwcyLLV5dkav8AOgvZ56vQmy0WjPwzmDAAZb5bcAN4GyfFAe+S7WNKNWCjCKk3CCDN74PtU7eQsrK3IETYR
# 303 x:  1548 Y  513  Text
# 304 x:  1548 Y  513  Text
# 305 x:  1548 Y  513  Text
# 306 x:  1548 Y  513  Text OBJETOS
# 307 x:  1549 Y  663  Text
# 308 x:  1549 Y  663  Text
# 309 x:  1549 Y  663  Text
# 310 x:  1549 Y  663  Text DOCUMENTOS
# 311 x:  1635 Y  663  Text DIGITALIZADOS
# 312 x:  1550 Y  686  Text
# 313 x:  1550 Y  686  Text
# 314 x:  1550 Y  686  Text
# 315 x:  1550 Y  686  Text $
# 316 x:  1596 Y  691  Text Configuración
# 317 x:  1548 Y  774  Text
# 318 x:  1548 Y  770  Text
# 319 x:  1576 Y  774  Text
# 320 x:  1576 Y  774  Text Mostrar
# 321 x:  1630 Y  766  Text cuadro:
# 322 x:  1548 Y  799  Text
# 323 x:  1548 Y  799  Text KO
# 324 x:  1576 Y  803  Text Restringir
# 325 x:  1635 Y  795  Text la
# 326 x:  1652 Y  795  Text edi
# 327 x:  0 Y  25  Text
# 328 x:  0 Y  25  Text
# 329 x:  0 Y  25  Text
# 330 x:  0 Y  25  Text
